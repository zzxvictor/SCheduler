# %% [markdown]
# ### SoC database interface, updating all course information when called

# %%
import requests
import os,json
from os.path import join, isdir
from pprint import pprint
import itertools
import dask
import re

class gateway2SoC:
    def __init__(self, outputDir):
        if not isdir(outputDir): # check directory
            os.mkdir(outputDir)
        self.outputDir = outputDir
        self.server = 'http://web-app.usc.edu/web/soc/api'
        self.deptDict  ={}
    def update_course_info(self, term):
        deptList = self.get_dept_list(term)
        multithreader = []
        for dept in deptList:
            multithreader.append(dask.delayed(self.get_dept_course)(dept['code'],dept['name'],term))
        dask.compute(*multithreader)
        self.__save_file(self.deptDict, name='deptDictionary',path = self.outputDir)
    # get a list of departments offering courses
    def get_dept_list(self, term):
        url = '/'.join([self.server,'depts', term])
        data = self.__make_request(url)['department']
        deptList = list(map(self.__dept_extractor, data))
        return list(itertools.chain.from_iterable(deptList))
    # get infor about one course
    def get_one_course(self, courseName, term):
        deptName  = " ".join(re.findall("[a-zA-Z]+", courseName))
        self.get_dept_course(deptName,term, interested = courseName)
        
    # get all courses under one department 
    def get_dept_course(self,deptCode, deptName, term, interested= ''):
        print ('processing courses for: ',deptCode)
        url = '/'.join([self.server,'classes' ,deptCode, term])
        courseList = self.__make_request(url)['OfferedCourses']['course']
        deptDir = join(self.outputDir,deptCode)
        self.deptDict [deptCode] =deptName # update dept dictionary
        if not isdir(deptDir) and len(courseList)>0:
            os.mkdir (deptDir)
        if type(courseList) == dict:
            courseList = [courseList]
        for course in courseList:
            courseName = course['PublishedCourseID']
            if interested != '' and courseName !=interested:
                continue 
            try:
                sessionData = list(map(self.__course_extractor, course['CourseData']['SectionData']))
            except:
                sessionData = [self.__course_extractor(course['CourseData']['SectionData'])]
            # create a file 

            self.__save_file(sessionData, courseName, deptDir) 
                
    #-----private helper
    # make request and return json data
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.json()
    def __course_extractor(self, jsonData):
        wantedFeature = ['type', 'day','start_time','end_time','spaces_available','number_registered','units','dclass_code']
        if jsonData['canceled'] == 'Y' or jsonData['canceled'] == 'y':
            return {}# return an empty dict if the session is cancled
        def helper(feature,jsonData): # handle unavailable information 
            try:
                return (feature,jsonData[feature])
            except:
                return (feature, '')
        extracted = dict((helper(feature,jsonData)) for feature in wantedFeature)
        if 'instructor' in jsonData:
            try:
                extracted['instructorName'] =[','.join([jsonData['instructor']['last_name'] ,jsonData['instructor']['first_name']])]
            except: # multiple prof for the same section
                extracted['instructorName'] =[','.join([prof['last_name'] ,prof['first_name']])
                                             for prof in jsonData['instructor']]
        else:
            extracted['instructorName'] = ''
        return extracted
    # extract department names
    def __dept_extractor(self, jsonData):
        try:
            if type(jsonData['department']) == list:
                return jsonData['department']
            else:
                return [jsonData['department']]
        except:
            return [jsonData] # some program might not have sub-department
    # save session data to a text file
    def __save_file(self, data, name,path): 
        #f =  open(join(path,courseName+'.json'), 'w') # rewrite files
        with open(join(path,name+'.json'), 'w') as fout:
            json.dump(data, fout)

# %%
gateway = gateway2SoC('./tempStorage/')
gateway.update_course_info('20193')
# Out:
# processing courses for: processing courses for: processing courses for: processing courses for:  NSCI
#  MPEM
#   ASTRPJMT
#
# processing courses for:  MOR
# processing courses for:  MUCM
# processing courses for:  LIM
# processing courses for:  RUSS
# processing courses for:  HEBR
# processing courses for:  DPHR
# processing courses for:  DSR
# processing courses for:  SCOR
# processing courses for:  ITP
# processing courses for:  DES
# processing courses for:  CHE
# processing courses for:  PHBI
# processing courses for:  CNB
# processing courses for:  ADNT
# processing courses for:  PAIN
# processing courses for:  MDES
# processing courses for:  CHEM
# processing courses for:  PHRD
# processing courses for:  WCT
# processing courses for:  ENE
# processing courses for:  FSEM
# processing courses for:  THTR
# processing courses for:  AME
# processing courses for:  SANA
# processing courses for:  PSCI
# processing courses for:  OT
# processing courses for:  CLAS
# processing courses for:  NAUT
# processing courses for:  COLT
# processing courses for:  CTAN
# processing courses for:  EALC
# processing courses for:  ACAD
# processing courses for:  SI
# processing courses for:  DBIO
# processing courses for:  SCRM
# processing courses for:  ARAB
# processing courses for:  OFP
# processing courses for:  PSC
# processing courses for:  SPAN
# processing courses for:  QBIO
# processing courses for:  COMM
# processing courses for:  IR
# processing courses for:  JS
# processing courses for:  ANST
# processing courses for:  GR
# processing courses for:  CORE
# processing courses for:  ASCJ
# processing courses for:  WRIT
# processing courses for:  QREA
# processing courses for:  AHIS
# processing courses for:  ACMD
# processing courses for:  SOCI
# processing courses for:  PERI
# processing courses for:  OMOD
# processing courses for:  MPTX
# processing courses for:  BUAD
# processing courses for:  NSC
# processing courses for:  NIIN
# processing courses for:  EDCO
# processing courses for:  BPMK
# processing courses for:  PMEP
# processing courses for:  ARLT
# processing courses for:  EDUE
# processing courses for:  CTPR
# processing courses for:  ARCH
# processing courses for:  BAEP
# processing courses for:  USC
# processing courses for:  ITAL
# processing courses for:  HMGT
# processing courses for:  MUSC
# processing courses for:  MPGU
# processing courses for:  JOUR
# processing courses for:  MUJZ
# processing courses for:  ALI
# processing courses for:  MEDB
# processing courses for:  POSC
# processing courses for:  VISS
# processing courses for:  CBG
# processing courses for:  TRGN
# processing courses for:  PHED
# processing courses for:  MPKS
# processing courses for:  MBPH
# processing courses for:  BISC
# processing courses for:  MPVA
# processing courses for:  ARTL
# processing courses for:  CE
# processing courses for:  GEOL
# processing courses for:  MICB
# processing courses for:  ECON
# processing courses for:  ANAT
# processing courses for:  GCT
# processing courses for:  HINQ
# processing courses for:  MATH
# processing courses for:  LAW
# processing courses for:  NEUR
# processing courses for:  PHYS
# processing courses for:  RXRS
# processing courses for:  CRIT
# processing courses for:  IRAN
# processing courses for:  NURS
# processing courses for:  GPG
# processing courses for:  MASC
# processing courses for:  ARCG
# processing courses for:  CSLC
# processing courses for:  DANC
# processing courses for:  RED
# processing courses for:  OFPM
# processing courses for:  OPER
# processing courses for:  CMGT
# processing courses for:  PCPA
# processing courses for:  PHIL
# processing courses for:  MTAL
# processing courses for:  PLUS
# processing courses for:  PPD
# processing courses for:  AEST
# processing courses for:  ANAT
# processing courses for:  MUCD
# processing courses for:  IDSN
# processing courses for:  EDHP
# processing courses for:  PM
# processing courses for:  ENGL
# processing courses for:  CNTV
# processing courses for:  GRSC
# processing courses for:  LING
# processing courses for:  CBY
# processing courses for:  MSCR
# processing courses for:  DHIS
# processing courses for:  DHYG
# processing courses for:  GERO
# processing courses for:  SSCI
# processing courses for:  MEDS
# processing courses for:  ISE
# processing courses for:  SAE
# processing courses for:  PSYC
# processing courses for:  MUEN
# processing courses for:  MPPM
# processing courses for:  BUCO
# processing courses for:  HCDA
# processing courses for:  GESM
# processing courses for:  PPDE
# processing courses for:  SWMS
# processing courses for:  MPWP
# processing courses for:  RNR
# processing courses for:  GSBA
# processing courses for:  ENST
# processing courses for:  INTD
# processing courses for:  INF
# processing courses for:  COH
# processing courses for:  CTCS
# processing courses for:  PUBD
# processing courses for:  PT
# processing courses for:  MPHY
# processing courses for:  MUHL
# processing courses for:  ART
# processing courses for:  HRM
# processing courses for:  GDEN
# processing courses for:  RSCI
# processing courses for:  EDUC
# processing courses for:  AMST
# processing courses for:  EE
# processing courses for:  HIST
# processing courses for:  GPH
# processing courses for:  CMPP
# processing courses for:  DENT
# processing courses for:  BME
# processing courses for:  BIOC
# processing courses for:  SCIS
# processing courses for:  MPST
# processing courses for:  MDA
# processing courses for:  MSS
# processing courses for:  ACCT
# processing courses for:  PTE
# processing courses for:  LAT
# processing courses for:  DSO
# processing courses for:  EASC
# processing courses for:  MKT
# processing courses for:  EDPT
# processing courses for:  REL
# processing courses for:  MUCO
# processing courses for:  HP
# processing courses for:  FREN
# processing courses for:  INDS
# processing courses for:  ASTE
# processing courses for: processing courses for:  POIR
#  FBE
# processing courses for:  ANTH
# processing courses for:  MS
# processing courses for:  CTIN
# processing courses for:  HBIO
# processing courses for:  DSM
# processing courses for:  ENGR
# processing courses for:  PEDO
# processing courses for:  MUIN
# processing courses for:  SOWK
# processing courses for:  LIFE
# processing courses for:  CSCI
# processing courses for:  SCIN
# processing courses for:  OCCL
# processing courses for:  MED
# processing courses for:  SLL
# processing courses for:  IML
# processing courses for:  PORT
# processing courses for:  CTWR
# processing courses for:  CXPT
# processing courses for:  PR
# processing courses for:  OS
# processing courses for:  ACCT
# processing courses for:  BKN
# processing courses for:  OPR
# processing courses for:  PATH
# processing courses for:  MTEC
# processing courses for:  CJ
# processing courses for:  DPBL
# processing courses for:  ARTS
# processing courses for:  SSEM
# processing courses for:  DIAG
# processing courses for:  GERM

# %% [markdown]
# ### RMP interface, collecting information about a given professor when called

# %%
from bs4 import BeautifulSoup
class gateway2RMP:
    def __init__(self, outputDir):
        if not isdir(outputDir):
            os.mkdir(outputDir)
        self.server = 'https://www.ratemyprofessors.com'
    def get_prof_rating(self, name, department):
        url = ''.join([self.server,
               '/search.jsp?queryoption=HEADER&queryBy=teacherName&schoolName=University+of+Southern+California&schoolID=1381&query=',
               '+'.join(name)])
        soup = BeautifulSoup(self.__make_request(url), 'html.parser')
        relatedProf = []
        for listings in  soup.find_all('li', attrs={'class':'listing PROFESSOR'}):
            link = listings.find('a', href=True)['href']
            name = listings.find('span', attrs = {'class':'main'}).text
            dept = listings.find('span', attrs = {'class':'sub'}).text
            relatedProf.append((link, name,dept))
        if len(relatedProf) == 0:
            print ('not found',name)
        if len(relatedProf) >1:
            print ('multiple', name)
    # make request and return json data
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.text

# %%
gateway = gateway2RMP('D:/Data/SCheduler/RMPData')
for name in names:
    text = gateway.get_prof_rating(name[0].split(','), department='')
# Out:
# not found ['Sanchez', 'Carlos']
# not found ['Mak', 'Chiho']
# not found ['Wang', 'Danny']
# not found ['Kuo', 'Chiaoyun']
# not found ['Roster', 'Michael']
# not found ['Schier', 'Lindsey']
# not found ['Morlacco', 'Monica']
# not found ['Nolan', 'Ginger']
# not found ['Quezada', 'Wanda']
# not found ['Maibaum', 'Paul']
# not found ['Hoyt', 'Justin']
# not found ['Waite', 'Barry']
# not found ['Patel', 'Vishal']
# not found ['Jonas', 'Anthony']
# not found ['Mc Gene', 'Juliana']
# not found ['Rasmussen', 'Robert']
# not found ['Wilson Sweeney', 'Zivia']
# not found ['Childress', 'Amy']
# not found ['Saran', 'Ama']
# not found ['Moss', 'Kelsey']
# not found ['Hasan', 'Angela']
# not found ['Moatasim', 'Faiza']
# not found ['Nguyen', 'Anna Quyen']
# not found ['Thomas', 'Duncan']
# not found ['Moss', 'Karen']
# not found ['Page', 'Tim']
# not found ['Cho', 'Nam']
# not found ['Curiel', 'Yajaira']
# not found ['Filback', 'Robert']
# not found ['Latham', 'Joseph']
# not found ['Dalton', 'Philip']
# not found ['Lovick', 'Jack']
# not found ['Haleblian', 'Herag']
# not found ['Sanner', 'Linda']
# not found ['Park', 'Jin']
# not found ['Libby', 'Jonathan']
# not found ['Sievers', 'Michael']
# not found ['Broughton', 'Bruce']
# not found ['Yang', 'Xinhui']
# not found ['Monge', 'Manuel']
# not found ['Sprague', 'Julia']
# not found ['Arrom', 'Michael']
# not found ['Nuzzo', 'Pierluigi']
# not found ['Morrell', 'Kristy']
# not found ['Stone', 'Arthur']
# not found ['Spedding', 'Geoffrey']
# not found ['Parks', 'Rick']
# not found ['Hihn', 'Jairus']
# not found ['Halligan', 'Buddy']
# not found ['Morlier', 'Louis']
# not found ['Seder', 'Betsy']
# multiple Casper, Drew
# not found ['Floyd', 'Gudrun']
# not found ['Surdyka', 'Marc']
# not found ['Sattelmaier', 'Nakisha']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Bharne', 'Vinayak']
# multiple Daniel, Tiffany
# not found ['Rebbe', 'Rebecca']
# not found ['Napoliello', 'Michael']
# not found ['Phillips', 'Wendy']
# not found ['Padilla', 'Mariela']
# not found ['Flashner', 'Henryk']
# not found ['Huntley', 'Jim']
# not found ['Sellers', 'Jefferey']
# not found ['Alhoussayni', 'Redda']
# not found ['Wang', 'Yuehan']
# not found ['Trifiro', 'Justin']
# not found ['Dutton', 'John']
# not found ['Cain', 'Nicholas']
# not found ['Yamada', 'Kimiko']
# not found ['Schonthal', 'Axel']
# not found ['Jonas', 'Anthony']
# not found ['Coaloa', 'Victoria']
# not found ['Vlaming', 'Jeffrey']
# not found ['Bender', 'Douglas']
# not found ['George', 'Patricia']
# not found ['Bustamante', 'Peggy']
# not found ['Bouteiller', 'Jeanmarie']
# not found ['Cadenas', 'Enrique']
# multiple Fuhrman, Jed
# not found ['Steed', 'Ashley']
# not found ['Fung', 'Cha-Chi']
# not found ['Gurvich', 'Tatyana']
# not found ['Hill-Glover', 'Sandra']
# not found ['Chomyn', 'Christopher']
# not found ['Campbell', 'Charlie']
# not found ['Dickason', 'Kathryn']
# not found ['Nieh', 'Yen-Hsiang']
# not found ['Squire', 'Jason E']
# not found ['Spann', 'Rufus']
# not found ['Krop', 'Cathy']
# not found ['Mecklenburg', 'Matthew']
# not found ['Oyaga', 'Ralph']
# not found ['Ghione', 'Caleb']
# not found ['Schoofs', 'Mark']
# not found ['Schafrik', 'Janice']
# multiple Bristow, Duke
# not found ['Ozaeta', 'Lisa']
# not found ['Roberts', 'Lindsay']
# not found ['Mak', 'Chiho']
# not found ['Kub', 'Joan']
# not found ['Smith', 'Sandra']
# not found ['Moss', 'Kelsey']
# not found ['Schyman', 'Garry']
# not found ['Stewart', 'Peggy']
# not found ['Boley Cruz', 'Nancy']
# not found ['Cousineau', 'Michael']
# not found ['Bastain', 'Tracy']
# not found ['Hamilton', 'Erica']
# not found ['Supranovich', 'Ruth Ann']
# not found ['Dechow', 'Patricia']
# not found ['Mariani', 'Francesca']
# not found ['Wong', 'Laurence']
# not found ['Yilmaz', 'Yasemin']
# not found ['West', 'Jennifer']
# not found ['Miller', 'Lynn']
# not found ['Seib', 'Philip']
# not found ['Smith', 'Krishna']
# not found ['Jang', 'Yuri']
# not found ['Ghirardo', 'Diane']
# not found ['Isken', 'Jonathan']
# not found ["D'Aquila", 'Mitzi']
# not found ['Gramatky Stradling', 'Mimi']
# not found ['Borenstein', 'Mark']
# not found ['King', 'Leslie']
# not found ['Cody', 'Jane']
# not found ['Tellis', 'Gerard']
# not found ['Brown', 'Lauren']
# not found ['Ornelas', 'Ricardo']
# not found ['Ghione', 'Caleb']
# not found ['Stone', 'Arthur']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['Merriman', 'Lynette']
# not found ['Ferson', 'Wayne']
# not found ['Fecht', 'Eric L']
# not found ['Park', 'Daniel']
# not found ['Park', 'Ryan']
# not found ['Apps', 'Kathleen']
# not found ['Dang', 'Richard']
# not found ['Ramsey', 'Robert']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['Lynch', 'Douglas']
# not found ['McCorkle', 'Kevin']
# not found ['Mistrano', 'Samuel']
# not found ['Roberts', 'Lindsay']
# not found ['Nguyen', 'Calvin']
# not found ['Clements', 'Jim']
# not found ['Hahn', 'Michael']
# not found ['Pon', 'Lisa']
# not found ['Pleasants', 'Gregory']
# not found ['Hardasmalani', 'Madhu']
# not found ['Heft', 'James Lewis']
# not found ['Webster III', 'George']
# not found ['Murphy', 'Daniel']
# not found ['Angelopoulou', 'Athina']
# not found ['Richardson', 'Allissa']
# not found ['El Sawy', 'Omar']
# not found ['Stewart', 'Christopher']
# not found ['Meza', 'Kevin']
# not found ['Silverberg', 'Allison']
# not found ['Nguyen', 'Qui-Ha']
# not found ['Wade', 'Isabel']
# not found ['Halsey', 'Jordan']
# multiple Stone, Fred
# multiple Kirschner, Julianna
# not found ['Katz', 'Gail']
# not found ['Klokow', 'Deirdre']
# not found ['Green', 'Richard']
# not found ['Bilson', 'Danny']
# not found ['Foster', 'Kenneth']
# not found ['Seuffert', 'Kirsten']
# not found ['Phark', 'Jin-Ho']
# not found ['Foster', 'Kenneth']
# not found ['Cho', 'Ha Yun']
# not found ['Prince', 'Patrick']
# multiple Filippi, Alessio
# not found ['McKendry', 'Rebekah']
# not found ['Alkhudair', 'Muhammad']
# not found ['Garcia', 'Ralph']
# not found ['Walker', 'Christopher']
# not found ['Brunious', 'Courtney']
# not found ['Nuzzo', 'Pierluigi']
# not found ['Webster', 'Robert']
# not found ['Kar', 'Kian']
# not found ['Marsh', 'Julie']
# not found ['Clark', 'Glenn']
# not found ['Suen', 'Sze-Chuan']
# not found ['Hoffman', 'Linda']
# not found ['Dasu', 'Sriram']
# not found ['Brumer', 'Daniel']
# not found ['Dubois', 'Michel']
# not found ['An', 'Woojin']
# not found ['Withers', 'Mellissa']
# not found ['Ostrov', 'Robert']
# not found ['Hopper', 'Julie']
# not found ['King', 'Sarah']
# not found ['Sandmeier', 'Trudi']
# not found ['Berg', 'Susan']
# not found ['Hanson', 'Mark']
# not found ['Wittig', 'Curt']
# not found ['Mazmanian', 'Dan']
# not found ['Sanchez', 'Cynthia']
# not found ['Corigliano', 'Theresa']
# not found ['Melnik', 'Roman']
# not found ['Cash', 'David']
# not found ['Cho', 'Heejin']
# not found ['Meng', 'Ellis']
# not found ['Thelen', 'Luke']
# not found ['Ephraim', 'Karen']
# not found ['Durham', 'Melissa']
# not found ['Sauder', 'Jonathan']
# not found ['Mayeda', 'Chris']
# not found ['Oda', 'Katsuhiko']
# multiple Ruth, Chung
# not found ['Minejima', 'Emi']
# not found ['Morocco', 'Chris']
# not found ['Bsharah', 'Jacquelyn']
# not found ['Avestimehr', 'Salman']
# not found ['Kim', 'Stephanie']
# not found ['Parga', 'Jennifer']
# not found ['Manis', 'Frank']
# not found ['Bhatia', 'Parul']
# not found ['Schwarz', 'Norbert']
# not found ['Rath', 'Laura']
# not found ['Sellami', 'Nadia']
# not found ['Banuelos', 'Sheila']
# not found ['Miller', 'Tom']
# not found ['Panushka', 'Christine']
# not found ['Whitfield', 'Elizabeth']
# not found ['Johnston', 'Jill']
# not found ['Smith', 'Kathy']
# not found ['Ley', 'Robert']
# not found ['Harris', 'Jennifer']
# not found ['Boros', 'Audrey']
# not found ['Frenkel', 'Baruch']
# not found ['Kropf', 'Claudia']
# not found ['Friar', 'Sean']
# not found ['Seuffert', 'Kirsten']
# not found ['Pacifici', 'Eunjoo']
# not found ['Webster', 'Peter']
# not found ['Austin', 'Kim']
# not found ['Ronen', 'Shlomi']
# not found ['Villalobos', 'Ligiah']
# not found ['Haiges', 'Ralf']
# not found ['Palacios', 'Michael']
# not found ['Fazio', 'Victor']
# not found ['Walsh', 'Julia']
# not found ['Gonzales', 'Vince']
# not found ['Mc Curdy', 'Ron']
# not found ['Natoli', 'Deborah']
# not found ['Park', 'Cw']
# not found ['Jones', 'Christopher']
# not found ['Ochoa', 'Ruben']
# not found ['Robinson', 'Ajita']
# not found ['Chung', 'Eun Ji']
# not found ['Jorgensen', 'Michael']
# not found ['Bottrell', 'Elizabeth']
# not found ['Lenington', 'Kimberly']
# not found ['Brekke', 'John']
# not found ['Arden', 'Michael']
# not found ['Sanger', 'Terence']
# not found ['Ugoretz', 'John K']
# not found ['Sanchez', 'Raquel']
# not found ['Thomas', 'Ladd']
# not found ['Annovi', 'Gian-Maria']
# not found ['Tajima', 'Takako']
# not found ['Sahibzada', 'Khatera']
# not found ['Glasgow', 'David']
# not found ['Webb', 'Christina']
# not found ['Lund', 'Dorothy']
# not found ['Vives', 'Eva']
# not found ['Coleman', 'Catherine']
# not found ['Jones', 'John']
# multiple Fellenzer, Jeff
# not found ['Kartun', 'Allan']
# not found ['Wills', 'Leslie']
# not found ['Yamashiro', 'Stan']
# not found ['Aguilar', 'Stephen']
# not found ['Schneiderman', 'Janet']
# not found ['Foley', 'Paul']
# not found ['Gear Rich', 'Camille']
# not found ['Schneider', 'Ed']
# not found ['Rogers', 'Philip']
# not found ['Westwick', 'Peter']
# not found ['Kurlat', 'Pablo']
# not found ['Li', 'Timothy']
# not found ['Ramsey', 'Robert']
# not found ['Iezman', 'Stanley']
# not found ['Wang', 'Joseph']
# not found ['Shapiro', 'Lauren']
# not found ['Block', 'Richard']
# not found ['Buchanan', 'Denise']
# not found ['Haworth', 'Ian']
# multiple Hernandez, Robert
# not found ['Ta', 'Thu']
# not found ['Lawless', 'Grant']
# not found ['King', 'Samuel']
# not found ['Jeffries', 'Georgia']
# not found ['Richeimer', 'Steven']
# not found ['Kim', 'Su Jung']
# not found ['Zalewska', 'Maria']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Klokow', 'Deirdre']
# not found ['Pire-Smerkanich', 'Nancy']
# not found ['Harper', 'Jason']
# not found ['Fokas', 'Athanassios']
# not found ['Sellers', 'Jefferey']
# multiple Becker, Douglas
# not found ['Zacarias', 'Raymundo']
# not found ['Seldera', 'Joselito']
# not found ['Ho Jr ', 'George']
# not found ['Hall', 'John']
# not found ['Eckel', 'Sandrah']
# not found ['Powell', 'Chloe']
# not found ['Desalvo', 'Anne']
# multiple Sedghizadeh, Parish
# not found ['Gross', 'Larry']
# not found ['Clements', 'Nicholas']
# not found ['Garcia-Sanda', 'Elsa']
# not found ['Andersen', 'Michael']
# not found ['Fanning', 'Michael']
# not found ['Halle', 'Ashley']
# not found ['Hong', 'Ben']
# not found ['Bihr', 'Katherine']
# not found ['Simmons', 'William']
# not found ['Ho', 'Jessica']
# not found ['Enguidanos', 'Susan']
# not found ['Nezami', 'Elahe']
# not found ['Chu', 'Allison']
# not found ['Morrison', 'Leah']
# not found ['Mc Caffery', 'Ed']
# not found ['Sanders', 'Jason']
# not found ['Powers', 'Kate']
# multiple Barone, C. Miranda
# not found ['Brier', 'Jessica']
# not found ['Kobara', 'Jenna']
# not found ['Hoefling', 'Trina']
# not found ['Westberg', 'Steven']
# not found ['Humphrey', 'Eunice']
# not found ['Hirsch', 'Alison']
# not found ['Elfstrom', 'Manfred']
# not found ['Jordan', 'Tom']
# not found ['Lagreco', 'Charles']
# not found ['Cameron', 'Michael']
# not found ['Di Pilato', 'Renee']
# not found ['McNulty', 'Michael']
# not found ['Raghavachary', 'Sathyanaraya']
# not found ['Goetsch', 'David']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['Gruzdys', 'Sophia']
# not found ['Qazwini', 'Hadi']
# not found ['McCarthy', 'T J']
# not found ['Sloane', 'David']
# not found ['Levine', 'Alan']
# not found ['Darna', 'Jeffrey']
# not found ['Margulies', 'Esther']
# not found ['An', 'Woojin']
# not found ['Hearne', 'Ted']
# not found ['Wang', 'Chu-Yi']
# not found ['Marshall', 'Sarah Anindo']
# not found ['Blanc', 'Tara']
# not found ['Pearlman', 'Jeffrey']
# not found ['Hess', 'Susan']
# not found ['Abrahamson', 'Alan']
# not found ['Ortega', 'Alberto']
# not found ['Groper', 'John']
# not found ['Liu', 'Mandong']
# not found ['Tilson', 'Julie']
# not found ['Mousli', 'Beatrice']
# not found ['Sun', 'Xuejing']
# not found ['Raghavachary', 'Sathyanaraya']
# not found ['Staub', 'Josh']
# not found ['Lesak', 'John']
# not found ['Ramuno', 'Philip']
# not found ['Pham', 'Eric N']
# not found ['Chen', 'Jeannie']
# not found ['Marin', 'Maximo']
# not found ['Nieto Manzer', 'Dorothy']
# not found ['Ishop', 'Kedra']
# not found ['Yashin', 'Veli N']
# not found ['Park', 'Jinheoy']
# not found ['Dedhia', 'Devang']
# not found ['Jain', 'Shobhit']
# not found ['Fried-Gintis', 'Sarah']
# not found ['Yasar', 'Kerim']
# not found ['Bryant', 'Joel']
# not found ['Cohn', 'Jody']
# not found ['Holt', 'Sean']
# not found ['Ryback', 'Brett']
# not found ['Kotin', 'Allan']
# not found ['Robertson', 'Eric']
# not found ['Campos', 'Martzi']
# not found ['Kim', 'Eunjin (anna)']
# not found ['Klinger', 'Kris']
# not found ['Dhillon', 'Kiranjeet']
# not found ['Mohamud', 'Ikran']
# not found ['Cunningham', 'Jim']
# not found ['Shea', 'Brendan']
# not found ['Vicinanza', 'Roberto']
# not found ['Nguyen', 'Qui-Ha']
# not found ['Tso', 'Kimberly']
# not found ['Schonthal', 'Axel']
# not found ['Loeb', 'Jerry']
# not found ['Greiman', 'April']
# not found ['Yasar', 'Kerim']
# not found ['Esnaola', 'Maria']
# not found ['Oliveira', 'Luis Paulo']
# not found ['Smith', 'Beth']
# not found ['Stidham', 'Lindsay']
# not found ['Sloan', 'Nathaniel']
# not found ['Chater', 'Andrew']
# not found ['Koetter', 'Alfred']
# not found ['Noble', 'Douglas']
# not found ['Williamson', 'Howard']
# not found ['Pierce', 'Stephen']
# not found ['Farahani', 'Siavash']
# not found ['Ghione', 'Caleb']
# not found ['Woo', 'Darlene']
# not found ['Qazwini', 'Hadi']
# not found ['Hungerford', 'Paul']
# not found ['Puggelli', 'Francesca Romana']
# not found ['Wixon', 'Dennis']
# not found ['Sparangis', 'Themistocles']
# not found ['Strychacz', 'Daniel']
# not found ['Sollett', 'Peter']
# not found ['Geller', 'Kenneth']
# not found ['Banuelos', 'Sheila']
# not found ['Banks', 'Robert']
# multiple Miller, Jennifer
# not found ['Zukis', 'Norman']
# not found ['Calvert', 'Melanie']
# not found ['Leveque', 'Matthew']
# not found ['Wilkins-Langie', 'Rosa']
# not found ['Stodder', 'Seth']
# not found ['Rowley', 'K Michael']
# not found ['Sideris', 'Constantine']
# not found ['Tan', 'Eric']
# not found ['Berman', 'Jason']
# not found ['Landolph', 'Joseph']
# not found ['Jha', 'Birendra']
# not found ['Nash', 'Paul']
# not found ['Heft', 'James Lewis']
# not found ['Jeffords', 'Brandon']
# not found ['Russett', 'Margaret']
# not found ['Forsburg', 'Susan L']
# not found ['Davis', 'Jordan']
# not found ['An', 'Woojin']
# not found ['Roges', 'Rafael']
# not found ['Lantz', 'Jean']
# not found ['Fatouros', 'Cassandra']
# not found ['Lee', 'Jungeun Olivia']
# not found ['Mc Kenna', 'Charles']
# not found ['Hong', 'Young-Kwon']
# not found ['Collins', 'Els']
# not found ['Lepley', 'Meredith']
# not found ['Jenkins', 'Rodrick']
# not found ['Perdomo', 'Marisa']
# not found ['Kaplan', 'Jonas']
# not found ['Barnett', 'Jonathan']
# not found ['Manis', 'Frank']
# not found ['Song', 'Wonho']
# not found ['Wang', 'Han']
# not found ['Quadrato', 'Giorgia']
# not found ['Reed', 'Amy']
# not found ['Tyerman', 'Jessica']
# not found ['Alkhudair', 'Muhammad']
# not found ['Okeeffe', 'James']
# not found ['Nichol', 'Michael']
# multiple McSweyn, Sara
# not found ['Mendoza-De Jesus', 'Ronald']
# not found ['Muller', 'Clark']
# not found ['Johnson', 'Joshua']
# not found ['Berdakin', 'Diego']
# not found ['Prakash', 'Arjun']
# not found ['Kezar', 'Adrianna']
# not found ['Framroze', 'Mayanna']
# not found ['Haas', 'Eric']
# not found ['Molina', 'Natalia']
# not found ['Doyle', 'Kerry']
# not found ['Gillam', 'Reighan']
# not found ['Pflug', 'Paul']
# not found ['Self', 'James']
# not found ['Zhao', 'Zhen']
# multiple Becker, Douglas
# not found ['Savior', 'Valerie']
# not found ['Natoli', 'Deborah']
# not found ['Zhao', 'Zhen']
# not found ['Garvin', 'Benita']
# not found ['Rotstein', 'Ilan']
# not found ['Thrash', 'James']
# not found ['Cohen', 'Ashley']
# not found ['Morrison', 'Leah']
# not found ['Bray', 'Dawn']
# not found ['Ta', 'Thu']
# not found ['Austin', 'Terri']
# not found ['Chen', 'Jiu-Chiuan']
# not found ['Fritz', 'Boris']
# not found ['Cho', 'Ha Yun']
# not found ['Sender', 'Stuart']
# not found ['Johnson', 'Nicole']
# not found ['Kaslow', 'Harvey']
# not found ['Story', 'Stacy']
# not found ['Fisher', 'Scott']
# not found ['Lazzara', 'David']
# not found ['Leal', 'Jorge']
# not found ['Baker', 'Jennifer']
# not found ['Freiser', 'Eric']
# not found ['Washington', 'Ella']
# not found ['Kishibay', 'John']
# not found ['Shen', 'Eric']
# not found ['Allen-Niesen', 'Keith']
# not found ['Duan', 'Leilei']
# not found ['Carrington', 'Ben']
# not found ['Mc Gene', 'Juliana']
# multiple Wilson, Francille
# multiple Hernandez, Robert
# not found ['Medina', 'Loren']
# not found ['Williams', 'Robert']
# not found ['Howard', 'David']
# not found ['Pastore', 'Clare']
# not found ['Moore', 'Jim']
# not found ['An', 'Woojin']
# not found ['Galligan', 'Joyce']
# not found ['Jin', 'Bocheng']
# not found ['Royce', 'Jeremy']
# not found ['Hentis', 'Marisa']
# not found ['Mc Curdy', 'Ron']
# not found ['Globe', 'Anne']
# not found ['Hodge', 'Candace']
# not found ['McNiff', 'P T']
# not found ['An', 'Woojin']
# not found ['Patnoe-Woodley', 'Paula']
# not found ['Saavedra', 'Juan']
# not found ['Scott', 'Matthew']
# not found ["O'Neill", 'Sharon']
# not found ['Kang', 'Hyo']
# not found ['Walker', 'Jim']
# not found ['Lagatta', 'Anne']
# not found ['Kaslow', 'Harvey']
# not found ['Pfizenmaier', 'Laureen']
# not found ['Alfaro', 'Ange-Marie']
# multiple Coombs, Michael
# not found ['Al-Eryani', 'Kamal']
# not found ['Patel', 'Tanvi']
# not found ['Dass', 'Kaali']
# not found ['Hollingshead', 'Andrea']
# not found ['Krausas', 'Veronika']
# multiple Brown, Bruce
# not found ['Dubois', 'Michel']
# not found ['Mayer', 'Doe']
# not found ['Livingston', 'Larry']
# not found ['Lundeen', 'Rebecca']
# not found ['Vasconcellos', 'Marcio']
# not found ['Manetti', 'Carolyn']
# not found ['Qin', 'Joe']
# not found ['Mc Curdy', 'Ron']
# not found ['Roberts', 'Lindsay']
# not found ['Pressley', 'Felicia']
# not found ['Pacifici', 'Eunjoo']
# not found ['El-Damak', 'Dina']
# not found ['Gallagher', 'Raymond']
# not found ['Schmaltz', 'Sarah Katherine']
# not found ['Bradley', 'Nina']
# not found ['Han', 'Emily']
# not found ['Galperin', 'Hernan']
# not found ['Morrell', 'Kristy']
# not found ['McGill', 'Sarah']
# not found ['Mariani', 'Francesca']
# not found ['Mikkelsen', 'Pamela']
# not found ['Garry', 'Hannah']
# not found ['Curran', 'Sean']
# not found ['Dayanim', 'Rebecca']
# not found ['Dreyfus', 'Karen']
# not found ['Hawkins', 'Viannda']
# not found ['Kast', 'W']
# not found ['Spead', 'Michael']
# not found ['Byrd', 'Dani']
# not found ['Takahashi', 'Susumu']
# not found ['Uyeshiro', 'Ashley']
# not found ['Smith', 'Sandra']
# not found ['Jenkins', 'Jeffery']
# not found ['De Leon', 'Adrian']
# not found ['Smith', 'Adam']
# multiple Becker, Douglas
# not found ['Nezami', 'Elahe']
# not found ['Ochi', 'Alexandra']
# not found ['Wilcox', 'Alexandra']
# not found ['Alyakoob', 'Mohammed']
# not found ['MacK', 'Wendy']
# not found ['Melrose', 'M']
# not found ['Bridel', 'David']
# not found ['Powell', 'Yaphett']
# not found ['Cortez', 'Nasser']
# not found ['Collins', 'Els']
# not found ['Winn', 'Jade']
# not found ['Barnes', 'Bradford']
# not found ['Ethington', 'Philip']
# not found ['Zhou', 'Qifa']
# not found ['Guevara', 'Katherine']
# not found ['Pratt', 'Sally']
# not found ['Nxumalo', 'Kristin']
# not found ['Carroll', 'Elizabeth']
# not found ['Kagan', 'Jeremy']
# multiple Brown, Rebecca Latham
# not found ['Hong', 'Young-Kwon']
# not found ['Gautsch', 'Susan']
# not found ['Rice', 'Judd']
# not found ['Koffman', 'Henry']
# not found ['Sinclair', 'Susan']
# not found ['Moran', 'Rachel']
# not found ['Ochi', 'Alexandra']
# not found ['Handley', 'William']
# not found ['Singh', 'Melissa']
# not found ['Sun', 'Xuejing']
# not found ['House', 'Mary']
# not found ['Segil', 'Neil']
# not found ['Lee', 'Changhan']
# not found ['Weiss', 'Eugenia']
# not found ['Reyes', 'Jose']
# not found ['Floyd', 'Gudrun']
# not found ['Pire-Smerkanich', 'Nancy']
# not found ['Ramsey', 'Elizabeth']
# not found ['Malloy', 'Courtney']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['Peters-Lazaro', 'Gabriel']
# not found ['Shnorhokian', 'Hovhanness']
# not found ['Degtyareva', 'Victoria']
# not found ['Kim', 'Susie']
# not found ['Krailo', 'Mark']
# not found ['Goldman', 'Dana']
# not found ['Diemer', 'Dotty']
# not found ['Nezami', 'Elahe']
# not found ['Takahashi', 'Susumu']
# not found ['Heft', 'James Lewis']
# not found ['James', 'Laura']
# not found ['Artavia', 'Margarita']
# not found ['Ghione', 'Caleb']
# not found ['Pearson', 'Mark']
# not found ['Thomas', 'Jennifer']
# not found ['Handley', 'William']
# not found ['Burruss', 'Laurie']
# not found ['Schmidt', 'Eric']
# not found ['Hildebrand', 'Janett']
# not found ['Saks', 'Elyn']
# not found ['Wang', 'Clay']
# not found ['Lee', 'John']
# not found ['Cazaux', 'Ramiro']
# not found ['Horak', 'Kathryn']
# not found ['Babicz', 'Marcelline']
# not found ['Holt', 'Sean']
# not found ['Wilner', 'Brent']
# not found ['Lewis', 'Judy']
# not found ['Landolph', 'Joseph']
# not found ['McCarthy', 'T J']
# not found ['Brier', 'Jessica']
# not found ['Federman', 'Wayne']
# not found ['Thayer', 'Madeline']
# not found ['Alcaraz', 'Alexander']
# not found ['Eiseman', 'Edward H']
# not found ['Grundmann', 'Natascha']
# not found ['Norris', 'Teresa']
# not found ['Aziz-Zadeh', 'Lisa']
# not found ['Belgrader', 'Andrei']
# not found ['Johnson', 'Ed']
# not found ['Vidale', 'John']
# not found ['Muglia', 'Caroline']
# not found ['Jafarpour', 'Behnam']
# not found ['Scott', 'Char']
# not found ['Lagatta', 'Anne']
# not found ['Berger', 'Jack']
# not found ['Donald', 'Paul']
# not found ['Stone', 'Sheldon']
# not found ['Golding', 'Jarrett']
# not found ['Ulin', 'David']
# not found ['Nyquist', 'Julie']
# not found ['Teng', 'Shanghua']
# not found ['Dean', 'Matt']
# not found ['Ferrario', 'Kim']
# not found ['Ullmann', 'Michaela']
# not found ['Borgman', 'Skye']
# not found ['Yanni', 'Rami']
# not found ['Stern', 'Paul']
# not found ['Forner', 'Nancy']
# not found ['Anderson', 'Marcus']
# not found ['Duarte', 'Sillas']
# not found ['Farias', 'Albert']
# not found ['Ban-Weiss', 'George']
# not found ['Cho', 'Ha Yun']
# not found ['Hofman', 'Florence']
# not found ['Nikolaidis', 'Stefanos']
# not found ['Blish', 'Jeffrey']
# not found ['Cureton', 'Ken']
# not found ['Patel', 'Pragna']
# not found ['Halvaksz', 'Jennifer']
# not found ['Kim', 'Eun']
# not found ['Lockman', 'Josh']
# not found ['Cox', 'Matthew']
# not found ['Morr', 'Nicholas']
# not found ['Bain', 'Susan']
# not found ['Riley', 'Laura']
# not found ['Pon', 'Lisa']
# not found ['Green', 'Dennis']
# not found ['Good', 'David']
# not found ['Yao', 'Ke-Thia']
# not found ['Hayashibara', 'Kammie']
# not found ['Bottom', 'James']
# not found ['Paul', 'Donald']
# not found ['Demers', 'Joanna']
# not found ['Hovenkamp', 'Erik']
# not found ['Palmer', 'Abigail']
# not found ['Tinsley', 'Karen']
# not found ['Provart', 'Michael']
# not found ['An', 'Woojin']
# not found ['Fried-Gintis', 'Sarah']
# not found ['Beltran', 'Victoria']
# not found ['Augustine', 'Stanley']
# not found ['Billings', 'Alexandra']
# not found ['Meyer', 'Carl']
# not found ['Postman', 'Anne']
# multiple Brocas, Isabelle
# not found ['Kukavica', 'Igor']
# not found ['Murphy', 'Patrick']
# not found ['Moulton', 'Michael']
# not found ['Ordaz', 'Mary']
# not found ['Gold', 'Michele']
# not found ['Adamik', 'Robert']
# not found ['Esirgen', 'Gokhan']
# not found ['Li', 'Shanshan']
# not found ['McManus', 'Thomas']
# not found ['Ching', 'Ward']
# not found ['Kozinets', 'Robert']
# not found ['Seuffert', 'Kirsten']
# not found ['Alexander', 'Ken']
# not found ['Phelps', 'Thomas']
# not found ['Bredie', 'Nicholas']
# not found ['Raghavachary', 'Sathyanaraya']
# not found ['Quinn', 'Troy']
# not found ['Wang', 'Vivian']
# not found ['Shannon', 'George']
# not found ['Malouf', 'Brian']
# not found ['Donato', 'Adrian']
# not found ['Schneir', 'Michael']
# not found ['Burke', 'Rita']
# not found ['Kirkland', 'Tracie']
# not found ['Franklin', 'Umeka']
# not found ['Eteson', 'Donna']
# not found ['Conlin', 'Caitlyn']
# not found ['Bay', 'Morten']
# not found ['Murphy', 'Mary Ann']
# not found ['Bergquist-Turori', 'Carina']
# not found ['Leggett', 'Ellen']
# not found ['Agius Vallejo', 'Jody']
# not found ['Noveck', 'Mary Anna']
# not found ['Jones', 'Pernell']
# not found ['Hossler', 'Donald']
# not found ['Foley', 'Paul']
# not found ['Dickason', 'Kathryn']
# not found ['McFarland', 'Michael']
# not found ['Pressley', 'Felicia']
# not found ['Webb', 'Christina']
# not found ['Connor', 'J D']
# not found ['Wixon', 'Dennis']
# not found ['Patall', 'Erika']
# not found ['Watson', 'John']
# not found ['Tanaka', 'Terry']
# not found ['Siddarth', 'Sivaramakrishnan']
# not found ['Mendoza-De Jesus', 'Ronald']
# not found ['Wu', 'Wei']
# not found ['Aguila Vega', 'Emma']
# multiple Becker, Douglas
# not found ['Schroeder', 'E Todd']
# not found ['Pasqua', 'Alan']
# not found ['Jacobs', 'Jamie']
# not found ['Antaramian', 'Richard']
# not found ['Chai', 'Yang']
# multiple Fellenzer, Jeff
# not found ['Molina', 'Natalia']
# not found ['Leimgruber', 'P J']
# multiple Becker, Douglas
# not found ['Wang', 'Clay']
# not found ['Schierle', 'G G']
# not found ['Weisberg', 'Ruth']
# not found ['Becerik', 'Burcin']
# multiple Bristow, Duke
# not found ['Platt', 'Jay']
# not found ['Bahng', 'Grace']
# not found ['De Guzman', 'Paolo']
# not found ['Moore', 'David']
# not found ['Tabancay Jr', 'Angel P']
# not found ['Baum', 'Carol']
# not found ['Wang', 'Hue']
# not found ['Sellers', 'Jefferey']
# not found ['Sloan', 'Richard']
# not found ['Fried', 'Rachel']
# not found ['Mulligan', 'Roseann']
# not found ['Yang', 'Xinhui']
# not found ['Thangavelu', 'Madhu']
# not found ['Kahane', 'Jeffrey']
# not found ['Fisher', 'Beth']
# not found ['Boorn', 'Marylynne']
# multiple Pate, Leah
# not found ['Reisman', 'Garrett']
# not found ['Wang', 'Ying']
# not found ['Redfearn', 'Christian']
# not found ['Kao', 'Steve']
# not found ['Seidman', 'Lisa']
# not found ['Floto', 'Jennifer']
# not found ['Tardibuono', 'Joan']
# not found ['Harris', 'Susan']
# not found ['Sandoval', 'Oscar']
# not found ['Park', 'Susie']
# not found ['Jaque', 'Diana']
# not found ['Raff', 'Elisabeth']
# multiple Fuhrman, Jed
# not found ['Datta', 'Mini']
# not found ['Curtis', 'James']
# not found ['Handley', 'William']
# not found ['Holt', 'Sean']
# not found ['Easterling', 'Bret']
# not found ['Altman', 'Scott']
# not found ['Schonthal', 'Axel']
# not found ['Dunn', 'Shannon']
# not found ['Joosten-Hagye', 'Dawn']
# not found ['Belik', 'Anastasiia']
# not found ['Cody', 'Jane']
# not found ['Belson', 'David']
# not found ['Eklund', 'John']
# not found ['Smythe', 'Robert']
# not found ['Delgatty', 'Grant']
# not found ['Humphrey', 'Eunice']
# not found ['Pang', 'Jong-Shi']
# not found ['Acosta-Mejia', 'Cesar']
# not found ['Haggerty', 'Rebecca']
# not found ['Oleszkiewicz', 'Darek']
# not found ['Barcal', 'Jack']
# not found ['Jimenez', 'Felipe']
# not found ['Andres', 'Mary']
# not found ['Good', 'David']
# not found ['Simpson', 'Michael']
# not found ['Nakpil', 'Joseph']
# not found ['Freking', 'Frederick']
# not found ['Burk', 'Anne']
# not found ['Danner', 'Debra']
# not found ['Lane', 'Rikesha']
# not found ['Brown', 'Darryl']
# not found ['Marx', 'Tim']
# not found ['Nazer-Zadeh', 'Hamid']
# not found ['De Liso', 'Debra']
# not found ['Kaneyasu Maranhao', 'Brenno']
# not found ['Conley', 'Courtney']
# not found ['Berger', 'Paige']
# not found ['Xie', 'Jianming']
# not found ['Raichlen', 'David']
# multiple Brown, Linda
# not found ['Seidenberg', 'Willa']
# not found ['Simkovic', 'Michael']
# not found ['Green', 'Richard']
# not found ['Finley', 'James']
# not found ['Beringer', 'Paul']
# not found ['Nelson', 'Margaret']
# not found ['Cheng', 'William']
# not found ['Sung', 'Doris']
# not found ['Raichlen', 'David']
# not found ['Plato-Johnson', 'Lindsey']
# not found ['McDowell', 'Alexander']
# not found ['Maiden', 'R Paul']
# not found ['Angelopoulou', 'Athina']
# not found ['Prieto Botana', 'Goretti']
# not found ['Coleman', 'Kim']
# not found ['Katz', 'Roeban']
# not found ['Kirst', 'Patrick']
# not found ['Metheny', 'Ryan']
# not found ['Yeoman', 'Lauren']
# not found ['Choi', 'Daniel']
# not found ['Reeves', 'Richard']
# not found ['Martin', 'Steven']
# not found ['Ingalls', 'Amanda']
# not found ['Muraszewski', 'Alison']
# not found ['Weinstein', 'Faye']
# not found ['Yashin', 'Veli N']
# not found ['Dubeau', 'Louis']
# not found ['Trovato', 'Steve']
# not found ['Kulakoff', 'Mark']
# not found ['Davis', 'Kristen']
# not found ['Warren Jr ', 'Gene']
# not found ['Kim', 'Rory']
# not found ['Kellar', 'Frances']
# not found ['Zappas', 'Michelle']
# not found ['Ho', 'Mary']
# not found ['Wixon', 'Dennis']
# not found ['Fusselman', 'Ian']
# not found ['Trahan', 'Don']
# not found ['Swain', 'Chris']
# not found ['Fitz-Gerald', 'Kevin']
# not found ['An', 'Woojin']
# not found ['Galstyan', 'Aram']
# not found ['Bowman', 'John']
# not found ['Ryan', 'Amy']
# not found ['Park', 'Jinheoy']
# not found ['Durham', 'Melissa']
# not found ['Squire', 'Jason E']
# not found ['Demers', 'Joanna']
# not found ['Nguyen', 'Michael']
# not found ['Wiley', 'June']
# not found ['Aydin', 'Orhun']
# not found ['Kreutzer', 'Carin']
# not found ['Brown', 'Douglas']
# not found ['Rath', 'Laura']
# not found ['Silverberg', 'Allison']
# not found ['Melguizo', 'Tatiana']
# not found ['Shepherd', 'Mark']
# not found ['Levy', 'Jaime']
# not found ['Nakpil', 'Joseph']
# not found ['Hicks', 'Chevon']
# not found ['Jones', 'Wesley']
# not found ['Taylor', 'Michael']
# not found ['Arnay', 'David']
# not found ['Bennett', 'Daniel']
# not found ['Webster', 'Nicole']
# not found ['Malouf', 'Brian']
# multiple Lee, Mike
# not found ['Ciccone', 'Karen']
# multiple Toshiyuki-Uno, Michael
# not found ['Vranca', 'Caroline']
# not found ['Barroso', 'Max']
# not found ['Shepherd', 'Mark']
# not found ['Winton', 'Chase']
# not found ['Clark', 'Glenn']
# not found ['Boloury-Azad', 'Babak']
# not found ['Goodnight', 'Gerald']
# not found ['Butler', 'Marcus']
# not found ['Potnuru', 'Akshay']
# not found ['Burton', 'Richard']
# multiple Wilson, Francille
# not found ['Stratton', 'Charlotte']
# multiple Filippi, Alessio
# not found ['Asatryan', 'Liana']
# not found ['King', 'Janna']
# not found ['Rogers', 'Philip']
# not found ['Harris', 'Michael']
# not found ['Juteau', 'Juli']
# not found ['Yamaguchi', 'Stephen']
# not found ['Neville', 'Jason']
# not found ['Senyuva', 'Nazli']
# not found ['Chavez Booth', 'Michael']
# not found ['Chang', 'Jincai']
# not found ['Mc Gene', 'Juliana']
# not found ['Soliman', 'Mark']
# not found ['Penton', 'Janis']
# not found ['Birman', 'Daniel']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['McGrath', 'Michael']
# not found ['Kanengiser', 'William']
# not found ['Crockett', 'Donald']
# not found ['Collins', 'Els']
# not found ['Gulin', 'Iain']
# not found ['Lucas', 'Cynthia']
# not found ['Watson', 'John']
# not found ['Bilson', 'Danny']
# not found ['Berhane', 'Kiros']
# not found ['Picus', 'Lawrence']
# not found ['Brinson', 'Peter']
# multiple Moll, Patience
# not found ['Rotz', 'Courtney']
# not found ['Wagner', 'Gary']
# not found ['Mullen', 'Adrienne Ann']
# not found ['Collins', 'Penny']
# not found ['Fleming', 'Steven']
# not found ['Lonergan', 'Rebecca']
# not found ['Harden', 'Bradley']
# not found ['Castro', 'Roderick']
# not found ['Dunn', 'Kathryn']
# not found ['Whitley', 'Richard']
# not found ['Beachem', 'Elizabeth']
# not found ['Sotelo', 'Holly']
# not found ['Yasar', 'Kerim']
# not found ['Kim', 'Annette']
# multiple Wilson, Francille
# not found ['Salhia', 'Bodour']
# not found ['Tiber', 'Arnold']
# not found ['Perlmutter', 'Herb']
# not found ['Lareau', 'Craig']
# multiple Daniel, Tiffany
# not found ['Dunn-Muzingo', 'Kathy']
# multiple Sedghizadeh, Parish
# not found ['Mayer', 'Doe']
# not found ['Beleno Sanchez', 'Joan']
# not found ['Seidenberg', 'Willa']
# multiple Rahimi, Maurice
# not found ['Reynolds', 'Ed']
# not found ['Hjelm', 'Brooke']
# not found ['Culty', 'Martine']
# not found ['Valente', 'Thomas']
# not found ['Padilla', 'Mariela']
# not found ['Havens', 'Kathryn']
# not found ['Haft-Candell', 'Julia']
# not found ['Lucido', 'Jerry']
# not found ['Jahanshad', 'Neda']
# not found ['Hirsch', 'Jeffrey']
# not found ['Murphy', 'Don']
# not found ['Jones', 'Stephen']
# multiple Casper, Drew
# not found ['Pratt', 'Sally']
# not found ['Ehrenreich', 'Ian']
# not found ['Nager', 'Frederick']
# not found ['Siegel', 'Barbara']
# not found ['Hooten', 'Thomas']
# not found ['Brown', 'Tameka']
# not found ['Pitts', 'Deborah']
# not found ['Maldonado', 'Maria']
# not found ['Belisle', 'Natalie']
# not found ['Ryutov', 'Tanya']
# not found ['Hopper', 'Julie']
# not found ['Russett', 'Margaret']
# not found ['Park', 'Sung-Shim']
# not found ['Iyanobor', 'Angela']
# not found ['Pellman', 'Amy']
# not found ['Kirages', 'Daniel']
# not found ['Jo', 'Jeanne']
# not found ['Lyman', 'Kevin']
# multiple Wilson, John
# not found ['Burch', 'Patricia']
# not found ['Garcia-Myers', 'Sandra']
# not found ['Ho', 'Jessica']
# not found ['Alfaro', 'Luis']
# not found ['Gross', 'Larry']
# not found ['Valdez', 'Avelardo']
# not found ['Srivastava', 'Ankur']
# not found ['Potnuru', 'Akshay']
# not found ['Grabarek', 'Patricia']
# not found ['Dieli-Conwright', 'Christina']
# not found ['Whitely', 'Candice']
# multiple Bristow, Duke
# not found ['Beringer', 'Paul']
# not found ['Castaneda', 'Laura']
# not found ['Tarbox', 'Jonathan']
# not found ['Stiles', 'Bangyan']
# not found ['Minnichelli', 'Robert']
# not found ['Galperin', 'Hernan']
# not found ['Varkulja', 'Luciana']
# not found ['Robert', 'Vincent']
# not found ['Landolph', 'Joseph']
# not found ['Swain', 'Chris']
# not found ['Cumberlander', 'Wanda']
# not found ['Kratky', 'Andreas']
# not found ['Keyishian', 'Liz']
# not found ['Patterson', 'Tyler']
# not found ['Bain', 'Susan']
# not found ['Newton', 'Paul']
# not found ['Santos', 'Oscar']
# not found ['Zimmerman', 'Gilbert']
# not found ['Jann', 'Kay']
# not found ['Kaldjian', 'Kevin']
# not found ['Hill', 'Robert H']
# not found ['Adibe', 'Bryant']
# not found ['Hewitt', 'Donald']
# not found ['Makijan', 'Narineh']
# not found ['Potenza', 'Frank']
# not found ['Yip', 'Felix']
# not found ['Lytal', 'Cristy']
# not found ['Rohrbach', 'Luanne']
# not found ['De Dominic', 'Nicholas']
# not found ['Kaye', 'Barry']
# not found ['Russell-Schlesinger', 'Charles']
# not found ['Olesen', 'Eric']
# not found ['Nikolaidis', 'Stefanos']
# not found ['Timm', 'Joel']
# not found ['Neubauer', 'Catherine']
# not found ['Hernandez', 'Christine']
# not found ['Reynolds', 'Ed']
# not found ['Vidale', 'John']
# not found ['Tsotsis', 'Theo']
# multiple Ramcharan, Rodney
# not found ['Sellami', 'Nadia']
# not found ['Santos', 'Oscar']
# not found ['Jessen', 'Kristian']
# not found ['Hales', 'Chaz']
# not found ['Agius Vallejo', 'Jody']
# not found ['West', 'Jeffrey']
# not found ['Okamoto', 'Curtis']
# not found ['Mallikarjun Sharada', 'Shaama']
# not found ['Leach', 'William']
# not found ['Flick', 'Stephen']
# not found ['Aranas', 'Pauline']
# not found ['Nezami', 'Elahe']
# not found ['Barraza', 'Jorge']
# not found ['Ariel', 'Jordan']
# not found ['Aclan', 'Megan']
# not found ['Robison', 'Mark']
# not found ['Stewart', 'Kirk']
# not found ['Posatko', 'Mary']
# not found ['Tom', 'James']
# not found ['Filback', 'Robert']
# not found ['Page Lippsmeyer', 'Kathryn']
# not found ['Buniatyan', 'Spartak']
# not found ['Owusu', 'Frederick']
# not found ['Deng', 'Yu']
# not found ['Nikoukar', 'Sahand']
# not found ['Rushen', 'Patrice']
# not found ['Kata', 'Tak']
# not found ['MacK', 'Wendy']
# not found ['Shahabi', 'Cyrus']
# not found ['Dang', 'Tim']
# not found ['Roman', 'Francisco']
# not found ['Cole', 'Tiffany']
# not found ['Han', 'Phuu']
# not found ['An', 'Woojin']
# not found ['Desai', 'Snehal']
# not found ['Sims', 'Shilby']
# not found ['Lu', 'Paul']
# not found ['Neff', 'Jessica']
# not found ['Meyerowitz', 'Beth']
# not found ['Dapkus', 'Paul']
# not found ['Klokow', 'Deirdre']
# not found ['Mousli', 'Beatrice']
# not found ['Quintana', 'Taqueena']
# not found ['Park', 'Jennifer']
# not found ['Eckel', 'Sandrah']
# not found ['Harris', 'Michael']
# not found ['Patnoe-Woodley', 'Paula']
# not found ['Epstein', 'Josh']
# not found ['Mulligan', 'Roseann']
# not found ['Choueiti', 'Marc']
# not found ['Libgober', 'Jonathan']
# not found ['Broitman', 'Samantha']
# not found ['Schnell', 'Jovi']
# not found ['Chidester', 'Margaret']
# not found ['Cizmar', 'Paula']
# not found ['Xu', 'Zhiming']
# not found ['Wheeler', 'Matthew']
# not found ['Krause', 'Elizabeth']
# not found ['Wahlroos-Ritter', 'Roland']
# not found ['Nakpil', 'Joseph']
# not found ['Westwick', 'Peter']
# not found ['Balmagia', 'Larry']
# not found ['Pahlevan', 'Niema']
# not found ['Pratt', 'F J']
# not found ['Richmond', 'Frances']
# not found ['Ta', 'Thu']
# not found ['Gillam', 'Reighan']
# not found ['Stevens', 'Mary']
# not found ['Ben-Ari', 'Ron']
# not found ['Agius Vallejo', 'Jody']
# not found ['La Brot', 'Benjamin']
# not found ['Bridges', 'Bob']
# not found ['Green', 'Richard']
# not found ['Fink', 'Michael']
# not found ['Kaslow', 'Harvey']
# not found ['Norman', 'Andrew']
# not found ['Zerunyan', 'Frank']
# not found ['Schnurr', 'Carl']
# not found ['Cho', 'Ha Yun']
# not found ['Tenderich', 'Burghardt']
# not found ['Hamer', 'Lauren']
# not found ['Johnson', 'Toni Ann']
# not found ['Seuffert', 'Kirsten']
# not found ['Seabury', 'Seth']
# not found ['Corbin', 'Patrick']
# not found ['Huang', 'Isaac K']
# not found ['Wong', 'Paul']
# not found ['Banks', 'Robert']
# not found ['Johnson Hayes', 'Deborah']
# not found ['Ryan', 'Tom']
# not found ['Howard', 'James']
# not found ['Deiner', 'James']
# not found ['Lohenry', 'Kevin']
# not found ['Bremond', 'Diandra']
# not found ['Framroze', 'Mayanna']
# not found ['Esirgen', 'Gokhan']
# not found ['Quinn', 'David']
# not found ['Glover', 'John']
# not found ['Dalton', 'Philip']
# multiple Brown, Bruce
# not found ['Bates', 'Julie']
# not found ['Wu', 'An-Min']
# not found ['Smith', 'Richard']
# not found ['Dieterle', 'Camille']
# not found ['Chernick', 'Richard']
# not found ['Couts', 'Spencer']
# not found ['King', 'Ron']
# not found ['Martinez Celaya', 'Enrique']
# multiple De La Roca, Jorge
# not found ['Castaneda', 'Laura']
# not found ['Korchek', 'Jeffrey']
# not found ['Vyas', 'Nick']
# not found ['Russett', 'Margaret']
# not found ['Crockett', 'Donald']
# not found ['Marek', 'Craig']
# not found ['Peracchio', 'Joe']
# not found ['Blush', 'Doug']
# not found ['Mori', 'Cynthia']
# not found ['Womack', 'Vincent']
# not found ['Mintzer', 'Bob']
# not found ['Parks', 'Michael']
# not found ['Yazdiha', 'Hajar']
# not found ['Lieu', 'Cynthia']
# not found ['Matsusaka', 'John']
# not found ['Looman', 'Mary']
# not found ['Jessen', 'Kristian']
# not found ['Gonzales', 'Vince']
# not found ['Jones', 'Penelope']
# not found ['Lee', 'Vinson']
# not found ['Pacifici', 'Angelo']
# not found ['Huerta', 'Adrian']
# not found ['Williams Brooks', 'Jacquelyn']
# not found ['Jutkowitz', 'Alexander']
# not found ['Gensler', 'Cynthia']
# not found ['Kar', 'Nikhil']
# not found ['Charles', 'Breea']
# not found ['Grayson', 'Shannon']
# not found ['Schonthal', 'Axel']
# not found ['Hausner', 'Larry']
# not found ['Haj-Mohamadi', 'Sourena']
# not found ['Soibelman', 'Lucio']
# not found ['Mc Gregor', 'Kristen']
# not found ['Hollis Ochetti', 'Marlene']
# not found ['Chee', 'Winston']
# not found ['Yashin', 'Veli N']
# not found ['Shubenkina', 'Ekaterina']
# not found ['Michelsen', 'Renee']
# not found ['Peeps', 'Claire']
# not found ['Mosqueda', 'Cynthia']
# not found ['Gillam', 'Reighan']
# not found ['Farnham', 'Peggy']
# not found ['Hayashi', 'Tomoaki']
# not found ['Schroeder', 'E Todd']
# not found ['Ibrahim', 'Zuhair']
# not found ['Andujo', 'Estela']
# not found ['Sloan', 'Nathaniel']
# not found ['Powers', 'Chris']
# not found ["O' Malley", 'Nathan']
# not found ['Hwang', 'Amie']
# not found ['Beachem', 'Elizabeth']
# not found ['Kudva', 'Jayanth']
# not found ['Rayburn', 'Kalim']
# not found ['Albrezzi', 'Steven']
# not found ['Knatz', 'Geraldine']
# not found ['Ta', 'Thu']
# not found ['Tolomiczenko', 'George']
# not found ['Harper', 'Shaun']
# not found ['Park', 'Jinheoy']
# not found ['Yamaguchi', 'Noriko']
# not found ['Danko', 'Tiffany']
# not found ['Moser', 'Margaret']
# not found ['Kuznetsov', 'Dmitrii']
# not found ['Kingsley', 'Karrie']
# not found ['Huang', 'Qiang']
# not found ['Schreiner', 'Julie']
# not found ['McQuillen', 'Colleen']
# not found ['Danenberg', 'Peter']
# not found ['Rawlings', 'Kelly']
# not found ['Green', 'Alan']
# not found ['French', 'Quade']
# not found ['Hu', 'Caroline']
# not found ['Tabatabaeenejad', 'Alireza']
# not found ['Choi', 'Rebecca']
# not found ['Ghalambor', 'Donna']
# not found ['Southers', 'Erroll']
# not found ['Cepeda', 'Alice']
# not found ['Mendoza-De Jesus', 'Ronald']
# not found ['Petersen', 'Jennifer']
# not found ['Trujillo', 'Osvaldo']
# not found ['Inozu', 'Bahadir']
# not found ['Silverberg', 'Allison']
# not found ['Treweek', 'Jennifer']
# not found ['Petersen', 'Jennifer']
# not found ['Warshofsky', 'David']
# not found ['Jessen', 'Kristian']
# not found ['Capron', 'Alex']
# not found ['Marsili', 'Jason']
# not found ['Wilson', 'Melissa']
# not found ['Bursky', 'Rick']
# not found ['Bellantoni', 'Christina']
# not found ['Blodget', 'Emily']
# multiple Wilson, John
# not found ['Gai', 'Xiaowu']
# not found ['Richert', 'Amber']
# multiple Smith, Bruce
# not found ['Harding', 'Lars']
# not found ['McKelvin', 'Mark']
# not found ['Goldsworthy', 'Raymond']
# not found ['Bahng', 'Grace']
# not found ['Dutta', 'Shantanu']
# not found ['Pantano-Rubino', 'Carlos']
# multiple Black, David S
# not found ['Culty', 'Martine']
# not found ['Klerman', 'Lisa']
# not found ['Schulze', 'Emily']
# not found ['Firsick', 'Dylan']
# not found ['Qazwini', 'Hadi']
# not found ['Gupta', 'Shalini']
# not found ['Leimgruber', 'P J']
# not found ['Davies', 'Daryl']
# not found ['Porter', 'Kathleen']
# not found ['Shaffer', 'Matthew']
# not found ['Frenkel', 'Baruch']
# not found ['Wander', 'Stephanie']
# not found ['Kim', 'Samuel']
# not found ['Medrano', 'Eric']
# not found ['Da Silva', 'Diane']
# multiple Barone, C. Miranda
# not found ['Brennan', 'John']
# not found ['Moon', 'Hyungsik Roger']
# not found ['Clarke', 'Peter']
# not found ['West-Faulcon', 'Kimberly']
# not found ['Vigil', 'Jesse']
# not found ['Wang', 'Clay']
# not found ['Mc Kenna', 'Charles']
# not found ['Johnson', 'Amy']
# not found ['Svadjian', 'Raffi']
# not found ['Floyd', 'Gudrun']
# not found ['Wolfington', 'Lindsay']
# not found ['Belson', 'David']
# not found ['Richmond', 'Frances']
# not found ['Padilla', 'Mariela']
# not found ['Cuccia', 'Nicholas']
# not found ['Guyer', 'Cindy']
# multiple James, Jane
# not found ['Schneider', 'Lee']
# not found ['Dauchot', 'Luke']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Green', 'Richard']
# not found ['Popp', 'Kimberly']
# not found ['Sommer', 'S Amy']
# not found ['Madni', 'Azad']
# not found ['Kasimow', 'Erin']
# not found ['Richey', 'Joyce']
# not found ['Lee', 'Lucy V']
# not found ['Landa', 'Edgar']
# not found ['Sloan', 'Nathaniel']
# not found ['Sloan', 'Nathaniel']
# not found ['Ramos', 'Jennifer']
# not found ['Quintana', 'Taqueena']
# not found ['Booth', 'Thomas']
# not found ['Turner', 'Myra']
# not found ['Stanton', 'Timothy']
# not found ['Bowles', 'Susan']
# not found ['Felt', 'Laurel']
# not found ['Botz', 'Hanns']
# not found ['Mousli', 'Beatrice']
# not found ['Alamo', 'Rosamaria']
# not found ['Dodds', 'Kimberly']
# not found ['Findeisen', 'Christopher']
# not found ['Fava Hochuli', 'Josephine']
# not found ['Scotten', 'Donald']
# not found ['Petasis', 'Nicos']
# not found ['Plocek', 'Keith']
# not found ['Turner', 'Kim']
# not found ['Bastian', 'Maurice']
# not found ['Salem', 'George']
# not found ['Irimia', 'Andrei']
# not found ['Floyd', 'Gudrun']
# not found ['Turner', 'Robert']
# not found ['Dapkus', 'Paul']
# not found ['Doctor', 'Jason']
# not found ['Hillier', 'Mary']
# not found ['Mintzer', 'Bob']
# multiple Coombs, Michael
# not found ['Scholder', 'Stacy']
# not found ['Castro', 'Carl']
# not found ['Alejado', 'Karen']
# not found ['Barnhart', 'David']
# not found ['Yin', 'Pai-Ling']
# not found ['Park', 'Jinheoy']
# not found ['Kaneyasu Maranhao', 'Brenno']
# not found ['Resnik', 'Cheryl']
# not found ['Yashin', 'Veli N']
# not found ['Beachem', 'Elizabeth']
# not found ['Kroopf', 'Scott']
# not found ['Minet-Lucid', 'Pamela']
# not found ['Benzon', 'Kiki']
# not found ['Ohama', 'Natsuko']
# not found ['Blake', 'Bonnie']
# not found ['Sligar', 'Sara']
# not found ['Bogdan', 'Paul']
# not found ['Hawkins', 'Satinder']
# not found ['Tanbonliong', 'Thomas']
# not found ['Lynett', 'Patrick']
# not found ['Ng', 'Tien']
# not found ["O'Hagan", 'Jennie']
# not found ['Chaisson', 'Mark']
# not found ['Brooker', 'Musa']
# not found ['Sumi', 'Joyce']
# not found ['Schrock', 'Andrew']
# not found ['Akinfemi', 'Bayo']
# not found ['Ochi', 'Emily']
# not found ['Coleman', 'Cheryl']
# not found ['Hinton', 'David']
# not found ['Frank', 'Eric']
# not found ['Leal', 'Jorge']
# not found ['Mor Barak', 'Michalle']
# not found ['Sakaguchi', 'Mark']
# not found ['Vayanos', 'Phebe']
# not found ['Green', 'Karen']
# not found ['Beckman', 'Christine']
# not found ['Bohlinger', 'Donald']
# not found ['Uranga', 'Alejandra']
# not found ['Town', 'Terrence']
# multiple Bozovic, Iva
# not found ['Kim', 'Samuel']
# not found ['Hannan', 'Michael']
# not found ['Chinn', 'Dana']
# not found ['Mc Kenna', 'Charles']
# not found ['Muthuswamy', 'Nithya']
# not found ['Cox', 'Llewellyn']
# not found ['Smith', 'Todd']
# not found ['Wade', 'Isabel']
# not found ['Suarez', 'Piedad']
# not found ['Lamkin Grancio', 'Lauren']
# not found ['Madden', 'Michael']
# not found ['Nihom', 'Joe']
# not found ['Rosenthal', 'Jane']
# not found ['Gupta', 'Satyandra']
# not found ['Anderson', 'Karen']
# not found ['Wade', 'Isabel']
# not found ['Thomas', 'Ladd']
# not found ['Kaslow', 'Harvey']
# not found ['Burton', 'Kate']
# not found ['Harvey', 'Shae']
# not found ['Mann', 'Elisabeth']
# not found ['Gertz', 'Laurence']
# not found ['Fullerton', 'Tracy']
# not found ['Cooper', 'Christine']
# not found ['Kaslow', 'Harvey']
# not found ['Bartner', 'Arthur']
# not found ['Neretina', 'Ekaterina']
# multiple Walsh, John
# not found ['Duran', 'Tomas']
# not found ['Wang', 'Jay']
# not found ['Manzone', 'Jessica']
# not found ['Manuel II', 'Douglas']
# not found ['Yang', 'Xinhui']
# not found ['Habibian', 'Mina']
# not found ['Paine', 'Michael']
# not found ['Farnham', 'Peggy']
# not found ['Schepens Niemiec', 'Stacey']
# not found ['Uwins', 'Simon']
# not found ['Morland', 'Graeme']
# not found ['Pratt', 'Sally']
# not found ['Murphy', 'Sheila']
# not found ['Annovi', 'Gian-Maria']
# not found ['Kaneyasu Maranhao', 'Brenno']
# not found ['Sun', 'Xuejing']
# not found ['Sandheinrich', 'Kris']
# not found ['Spann', 'Rufus']
# not found ['Green', 'Susan']
# not found ['Bishop', 'Gregory']
# not found ['Comi', 'Diane']
# not found ['Vermulst', 'Marc']
# not found ['Lacy', 'Suzanne']
# not found ['Hiebert', 'Tyler']
# not found ['Franklin', 'Meredith']
# multiple Shipley, Brad
# not found ['Cohn', 'Gary']
# not found ['Lurie', 'Steven']
# not found ['Bustamante', 'Nao']
# not found ['Schonthal', 'Axel']
# not found ['Brunell', 'Natalie']
# not found ['Curtis', 'Mathew']
# not found ['Rigon', 'Silvia']
# not found ['Zerunyan', 'Frank']
# not found ['Westwick', 'Peter']
# not found ['Blain', 'Roberto']
# not found ['Austin', 'Andrea']
# not found ['Barton', 'Corey']
# not found ['Jha', 'Birendra']
# not found ['Oneil', 'Harry']
# not found ['Jha', 'Birendra']
# not found ['Carlin', 'Daniel']
# not found ['Latimer', 'Millard']
# not found ['Antaramian', 'Richard']
# not found ['Madni', 'Azad']
# not found ['McMahon', 'Andrew']
# not found ['Gabrielian', 'Aroussiak']
# not found ['Riley', 'Patricia']
# not found ['Fanghanel Santibanez', 'Eric']
# not found ['Steinberg', 'Jane']
# not found ['Campbell', 'Lori']
# not found ['Ching', 'Ward']
# not found ['Johnson Harrison', 'Dian']
# not found ['Rasheed', 'Suraiya']
# not found ['Russett', 'Margaret']
# not found ['Trifunac', 'Mihailo']
# not found ['Kemper', 'Thomas']
# not found ['Ogilvie', 'Nathan']
# not found ['Feldman', 'Corinne']
# not found ['Seib', 'Philip']
# not found ['Goldman', 'Jason']
# not found ['Malisos', 'Samantha']
# not found ['Shakeshaft', 'Robin']
# not found ['Harrison', 'Olivia C']
# not found ['Farmer', 'Judith']
# not found ['Kinsella', 'Patrick']
# not found ['Yang', 'Xinhui']
# not found ['Soria', 'Cynthia']
# not found ['Vermulst', 'Marc']
# not found ['Marcu', 'Bogdan']
# not found ['Wang', 'Bing']
# not found ['Wind', 'James']
# not found ['Griffith', 'Tom']
# not found ['Bahl', 'Deepak']
# not found ['Yaron', 'Linda']
# not found ['Dole', 'Cindy']
# not found ['Rudin', 'Deniz']
# not found ['Cadambi', 'Anitha']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Cody', 'Jane']
# not found ['Masri', 'Sami']
# not found ['Chandrasoma', 'Janak']
# not found ['Franzwa', 'Pam']
# not found ['Khashe', 'Yalda']
# not found ['Cunningham', 'Jim']
# not found ['Padilla', 'Mariela']
# not found ['Castaneda', 'Laura']
# not found ['Calanni', 'John']
# not found ['Pohle', 'Cara']
# not found ['Gordon', 'Stewart']
# not found ['Cheng', 'Teresa']
# not found ['Chater', 'Andrew']
# not found ['Pratt', 'Sally']
# multiple Sarna, Sim
# not found ['Sartori', 'Neimar']
# not found ['Kaslow', 'Harvey']
# not found ['Pier', 'Thomas']
# not found ['De La Fuente', 'Jennifer']
# not found ['Malzahn', 'Scott']
# not found ['Charas', 'Solange']
# not found ['Owens', 'John']
# not found ['Miller', 'Melissa L']
# not found ['Lin', 'Carol']
# not found ['Kintzle', 'Sara']
# not found ['Findeisen', 'Christopher']
# not found ['Chow', 'Mina']
# not found ['Abid', 'Mohamed']
# not found ['Forrester', 'Kevin']
# not found ['Lagatta', 'Anne']
# not found ['Chesley', 'Gregory']
# not found ['Thames', 'April']
# not found ['Kingsley Vertenten', 'Dr Dora']
# not found ['Boeing', 'Geoff']
# not found ['Ebramzadeh', 'Edward']
# not found ['Westwick', 'Peter']
# not found ['Martini', 'Aaron']
# not found ['Townsend', 'Robert']
# not found ['Spatz', 'Ian']
# not found ['Faia', 'Michael']
# not found ['Kling', 'Gregory']
# not found ['Liberman', 'Danica']
# multiple Filippi, Alessio
# not found ['Goetz', 'Jack']
# not found ['Moeller', 'Jeffrey']
# not found ['Lupovitz', 'Dan']
# not found ['Rosen', 'Jovanna']
# not found ['Burnham', 'Hannah']
# not found ['Shaikh', 'Sonia Jawaid']
# not found ['Lucas', 'Gale']
# not found ['Wuestewald', 'Todd']
# not found ['Konis', 'Kyle']
# not found ['Demers', 'Joanna']
# not found ['Schoeben', 'Rob']
# not found ['Duarte', 'Sillas']
# not found ['Winstein', 'Carolee']
# not found ['Lulejian', 'Armine']
# not found ['Chong', 'Traysi']
# not found ['Kim', 'Namkil']
# not found ['Jackson', 'Laura']
# multiple Formigoni, Marco
# not found ['Wald', 'James']
# not found ['Schorsch', 'Kathleen']
# multiple Wilson, Francille
# not found ['Margolin', 'Gayla']
# not found ['Delvecchio', 'Gene']
# not found ['Burki', 'Uzma']
# not found ['Meyers', 'Michelle']
# not found ['Grant', 'Derisa']
# not found ['Trovato', 'Steve']
# not found ['Karafantis', 'Layne']
# not found ['Newmyer', 'Richard']
# not found ['Wu', 'Wei']
# not found ['Hinton', 'David']
# not found ['Kaslow', 'Harvey']
# not found ['Pesaran', 'Hashem']
# not found ['Chang', 'Jincai']
# not found ['Neff', 'Jessica']
# not found ['Fife', 'Elizabeth']
# not found ['Lasmana', 'Viola']
# not found ['Riggio', 'Marsha']
# not found ['McGrath', 'Michael']
# not found ['Domasin', 'Gary']
# not found ['Louie', 'Stan']
# not found ['Haraldsson', 'Helga']
# not found ['Tan', 'Patricia']
# not found ['Patnoe-Woodley', 'Paula']
# not found ['Schonthal', 'Axel']
# not found ['Pereira', 'Joseph']
# not found ['Mc Ilvery', 'Richard']
# not found ['Braun', 'Theodore']
# not found ['Callaway', 'Trey']
# not found ['Levine', 'David']
# not found ['Bay', 'Morten']
# not found ['Sweeney', 'Mary']
# not found ['Lee', 'Daniel']
# not found ['Bouchard', 'Sean']
# not found ['Ahmadi', 'Shafiqa']
# not found ['Morgan', 'Alaina']
# not found ['Joe', 'Nam']
# not found ['Power', 'Gerard']
# not found ['Hummer', 'Don']
# not found ['Tolson', 'Franita']
# not found ['Byrd', 'Dani']
# not found ['Manuel II', 'Douglas']
# not found ['Ingenito', 'Robert']
# not found ['Moon', 'Casey']
# not found ['Ying', 'Qilong']
# not found ['John', 'Seth']
# not found ['Harwood', 'Matthew']
# not found ['Jaconi', 'Kristen']
# not found ['Radan', 'Elham']
# not found ['Annovi', 'Gian-Maria']
# not found ['Stevens', 'Gregory']
# not found ['Melnick', 'Glenn']
# not found ['Acosta-Mejia', 'Cesar']
# not found ['Simmons', 'William']
# multiple Wilson, John
# not found ['Smith', 'Shelley']
# not found ['Bairoliya', 'Neha']
# not found ['Khorshad', 'Daniel']
# not found ['Roche', 'John']
# not found ['Tran', 'Jennifer']
# not found ['Sedano', 'Elisabeth']
# not found ['Savla', 'Ketan']
# not found ['Slots', 'Jorgen']
# not found ['Davis', 'Charles']
# not found ['Shelton', 'Judith']
# not found ['Lee', 'John']
# not found ['McNitt-Gray', 'Jill L']
# not found ['MacCalla', 'Nicole']
# not found ['Greene', 'Sharon']
# not found ['Delgado Jr', 'Celso']
# not found ['Luna', 'Lisa']
# not found ['Geffner', 'Carol']
# multiple Lee, Mike
# multiple Brauer, Elizabeth
# not found ['Garman', 'John']
# not found ['Ghirardo', 'Diane']
# not found ['Dipprey', 'Ellen-Linnea']
# not found ['Trifiro', 'Justin']
# not found ['Elledge', 'Robin']
# not found ['Rasheed', 'Suraiya']
# not found ['Bruzzese', 'Vincent']
# not found ['Han', 'Phuu']
# not found ['Parrish', 'David']
# not found ['Renov', 'Michael']
# not found ['Cox', 'Robynn']
# not found ['Merrill-Brugger', 'Amy']
# not found ['Demers', 'Joanna']
# not found ['Manderscheid', 'Ronald']
# not found ['Eatwell', 'John']
# not found ['Kaslow', 'Harvey']
# not found ['Sellers', 'Jefferey']
# not found ['Phan', 'Phan']
# not found ['Kaki', 'Rym']
# not found ['Tzudiker', 'Bob']
# not found ['Burke', 'Rita']
# not found ['Richmond', 'Frances']
# not found ['Kanengiser', 'William']
# not found ['Maxfield', 'Jessica']
# not found ['Tobiska', 'William']
# not found ['Hakomori', 'Yo-Ichiro']
# not found ['Jovanovic', 'Mihailo']
# not found ['Bell', 'Catherine']
# not found ['Marjoram', 'Paul']
# not found ['Angelson', 'Caryn']
# not found ['Alvarez', 'Boni']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Sridharan', 'Vishnu']
# not found ['Guinter', 'Jennifer']
# not found ['Gonzales', 'Vince']
# not found ['McCann', 'Pamela']
# not found ['Buniatyan', 'Spartak']
# not found ['Martinez', 'Clarisa']
# not found ['Floto', 'Jennifer']
# not found ['Villaverde', 'Vivien']
# not found ['George', 'Patricia']
# not found ['Bar', 'Fran̤ois']
# not found ['Manuel II', 'Douglas']
# not found ['Sun', 'Xuejing']
# not found ['Maarek', 'Jean-Michel']
# not found ['Clemens', 'Roger']
# not found ['Abrams', 'Thomas']
# not found ['Alpren', 'Emily']
# not found ['Kane', 'Kevin']
# not found ['King', 'Agatha']
# not found ['Pade', 'Courtney']
# not found ['Renov', 'Michael']
# not found ['Koffman', 'Henry']
# not found ['Chong', 'Dennis']
# not found ['Beyer-Johnson', 'Kim']
# not found ['Kleinbard D', 'Edward']
# not found ['Kar', 'Kian']
# not found ['Smith', 'Michael Dennis']
# not found ['Nguyen', 'Michaela']
# not found ['Ito', 'Kaori']
# not found ['Lazari', 'Matthew']
# not found ['Abramson', 'Jeremy']
# not found ['Katritch', 'Vsevolod']
# not found ['Nealy', 'Zahra']
# not found ['Fischer', 'Mike']
# not found ['Page', 'Tim']
# not found ['Hazelton', 'Deborah']
# not found ['Gepshtein', 'Sergei']
# not found ['Kestermann', 'Rolf']
# not found ['Lenet', 'Scott']
# not found ['Tambascia', 'Tracy']
# not found ['Peterson', 'Richard']
# not found ['Ryan', 'Amy']
# not found ['Gillam', 'Reighan']
# not found ['Roberts', 'Lindsay']
# not found ['Clark', 'Glenn']
# not found ['McCormick', 'Bruce']
# not found ['Kho', 'Adam']
# multiple Wilson, Francille
# not found ['Mendoza', 'Vincent']
# not found ['Combs', 'Wayne']
# not found ['McHale', 'Maureen']
# not found ['Rosenfield', 'Jason']
# not found ['Bassi', 'Vittorio']
# not found ['Fleming', 'Steven']
# not found ['Sellers', 'Jefferey']
# not found ['Amaya', 'Hector']
# not found ['Molina', 'Natalia']
# not found ['Mitchell', 'Ronald']
# not found ['Kiddoo', 'Bob']
# not found ['Paige', 'Gary']
# not found ['Shahi', 'Santosh']
# not found ['Cox', 'Linda']
# not found ['Frydman', 'Alon']
# not found ['Jacobson', 'Tom']
# not found ['Brown', 'Andrae']
# not found ['Gallagher', 'Katie']
# not found ['Hirabayashi', 'Kimberly']
# not found ['Finn', 'Bruce']
# not found ['Waters-Roman', 'Debra']
# not found ['Panova', 'Greta']
# not found ['Schiller', 'Robert']
# not found ['Park', 'Karen']
# not found ['Mantell', 'Samuel']
# not found ['Kim', 'Seon']
# not found ['Belling', 'Shawn']
# not found ['Tennant', 'Scott']
# not found ['Choi', 'Joon-Ho']
# not found ['Rohs', 'Remo']
# not found ['Brown', 'Garrett']
# not found ['Hodge', 'Amy']
# not found ['Ochoa', 'Ruben']
# not found ['Cody', 'Jane']
# not found ['Furay', 'John']
# not found ['Kast', 'W']
# not found ['Fong', 'Miller']
# not found ['Madhukar', 'Anupam']
# not found ['Cozby', 'Jason']
# not found ['Cash', 'David']
# not found ['Kim', 'B K Elizabeth']
# not found ['Hill', 'Robert']
# not found ['Ray', 'Stephan']
# not found ['Peng', 'Nanyun']
# multiple Wilson, Francille
# not found ['Guzman', 'Andrew']
# not found ['Mc Gene', 'Juliana']
# not found ['Bong', 'Tiffany']
# not found ['Jaconi', 'Kristen']
# not found ['Dieken', 'Paul']
# not found ['Sussman', 'Daniel']
# not found ['Rohs', 'Remo']
# not found ['Culty', 'Martine']
# not found ['Rogers', 'Philip']
# not found ['Stark', 'Charles']
# not found ['Russell', 'Scott']
# not found ['Prioleau', 'Paul']
# not found ['Beckman', 'Christine']
# not found ['Tynes', 'Brendesha']
# not found ['Mutlow', 'John']
# not found ['Hay', 'Joel']
# not found ['Kelley', 'David']
# not found ['Bennett', 'Mia']
# not found ['Swain', 'Chris']
# not found ['Munoz', 'Mike']
# not found ['Benzon', 'Kiki']
# not found ['Dubeau', 'Louis']
# not found ['Lundeen', 'Rebecca']
# not found ['Desai', 'Ruchi']
# not found ['Ban-Weiss', 'George']
# not found ['Regur', 'Carey']
# not found ['Lippit', 'Akira Mizuta']
# not found ['Mitchell', 'Kenneth']
# not found ['Shih', 'Win']
# not found ['Richardson', 'Allissa']
# not found ['Kiddoo', 'Bob']
# not found ['Carrington', 'Ben']
# not found ['Marx', 'Andrew']
# not found ['Bernstein', 'Jennifer']
# not found ['Kaplan', 'Sandra']
# not found ['Ticheli', 'Frank']
# multiple Rummel, Heidi
# not found ['Uriu', 'Scott']
# not found ['Hahn', 'Michael']
# not found ['Robles', 'Darline']
# not found ['Goldman', 'Dana']
# not found ['Johnson', 'Clifford']
# not found ['York', 'Ashley']
# not found ['Haworth', 'Ian']
# not found ['Kouyoumdjian', 'Natalie']
# not found ['Lewis', 'Jenebah']
# not found ['Donald', 'Paul']
# not found ['Rasmussen', 'Rebecca']
# not found ['Katritch', 'Vsevolod']
# not found ['Reisig', 'Jason']
# not found ['Madhukar', 'Anupam']
# not found ['Dipprey', 'Ellen-Linnea']
# not found ['Yillik', 'Amy']
# multiple Armour, Jody
# not found ['Mc Ilvery', 'Richard']
# not found ['Harper', 'Elizabeth']
# not found ['Morrison', 'Leah']
# not found ['Landolph', 'Joseph']
# not found ['Kejriwal', 'Mayank']
# not found ['Creager', 'Todd']
# not found ['Blackard', 'Gary']
# not found ['Santinelli', 'Gabriella']
# not found ['Chen', 'Casey']
# not found ['Arora', 'Gitanjli']
# not found ['Graham', 'Nicholas']
# not found ['Lyons-Moore', 'Akilah']
# not found ['Handley', 'William']
# not found ['Pynoos', 'Jon']
# not found ['Walsh', 'Patrick']
# not found ['Schonthal', 'Axel']
# not found ['McKean-Cowdin', 'Roberta']
# not found ['Schmitt', 'Howard']
# not found ['Rawlings', 'Kelly']
# not found ['Manos', 'Matthew']
# not found ['Cherry', 'Nathan']
# not found ['Tescher', 'Woodie']
# not found ['Gates', 'Jodie']
# not found ['Molina', 'Natalia']
# not found ['Bellamy', 'Gordon']
# multiple Rollo-Carlson, Cynthia
# not found ['De Leon', 'Adrian']
# not found ['Beachem', 'Elizabeth']
# not found ['Jolles', 'Monica']
# not found ['Hoskin', 'Maia']
# not found ['Cooperdock', 'Emily']
# not found ['Galloway', 'Scotty']
# not found ['Schierle', 'G G']
# not found ['Arevalo', 'Lupe']
# not found ['Bruckheimer', 'Bonnie']
# not found ['Rock', 'Loretta']
# not found ['Kar', 'Nikhil']
# not found ['Chang', 'Patty']
# not found ['Hlavka', 'Jakub']
# not found ['Jochai', 'Diana']
# not found ['Ramirez', 'Sally']
# not found ['MacOn-Oliver', 'Cheryl']
# not found ['Raber', 'Jack']
# not found ['Simmons', 'William']
# not found ['Mc Curdy', 'Ron']
# not found ['Maquiling', 'David']
# not found ['Holder', 'Bill']
# not found ['Boley Cruz', 'Nancy']
# not found ['Foster', 'Mike']
# not found ['Nguyen', 'Qui-Ha']
# not found ['Smith', 'Brian']
# not found ['Bamberg', 'Annelise']
# not found ['Hollingshead', 'Andrea']
# not found ['Shaffer', 'Gary']
# not found ['Hopper', 'Julie']
# not found ['Alfaro', 'Ange-Marie']
# not found ['Chasalow', 'Michael']
# not found ['Diewald', 'James']
# not found ['Benzon', 'Kiki']
# not found ['Kresin', 'Vitaly']
# not found ['Riggio', 'Marsha']
# not found ['Nguyen', 'Qui-Ha']

# %%
baseDir = 'D:/Data/SCheduler/SoCData'
deptList = os.listdir(baseDir)
names = []

for dept in deptList:
    try:
        courses = os.listdir(os.path.join(baseDir, dept))
        for course in courses:
            names += list(getProfNames(course,dept, baseDir))
    except:
        print (dept)
        pass
names = [(pair[0][0], pair[1]) for pair in names if pair[0] !='']
names = set(names)
# Out:
# deptDictionary.json

# %%
def getProfNames(courseName, deptName,baseDir):
    path = os.path.join(baseDir, deptName, courseName)
    with open(join(baseDir,deptName,courseName), 'r') as fin:
        data = json.load(fin)
    for session in data:
        if session != {}:
            yield (session['instructorName'], deptName)

# %%
len(names)
# Out:
# 3991
