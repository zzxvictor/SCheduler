# %%
import requests
import os,json
from os.path import join, isdir
from pprint import pprint
import itertools as it
import dask
import re
from bs4 import BeautifulSoup
import string 
import numpy as np

# %%
class SoCInterface:
    def __init__(self):
        self.SoCPrefix = 'http://web-app.usc.edu/web/soc/api' 
    '''
    get the list of active instructors of the given semester. 
    Take ~10 secs to run [7.62 s ± 545 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)]
    parameter: 
        semester, str, for instance: '20193' (2019 Fall)
    return:
        prof name, set, for instance: {(first, last), (first, last)...}
    '''
    def get_all_instructors(self, semester):
        url = '/'.join([self.SoCPrefix,'depts', semester]) # form a valid url
        schoolList = self.__make_request(url)['department']
        deptList = list(map(self.__dept_extractor, schoolList)) 
        deptList = list(it.chain.from_iterable(deptList)) # flatten the data structure, [{code:csci, name:comp science},{}]
        # now use get instructor info (multithreading)
        multithreader = [ dask.delayed(self.__get_dept_course)(dept,semester) for dept in deptList]
        # flattened result
        return list(set(list(it.chain.from_iterable(dask.compute(*multithreader, scheduler = 'threads',num_workers=12))) ))

    #---------------------------
    # private helpers 
    '''
    retrieve information from the given url 
    parameter:
        url: a valid url 
    return:
        a json file 
    '''
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.json()
    '''
    extract department names
    parameter: 
        dictionary: a dictionary of school information
    return:
        a list of departments under the given school, list of str
    '''
    def __dept_extractor(self, dictionary):
        try:
            if type(dictionary['department']) == list:
                return dictionary['department']
            else:
                return [dictionary['department']] # some school only has one department 
        except:
            return [dictionary] # some school might not have sub-department
    '''
    extract course information 
    parameter: 
        courseData: dictionary generated by __get_dept_course
    return:
        list of intructors of an given class, list of tuple
    '''
    def __course_extractor(self, courseData):
        if courseData['canceled'] == 'Y' or courseData['canceled'] == 'y':
            return []# return an empty dict if the session is cancled
        if 'instructor' in courseData:
            if type(courseData['instructor']) == dict: # mutiple instructors
                return [(courseData['instructor']['first_name'], courseData['instructor']['last_name']) ]
            else: # multiple prof for the same section
                return [(prof['first_name'], prof['last_name']) for prof in courseData['instructor']]
        else:
            return []
        
    '''
    get all courses under the same department
    parameter: 
        deptInfo, dictionary generated by getAllInstructors
        semester, str, for instance: '20193' (2019 Fall)
    return: a list of professors under the given department, a list of tuple
    '''
    def __get_dept_course(self,deptInfo, semester):
        url = '/'.join([self.SoCPrefix,'classes' ,deptInfo['code'], semester])
        courseList = self.__make_request(url)['OfferedCourses']['course']
        if type(courseList) == dict: # some dept has only one course
            courseList = [courseList]
        profList = []
        for course in courseList: 
            if type(course['CourseData']['SectionData']) == dict:  # some course has only one session
                profList += [self.__course_extractor(course['CourseData']['SectionData'])]
            else:
                profList += list(map(self.__course_extractor, course['CourseData']['SectionData']))
        return list(it.chain.from_iterable(profList)) # flatten the list

# %%
class RMPInterface:
    def __init__(self, outDir):
        if not isdir(outDir):
            os.mkdir (outDir)
        self.outDir = outDir
        self.RMPPrefix = 'https://www.ratemyprofessors.com'
        self. queryBody = '/search.jsp?queryoption=HEADER&queryBy=teacherName&schoolName=University+of+Southern+California&schoolID=1381&query='
    def update_prof_DB(self, profList):
        multithreader = [ dask.delayed(self.__get_prof_info)(prof) for prof in profList]
        profScoreList = list(dask.compute(*multithreader, scheduler = 'threads', num_workers=12))
        profScoreList = list (filter (lambda profInfo: len(profInfo)>0, profScoreList))
        
        #with open(join(self.outDir,'profInfoDB.json'), 'w') as outfile:
        #    json.dump(dict(profScoreList), outfile)
        return profScoreList
    '''    
    retrieve information about the given professor
    parameter:
        profName, tuple, (first name, last name)
    return: 
        information about the prof, tuple, for instance:
        (name, {department name 1: (score, # of raters), department name 2: (score, # of raters)}) 
        a name may have several departments because people may have the same name
    '''
    def __get_prof_info(self, profName):
        print ('processing prof:', profName)
        url = ''.join([self.RMPPrefix,self.queryBody,'+'.join(profName)])
        profListPage = BeautifulSoup(self.__make_request(url), 'html.parser')
        relatedProf = []
        for listings in  profListPage.find_all('li', {'class':'listing PROFESSOR'}):
            profUrl = self.RMPPrefix + listings.find('a', href=True)['href']# link to prof's individual page
            dept = listings.find('span', attrs = {'class':'sub'}).text.split(',')[-1]
            profInfoPage = BeautifulSoup(self.__make_request(profUrl), 'html.parser')
            rateTuple = self.__extract_prof_info(profInfoPage)
            if rateTuple != tuple(): # in case no information found 
                relatedProf.append (rateTuple)
        relatedProf = np.array(list (filter (lambda x:len(x)>1, relatedProf)))
        try:
            return (' '.join(profName), [np.mean(relatedProf[:,0]), np.mean(relatedProf[:,1]), sum(relatedProf[:,2])])
        except:
            return (' '.join(profName), [])
    '''
    make request and return text data
    parameter:
        url: a valid url pointing to RMP pages
    return:
        web content, str
    '''
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.text
    
    def __extract_prof_info(self, profInfoPage):
        try:
            grade = profInfoPage.find_all('div', {'class': 'grade'}, limit=2) # get avg. RMP score
            # get num of rater
            raterNum = re.findall(r'\b\d+\b',profInfoPage.find('div', {'class': 'table-toggle rating-count active'}).text)
            avgScore, diffLevel = float(grade[0].text),  float(re.findall(r'\b\d+\b',grade[1].text)[0])/100
            return [ avgScore, diffLevel, int(raterNum[0])]
        except:
            return []

# %%
# %%time
gateway = SoCInterface()
profs = gateway.get_all_instructors('20193')
# Out:
# CPU times: user 6.07 s, sys: 870 ms, total: 6.94 s
# Wall time: 10.3 s

# %%
# %%time
gateway = RMPInterface('.')
#gateway.update_prof_DB([('aaron', 'cote')])
profInfo = gateway.update_prof_DB(profs)
# Out:
# processing prof: processing prof:('Bret', 'Nielsen')
#  ('Robert', 'Williams')
# processing prof: processing prof:('Ekaterina', 'Neretina')
#  ('Jeffrey', 'Vlaming')
# processing prof: ('Elsi', 'Kaiser')
# processing prof: ('Mark', 'McKelvin')
# processing prof: ('Margaret', 'Nelson')
# processing prof: ('Marc', 'Ballon')
# processing prof: ('Kathryn', 'Poindexter')
# processing prof: ('Keith', 'Burghardt')
# processing prof: ('Shana', 'Kraynak')
# processing prof: ('Jesse', 'Wilson')
# processing prof: ('Leah', 'Kemp')
# processing prof: ('Christopher', 'Muniz')
# processing prof: ('Khalil', 'Iskarous')
# processing prof: ('Kenneth', 'Breisch')
# processing prof: ('Michael', 'Renov')
# processing prof: ('Julian', 'Gutierrez-Albilla')
# processing prof: ('Allan', 'Kartun')
# processing prof: ('Maged', 'Dessouky')
# processing prof: ('Garrett', 'Brown')
# processing prof: ('Bangyan', 'Stiles')
# processing prof: ('Jon', 'Burlingame')
# processing prof: ('Murat', 'Bayiz')
# processing prof: ('Daria', 'Roithmayr')
# processing prof: ('Alice', 'Baumgartner')
# processing prof: ('Nicole', 'Jackson')
# processing prof: ('Judith', 'Hirsch')
# processing prof: ('Phil', 'Meyer')
# processing prof: ('Anthony', 'Kemp')
# processing prof: ('Michelle', 'Rosado')
# processing prof: ('Joselito', 'Seldera')
# processing prof: ('Amy', 'Johnson')
# processing prof: ('Lori', 'Campbell')
# processing prof: ('Rym', 'Kaki')
# processing prof: ('Ralf', 'Haiges')
# processing prof: ('Manochehr', 'Rashidian')
# processing prof: ('Eric', 'Schmidt')
# processing prof: ('Michael', 'Press')
# processing prof: ('Sandra', 'Smith')
# processing prof: ('Ashton', 'Cooper')
# processing prof: ('Timothy', 'Li')
# processing prof: ('Edward', 'Rhodes')
# processing prof: ('Brett', 'Sheehan')
# processing prof: ('Nicholas', 'Graham')
# processing prof: ('Devang', 'Dedhia')
# processing prof: ('Casey', 'Chen')
# processing prof: ('Jeffery', 'Jenkins')
# processing prof: ('Meredith', 'Franklin')
# processing prof: ('Joseph', 'Nunes')
# processing prof: ('Yaphett', 'Powell')
# processing prof: ('Ann', 'Majchrzak')
# processing prof: ('Ryan', 'Metheny')
# processing prof: ('William', 'Simmons')
# processing prof: ('Wendy', 'Phillips')
# processing prof: ('Jong-Shi', 'Pang')
# processing prof: ('Andrea', 'Parra')
# processing prof: ('Clayton', 'Stephenson')
# processing prof: ('Rory', 'Lukins')
# processing prof: ('Iva', 'Bozovic')
# processing prof: ('Kurt', 'Palmer')
# processing prof: ('Jessica', 'Tyerman')
# processing prof: ('Monica', 'Bachner')
# processing prof: ('Rebecca', 'Brown')
# processing prof: ('Megan', 'Meylor')
# processing prof: ('Emma', 'Jackson')
# processing prof: ('Ian', 'Culbertson')
# processing prof: ('Darren', 'Ruddell')
# processing prof: ('Kathryn', 'Horak')
# processing prof: ('Rebecca', 'Lonergan')
# processing prof: ('Michaela', 'Nguyen')
# processing prof: ('David', 'Gerber')
# processing prof: ('Melissa', 'Wilson')
# processing prof: ('Steven', 'Fleming')
# processing prof: ('Jim', 'Cunningham')
# processing prof: ('Patrick', 'Walsh')
# processing prof: ('Hilary', 'Schor')
# processing prof: ('Michael', 'Fink')
# processing prof: ('Rodney', 'Ramcharan')
# processing prof: ('David', 'Raichlen')
# processing prof: ('Teddy', 'Lance')
# processing prof: ('Douglas', 'Fleming')
# processing prof: ('Roland', 'Wahlroos-Ritter')
# processing prof: ('Donald', 'Collins')
# processing prof: ('Peter', 'Erskine')
# processing prof: ('Akshay', 'Potnuru')
# processing prof: ('Solange', 'Charas')
# processing prof: ('Ekaterina', 'Shubenkina')
# processing prof: ('Nikhil', 'Bhatia')
# processing prof: ('Suzanne', 'Hudson')
# processing prof: ('Dale', 'Kiefer')
# processing prof: ('Hans', 'Oh')
# processing prof: ('Holly', 'Willis')
# processing prof: ('Michael', 'McNulty')
# processing prof: ('Jamie', 'Jacobs')
# processing prof: ('Lem', 'Dobbs')
# processing prof: ('Rodrick', 'Jenkins')
# processing prof: ('Benjamin', 'Weiss')
# processing prof: ('Rebekah', 'McKendry')
# processing prof: ('Dara', 'Barker')
# processing prof: ('Gabriel', 'Peters-Lazaro')
# processing prof:processing prof: ('Sung-Hwa', 'Park')
#  ('Kirk', 'Snyder')
# processing prof: ('Tracy', 'Fullerton')
# processing prof: ('Grace', 'Cheng')
# processing prof: ('Peter', 'Danenberg')
# processing prof: ('Shefali', 'Rajamannar')
# processing prof: ('Irina', 'Jestkova')
# processing prof: ('Jordan', 'Davis')
# processing prof: ('Nancy', 'Boley Cruz')
# processing prof: ('Hajar', 'Yazdiha')
# processing prof: ('John', 'Watson')
# processing prof: ('Brittany', 'Kay')
# processing prof: ('Mina', 'Habibian')
# processing prof: ('Christopher', 'Smith')
# processing prof: ('Cruz', 'Arroyo')
# processing prof: ('Karen', 'Moss')
# processing prof: ('Oscar', 'Aparicio')
# processing prof: ('Xavier', 'Fumat')
# processing prof: ('Vishal', 'Patel')
# processing prof: ('Betsy', 'Seder')
# processing prof: ('Ken-Ichi', 'Nomura')
# processing prof: ('Molly', 'Bendall')
# processing prof: ('Frank', 'Potenza')
# processing prof: ('Deborah', 'Johnson Hayes')
# processing prof: ('Caleb', 'Ghione')
# processing prof: ('Mary', 'McNamara')
# processing prof:processing prof:  ('Kirsten', 'Seuffert')
# ('Eileen', 'Abel')
# processing prof: ('Dotty', 'Diemer')
# processing prof: ('Carolyn', 'Manetti')
# processing prof: ('June', 'Wiley')
# processing prof: ('Julie', 'Marsh')
# processing prof: ('Joseph', 'Garlington')
# processing prof: processing prof:('Antoine', 'Bechara')
#  ('Bogdan', 'Marcu')
# processing prof: ('Juliana', 'Mc Gene')
# processing prof: ('Mark', 'Pearson')
# processing prof: ('Stephen', 'Yamaguchi')
# processing prof: ('Nicholas', 'Morr')
# processing prof: ('Quan', 'Nguyen')
# processing prof: ('Paula', 'Carbone')
# processing prof: ('Bruce', 'Green')
# processing prof: ('Hee Seong', 'Lee')
# processing prof: ('Lucienne', 'Aarsen')
# processing prof:processing prof: ('Roberto', 'Diaz')
#  ('Dion', 'Dickman')
# processing prof: ('Kristen', 'Davis')
# processing prof: ('Aurelien', 'Davennes')
# processing prof:processing prof: ('Mike', 'Fischer')
#  ('Vincent', 'Farenga')
# processing prof: ('Marisa', 'Hentis')
# processing prof: ('Yiying', 'Zheng')
# processing prof: processing prof:processing prof:('Joe', 'Peracchio')  ('Eva', 'Kanso')
# ('Bistra', 'Dilkina')
#
# processing prof: ('Corey', 'Barton')
# processing prof: ('Timo', 'Preece')
# processing prof: ('Paul', 'Stern')
# processing prof: ('Frederick', 'Owusu')
# processing prof: ('Stephen', 'Pierce')
# processing prof: ('Bonnie', 'Shrewsbury')
# processing prof: ('Cindy', 'Dole')
# processing prof: ('Stephanie', 'Wander')
# processing prof: ('Richard', 'Jones')
# processing prof: ('Andrew', 'Leff')
# processing prof: ('Lauren', 'Shapiro')
# processing prof: ('Leslie', 'King')
# processing prof:processing prof: ('James', 'Diewald')
#  ('Joanna', 'Demers')
# processing prof: ('Leah', 'Hochman')
# processing prof: ('Russell', 'Jacobs')
# processing prof: ('Steven', 'Brookman')
# processing prof: ('Cymra', 'Haskell')
# processing prof: ('Paula', 'Walker-Kestermann')
# processing prof: ('Taqueena', 'Quintana')
# processing prof: ('Elizabeth', 'Zelinski')
# processing prof: ('Evelyn', 'Boria-Rivera')
# processing prof: ('Betsy', 'Phillips')
# processing prof: ('Julia', 'Walsh')
# processing prof: ('Catherine Amanda', 'Schweizer')
# processing prof: ('Taiyaba', 'Husain')
# processing prof: ('Erin', 'Graff Zivin')
# processing prof: ('Kai', 'Chen')
# processing prof: ('Kaori', 'Ito')
# processing prof: ('Moh', 'El-Naggar')
# processing prof:processing prof: ('Chris', 'Powers')
#  ('Martin', 'Daniel')
# processing prof: ('Alexander', 'Alcaraz')
# processing prof: ('Samuel', 'Erman')
# processing prof: ('Therese', 'Wilbur')
# processing prof: ('Heidi', 'Khalil')
# processing prof: ('Robert', 'Shrum')
# processing prof: ('Frances', 'Kellar')
# processing prof: ('Nina', 'Kang')
# processing prof: ('Rong', 'Lu')
# processing prof: ('Jose', 'Sanchez')
# processing prof: ('Shawn', 'Roll')
# processing prof: ('Rachel', 'Moran')
# processing prof: ('Matthew', 'Harwood')
# processing prof: ('Sandra', 'Kazarian')
# processing prof: ('Darry', 'Sragow')
# processing prof: ('Kathleen', 'Apps')
# processing prof: ('Stephan', 'Ray')
# processing prof: ('Yomna', 'Elsayed')
# processing prof: ('Josh', 'Staub')
# processing prof: ('Lynn', 'Helding')
# processing prof: ('Jeffrey', 'Pearlman')
# processing prof: ('Amy', 'Merrill-Brugger')
# processing prof: ('Stefanie', 'Demetriades')
# processing prof: ('Josh', 'Kun')
# processing prof: ('Wolf', 'Gruner')
# processing prof: ('John', 'Roach')
# processing prof: ('Jennifer', 'Lott')
# processing prof: ('Isabelle', 'Brocas')
# processing prof: processing prof:('Bart', 'Kosko')
#  ('Victoria', 'Cortessis')
# processing prof: ('Matthew', 'Leveque')
# processing prof: ('Ann Marie', 'Yamada')
# processing prof: ('Dana', 'Goldman')
# processing prof: ('Bingen', 'Yang')
# processing prof: ('Judith', 'Shelton')
# processing prof: ('Anthony', 'Taranto')
# processing prof: ('Cecil', 'Jackson')
# processing prof: ('Sri', 'Narayan')
# processing prof: ('Jaime', 'Levy')
# processing prof: ('Patrick', 'Tabon')
# processing prof: ('Kim', 'Austin')
# processing prof: ('Cynthia', 'Mosqueda')
# processing prof: ('Tom', 'Chang')
# processing prof:processing prof: ('Roshan', 'Rajani')
#  ('Yvonne', 'Marchand')
# processing prof: ('Beverly', 'Younger')
# processing prof: ('Monique', 'Datta')
# processing prof: ('Ashok', 'Srinivasan')
# processing prof: ('Erin', 'Cuevas')
# processing prof: ('Kate', 'Burton')
# processing prof: ('Helaine', 'Lopes')
# processing prof: ('Eric', 'Shen')
# processing prof: ('Elizabeth', 'Fife')
# processing prof: ('Jason', 'Goldman')
# processing prof: ('Monika', 'Wiener')
# processing prof:processing prof: ('Jeffrey', 'Weaver') ('Alberto', 'Ortega')
#
# processing prof: ('Nina', 'Young')
# processing prof: ('Angelo', 'Pacifici')
# processing prof: ('Lina', 'Bahn')
# processing prof: ('Diego', 'Berdakin')
# processing prof: ('Mark', 'Schroeder')
# processing prof: ('Kimberly', 'Kelly Rolfe')
# processing prof: ('Richard', 'Antaramian')
# processing prof: ('Doug', 'Blush')
# processing prof: ('Michael', 'Palacios')
# processing prof: ('John', 'Murray')
# processing prof: ('Cynthia', 'Woll')
# processing prof: ('Tom', 'Jacobson')
# processing prof: ('Natalie', 'Kouyoumdjian')
# processing prof: ('Barry', 'Thompson')
# processing prof: ('Eric', 'Olesen')
# processing prof: ('James', 'Polk')
# processing prof: ('Jose', 'Reyes')
# processing prof: ('Margaret', 'Chidester')
# processing prof: ('Allison', 'Silverberg')
# processing prof: ('Samantha', 'Burton')
# processing prof: ('Chevon', 'Hicks')
# processing prof: ('Beth', 'Fisher')
# processing prof: ('Howard', 'Rodman')
# processing prof: ('Michael', 'Spead')
# processing prof: ('Vianey', 'Cabrera')
# processing prof: ('Leilei', 'Duan')
# processing prof: ('Charlie', 'Sarosy')
# processing prof: ('Bhargav', 'Oza')
# processing prof: ('Nayeon', 'Kim')
# processing prof: ('John', 'Groper')
# processing prof: ('Ron', 'Grover')
# processing prof: ('Shaddin', 'Dughmi')
# processing prof: ('Paul', 'Petschek')
# processing prof: ('Carl', 'Meyer')
# processing prof: ('Alexander', 'Benderskii')
# processing prof: ('Elisabeth', 'Raff')
# processing prof: ('Steve', 'Trovato')
# processing prof: ('Jennifer', 'Baker')
# processing prof: ('Yi-Hsien', 'Liu')
# processing prof: ('Qiang', 'Huang')
# processing prof: ('Ruben', 'Ochoa')
# processing prof: ('Jessica', 'Klein')
# processing prof: ('Jianming', 'Xie')
# processing prof: ('Andrew', 'Norman')
# processing prof: ('Brent', 'McMunn')
# processing prof: ('Andrew', 'Simpson')
# processing prof: ('Tameka', 'Brown')
# processing prof: ('Daniel', 'Schnur')
# processing prof: ('Linda', 'Brown')
# processing prof: ('Stephanie', 'Payne')
# processing prof: ('Karen', 'Anderson')
# processing prof: ('Mayumi', 'Ikeda')
# processing prof: ('Peter', 'Braun')
# processing prof: ('Emily', 'Zeamer')
# processing prof: ('Sharon', 'Carnicke')
# processing prof: ('Anita', 'Penkova')
# processing prof: ('Aro', 'Velmet')
# processing prof: ('Scott', 'Kanoski')
# processing prof: ('Jean-Michel', 'Maarek')
# processing prof: ('Nan', 'Jia')
# processing prof: ('Chunming', 'Wang')
# processing prof: ('Christopher', 'Harrer')
# processing prof: ('Jonathan', 'Sauder')
# processing prof: ('Roman', 'Melnik')
# processing prof: ('Bryant', 'Adibe')
# processing prof: ('Julie', 'Suh')
# processing prof: ('Lauren', 'Lamkin Grancio')
# processing prof: ('Susan', 'Helfter')
# processing prof: ('Daniel', 'Caputo')
# processing prof: ('Arthur', 'Chivichyan')
# processing prof: ('Philip', 'Seib')
# processing prof: ('Jill', 'Sohm')
# processing prof: ('Michael', 'Taylor')
# processing prof: ('Isaac K', 'Huang')
# processing prof: ('Andrew', 'Nealen')
# processing prof: ('Cara', 'Mullio')
# processing prof: ('Jennifer', 'Ramos')
# processing prof: ('Karen', 'Ephraim')
# processing prof: ('Kurt', 'Kwast')
# processing prof: ('Briana', 'Hinga')
# processing prof: ('Clark', 'Kromenaker')
# processing prof: ('Fariba', 'Ariaei')
# processing prof: ('Stephen', 'Finlay')
# processing prof: ('Amber', 'Foster')
# processing prof: ('Zen', 'Dochterman')
# processing prof: ('Michael', 'Lieber')
# processing prof: ('Douglas', 'Lynch')
# processing prof: ('Holly', 'Bridges')
# processing prof: ('Paolo', 'De Guzman')
# processing prof: ('Pablo', 'Frasconi')
# processing prof: ('Brendesha', 'Tynes')
# processing prof: ('Sean', 'Friar')
# processing prof: ('Kelly', 'Sanders')
# processing prof: ('William', 'Celis')
# processing prof: ('Chris', 'Kyriakakis')
# processing prof: ('Cristian', 'Grases')
# processing prof: ('Gayle', 'Fiedler-Vierma')
# processing prof: ('Nicholas', 'Smith')
# processing prof: ('Edward', 'Seo')
# processing prof: ('Ashley', 'Bennett')
# processing prof: ('Clarisa', 'Martinez')
# processing prof: ('Lindsay', 'Stidham')
# processing prof: ('David', 'MacMillan')
# processing prof: ('Corinne', 'Feldman')
# processing prof: ('Karen', 'Liebowitz')
# processing prof: ('Jacquelyn', 'Bsharah')
# processing prof: ('Julie', 'Bates')
# processing prof: ('Jordan', 'Halsey')
# processing prof:processing prof: ('Laurence', 'Wong')
#  ('Michael', 'Cameron')
# processing prof: ('Christian', 'Phillips')
# processing prof: ('E. Todd', 'Schroeder')
# processing prof: ('Michael', 'Rank')
# processing prof: ('Karra', 'Bikson')
# processing prof: ('Matthew', 'Manos')
# processing prof: ('Stanley', 'Rosen')
# processing prof: ('David', 'Treuer')
# processing prof: ('Jolanta', 'Aritz')
# processing prof: ('April', 'Davidauskis')
# processing prof: ('Andrew', 'Campbell')
# processing prof: ('Scott', 'Faris')
# processing prof: ('Angela', 'Iyanobor')
# processing prof: ('Michael', 'Neely')
# processing prof: ('Satwindar', 'Sadhal')
# processing prof: ('Shinyi', 'Wu')
# processing prof: ('Xuejing', 'Sun')
# processing prof: ('Avelardo', 'Valdez')
# processing prof: ('Jacob', 'Soll')
# processing prof: ('Steve', 'Hsu')
# processing prof: ('Seth', 'Stodder')
# processing prof: ('Scott', 'Wiltermuth')
# processing prof: ('Marianne', 'Krawczyk')
# processing prof: ('Kim', 'Coleman')
# processing prof: ('Dana', 'Johnson')
# processing prof: ('Steven', 'Westberg')
# processing prof: ('Laura', 'Davis')
# processing prof: ('Tessa', 'Milman')
# processing prof: ('Elizabeth', 'Whitfield')
# processing prof: ('Traysi', 'Chong')
# processing prof: ('Karlton', 'Wong')
# processing prof: ('Xochitl', 'Ruiz')
# processing prof: processing prof: ('Jennifer', 'De La Fuente')
# ('Andrei', 'Belgrader')
# processing prof: ('Georgia', 'Jeffries')
# processing prof: ('Hye Min', 'Kim')
# processing prof: ('Roderick', 'Castro')
# processing prof: ('Bhaskar', 'Krishnamachari')
# processing prof: ('Darek', 'Oleszkiewicz')
# processing prof: ('Farida', 'Habeeb')
# processing prof: ('Silvia', 'Rigon')
# processing prof:processing prof: ('Elaine', 'Zhong')
#  ('Ashley', 'Uyeshiro')
# processing prof: ('Jennifer', 'Treweek')
# processing prof: ('Jennifer', 'Unger')
# processing prof: ('Mayanna', 'Framroze')
# processing prof: ('Thomas', 'Hooten')
# processing prof: ('Dan', 'Simon')
# processing prof: ('Wayne', 'Federman')
# processing prof: ('Catherine', 'Pham')
# processing prof: ('Hyungjin', 'Eoh')
# processing prof: ('Marcelline', 'Babicz')
# processing prof: ('Fedor', 'Malikov')
# processing prof: ('George', 'Tolomiczenko')
# processing prof: ('Kirby', 'Farah')
# processing prof: ('Raymundo', 'Zacarias')
# processing prof: ('Ivan', 'Nikkhoo')
# processing prof: ('Lucia', 'Aparicio')
# processing prof: ('James', 'Deiner')
# processing prof: ('Eric', 'Canny')
# processing prof: ('Gregory', 'Pleasants')
# processing prof: ('David', 'Macmillan')
# processing prof: ('Lavonna', 'Lewis')
# processing prof: ('John', 'Strauss')
# processing prof: ('Gregory', 'Chesley')
# processing prof: ('Allison', 'Chu')
# processing prof: ('Thomas', 'Mueller')
# processing prof: ('Hiroshi', 'Ochiumi')
# processing prof: ('Suh-Pyng', 'Ku')
# processing prof: ('Kevin', 'Lohenry')
# processing prof: ('Larry', 'Sheffield')
# processing prof: ('Audrey', 'Boros')
# processing prof: ('Bing', 'Wang')
# processing prof: ('Ben', 'Hong')
# processing prof: ('Mahvash', 'Navazesh')
# processing prof: ('Su Jin', 'Lee')
# processing prof: ('Samantha', 'Malisos')
# processing prof: ('Kristen', 'Jaconi')
# processing prof: ('Dain', 'Blanton')
# processing prof: ('Sarah (Essy)', 'Stone')
# processing prof: ('Pamela', 'Minet-Lucid')
# processing prof: ('Lina', 'Nie')
# processing prof: ('Ian', 'Fusselman')
# processing prof: ('Terrence', 'Town')
# processing prof: ('Armand', 'Tanguay')
# processing prof: ('Esther', 'Margulies')
# processing prof: ('Kian', 'Kar')
# processing prof: ('Ruth Ann', 'Supranovich')
# processing prof: ('Philip', 'Ramuno')
# processing prof: ('Tyler', 'Hiebert')
# processing prof: ('Jessica', 'Sharzer')
# processing prof: ('Sean', 'Flanagan')
# processing prof: ('Yang', 'Chai')
# processing prof: ('Carolina', 'Garcia')
# processing prof: ('Mark', 'Griffiths')
# processing prof: ('Mary', 'Traester')
# processing prof: ('Gerald', 'Giaquinta')
# processing prof: ('Regalado', 'Valerio')
# processing prof: ('Wanda', 'Quezada')
# processing prof: ('Lessa', 'Grunenfelder')
# processing prof: ('Linda', 'Sanner')
# processing prof: ('Roberto', 'Blain')
# processing prof: ('Annette', 'Kim')
# processing prof: ('Mary', 'Stevens')
# processing prof: ('Jonathan', 'Aronson')
# processing prof: ('Daniel', 'Richter')
# processing prof: ('Jorge', 'Leal')
# processing prof: ('Lourdes', 'Avelar Portillo')
# processing prof: ('Stacy', 'Story')
# processing prof: ('Heather', 'Culbertson')
# processing prof: ('Christoph', 'Haselwandter')
# processing prof: ('Amy', 'Fuller')
# processing prof: ('Carolin', 'Fleischmann')
# processing prof: ('Michael', 'Andersen')
# processing prof: ('Debra', 'Danner')
# processing prof: ('Song-Hee', 'Kim')
# processing prof: ('Dan', 'Shaner')
# processing prof: ('Amy', 'Cannon')
# processing prof: ('Susie', 'Park')
# processing prof: ('Martin', 'Villares Ogaza')
# processing prof: ('Daniel', 'Lee')
# processing prof: ('Angela', 'Hasan')
# processing prof: ('Lorraine', 'Turcotte')
# processing prof: ('Sergio', 'Arguello')
# processing prof: ('Eric', 'Roth')
# processing prof: ('Jenny', 'Lin')
# processing prof: ('Richard', 'Coles')
# processing prof: ('Rebecca', 'Lundeen')
# processing prof: ('Tom', 'Buderwitz')
# processing prof: ('Sami', 'Masri')
# processing prof: ('Velina', 'Hasu Houston')
# processing prof: ('Sandra', 'Batista')
# processing prof: ('Daniel', 'Khorshad')
# processing prof: ('Jonathan', 'Libgober')
# processing prof: ('Nicole', 'MacCalla')
# processing prof: ('Chengyu', 'Liang')
# processing prof: ('Erica', 'McCall')
# processing prof: ('Oliver', 'Mayer')
# processing prof: ('Steven', 'Mednick')
# processing prof: ('Natalie', 'Meyers')
# processing prof: ('Michael', 'Powers')
# processing prof: ('Sandra', 'Ross')
# processing prof: ('Douglas', 'Noble')
# processing prof: ('Mitzi', "D'Aquila")
# processing prof: ('Robert', 'Schiller')
# processing prof: ('Robertas', 'Gabrys')
# processing prof: ('Julie', 'Schreiner')
# processing prof: ('Richard', 'Mc Laughlin')
# processing prof: ('Timothy', 'Kobza')
# processing prof: ('Janice', 'Tramel')
# processing prof: ('Juan', 'Saavedra')
# processing prof: ('Doni', 'Whitsett')
# processing prof: ('Dmitri', 'Williams')
# processing prof: ('Kevin', 'Kane')
# processing prof: ('Veli N', 'Yashin')
# processing prof: ('Scotty', 'Galloway')
# processing prof: ('Dawn', 'Bray')
# processing prof: ('Piedad', 'Suarez')
# processing prof:processing prof: ('Kelly', 'Rawlings')
#  ('Parmer', 'Fuller')
# processing prof: ('Kalim', 'Rayburn')
# processing prof: ('Jessica', 'Maxfield')
# processing prof: ('John', 'Jones')
# processing prof: ('Matthew', 'Lazari')
# processing prof: ('Emily', 'Blodget')
# processing prof: ('Nam', 'Joe')
# processing prof: ('Joanne', 'Rietta')
# processing prof: ('Jeffrey', 'Kahane')
# processing prof: ('Scott', 'Lenet')
# processing prof: ('Jim', 'Huntley')
# processing prof: ('Anthony', 'Boyle')
# processing prof: ('Pragna', 'Patel')
# processing prof: ('Dan', 'Mazmanian')
# processing prof: ('Neelesh', 'Tiruviluamala')
# processing prof: ('Paul', 'Moorman')
# processing prof: ('Paulo', 'Branicio')
# processing prof: ('Francesca Romana', 'Puggelli')
# processing prof: ('Rosa', 'Wilkins-Langie')
# processing prof: ('Phuu', 'Han')
# processing prof: ('Carrie', 'Guss')
# processing prof: ('Ratika', 'Narag')
# processing prof: ('Vincent', 'Womack')
# processing prof: ('Jodie', 'Gates')
# processing prof: ('John', 'Duggan')
# processing prof: ('Salman', 'Avestimehr')
# processing prof: ('Robert', 'Waller')
# processing prof: ('Jian', 'Xu')
# processing prof: ('Brian', "O'Connell")
# processing prof: ('Suvrajeet', 'Sen')
# processing prof: ('Robert', 'Webster')
# processing prof: ('Roy', 'Quintero')
# processing prof: ('Gregory', 'Treverton')
# processing prof: ('W', 'Kast')
# processing prof: ('Robert', 'Sacker')
# processing prof: ('David', 'Tomkins')
# processing prof: ('Patricia', 'Taylor')
# processing prof: ('Mick', 'Swartz')processing prof: ('Francesca', 'Mariani')
#
# processing prof: ('Alice', 'Gambrell')
# processing prof: ('Jacob', 'Nebel')
# processing prof: ('Brijesh', 'Pinto')
# processing prof: ('Valery', 'Fokin')
# processing prof: ('Patricia', 'George')
# processing prof: ('Jill', 'Davis')
# processing prof: ('Craig', 'Lareau')
# processing prof: ('Yuri', 'Jang')
# processing prof: ('Andrew', 'Chater')
# processing prof: ('Dennis', 'Nemeschansky')
# processing prof: ('Shafiqa', 'Ahmadi')
# processing prof: ('Eric', 'Goldberg')
# processing prof: ('Amanda', 'Ingalls')
# processing prof: ('Kirstin', 'Eggers')
# processing prof: ('Emily', 'Ochi')
# processing prof: ('Danielle', 'Zammit')
# processing prof: ('Miller', 'Fong')
# processing prof: ('Marisa', 'Mandler')
# processing prof: ('Jay', 'Bartroff')
# processing prof: ('Allissa', 'Richardson')
# processing prof: ('Hannah', 'Burnham')
# processing prof: ('Nathalie', 'Joseph')
# processing prof: ('Pablo', 'Barbera-Aranguena')
# processing prof: ('Sarah', 'Kessler')
# processing prof: ('Fred', 'Cook')
# processing prof: ('Emily', 'Artiano')
# processing prof: ('Martine', 'Culty')
# processing prof: ('Susan', 'Green')
# processing prof: ('Edward', 'Maby')
# processing prof: ('Thomas', 'McManus')
# processing prof: ('David', 'Kelley')
# processing prof: ('David', 'Bialock')
# processing prof: ('John', 'Carlsson')
# processing prof: ('Julia', 'Plotts')
# processing prof: ('Theodore', 'Braun')
# processing prof: ('Ronald', 'Mitchell')
# processing prof: ('Gene', 'Bickers')
# processing prof: ('Sven', 'Koenig')
# processing prof: ('Albert', 'Herrera')
# processing prof: ('Annelise', 'Bamberg')
# processing prof: ('Cheryl', 'Coleman')
# processing prof: ('Lilit', 'Keshishyan')
# processing prof: ('Reyes', 'Enciso')
# processing prof: ('Bruce', 'McCormick')
# processing prof: ('Jennifer', 'Beatty')
# processing prof: ('Remo', 'Rohs')
# processing prof: ('Mohammed', 'Alyakoob')
# processing prof: ('Carl', 'Schnurr')
# processing prof: ('Janet', 'Batchler')
# processing prof: ('Michael Dennis', 'Smith')
# processing prof: ('Philip', 'Dalton')processing prof: ('Karen', 'Dreyfus')
#
# processing prof: ('Annie', 'Chen')
# processing prof: ('Sarah', 'King')
# processing prof: ('Sharon', "O'Neill")
# processing prof:processing prof: ('Daniel', 'Mcauliffe')
#  ('Trina', 'Hoefling')
# processing prof: ('Joe', 'Qin')
# processing prof: ('George', 'Salem')
# processing prof: ('Sarah', 'Bottjer')
# processing prof: ('Yves', 'Declerck')
# processing prof: ('Stephanie', 'Sabo')
# processing prof: ('Tianshu', 'Sun')
# processing prof: ('Marcia', 'Wilson')
# processing prof: ('Teresa', 'Norris')
# processing prof: ('Mathew', 'Curtis')
# processing prof: ('Trisha', 'Tucker')
# processing prof: ('Shalini', 'Gupta')
# processing prof: ('Lan', 'Luo')
# processing prof: ('Melissa', 'Batchelor Warnke')
# processing prof: ('Michelle Silver', 'Lee')
# processing prof: ('Julie', 'Zissimopoulos')
# processing prof: ('Assad', 'Oberai')
# processing prof: ('F J', 'Pratt')
# processing prof: ('David', 'Weber')
# processing prof: ('Robin', 'Jeshion')
# processing prof: ('Geza', 'Bottlik')
# processing prof: ('Katherine', 'Guevara')
# processing prof: ('James', 'Fortney')
# processing prof: ('Jeanne', 'Mckean')
# processing prof: ('Shieva', 'Kleinschmidt')
# processing prof: ('Brooklyne', 'Gipson')
# processing prof: ('Erin', 'Moore')
# processing prof: ('Fred', 'Weissman')
# processing prof: ('Kristin', 'Nxumalo')
# processing prof: ('Richard', 'Vawter')
# processing prof: ('Carly', 'Roman')
# processing prof: ('Jarvis', 'Turner')
# processing prof: ('Roksana', 'Karim')
# processing prof: ('Petros', 'Ioannou')
# processing prof: ('Rena', 'Heinrich')
# processing prof: ('Alan', 'Green')
# processing prof: ('Charles', 'Gutierrez')
# processing prof: ('Sarah', 'Portnoy')
# processing prof: ('Adrian', 'Donato')
# processing prof: ('Stan', 'Louie')
# processing prof: ('Jenny', 'Yu')
# processing prof: ('Jean', 'Robison')
# processing prof: ('Kathleen', 'West')
# processing prof: ('Kimberly', 'Lenington')
# processing prof: ('Fayez', 'Hammad')
# processing prof: ('Adam', 'Silverman')
# processing prof: ('Michael', 'Tramutola')
# processing prof: ('Dorothy', 'Nieto Manzer')
# processing prof: ('Tatiana', 'Akishina')
# processing prof: ('Nicole', 'Darling')
# processing prof: ('Timothy', 'Turnbull')
# processing prof: ('Wei', 'Wu')
# processing prof: ('Barrett', 'Koster')
# processing prof: ('Darrell', 'Mavis')
# processing prof: ('Olivia C', 'Harrison')
# processing prof: ('Anastassia', 'Tzoytzoyrakos')
# processing prof: ('Guillaume', 'Dreyer')
# processing prof: ('Mike', 'Paranal')
# processing prof: ('Andre', 'Ouellette')
# processing prof: ('Mark', 'Hanson')
# processing prof: ('Ying', 'Wang')
# processing prof: ('Arman', 'Nadershahi')
# processing prof: ('Christopher', 'Jones')
# processing prof: ('Michael', 'Chasalow')
# processing prof: ('Nazli', 'Senyuva')
# processing prof: ('Marc', 'Vermulst')
# processing prof: ('Adriana', 'Lacy')
# processing prof: processing prof: ('Tatiana', 'Melguizo')
# ('Meiying', 'Li')
# processing prof: ('Angela', 'Kim')
# processing prof: ('Aluizio', 'Prata')
# processing prof: ('Samantha', 'Ikehara')
# processing prof: ('Rita', 'Burke')
# processing prof: ('John', 'Furay')
# processing prof: ('Sharon', 'Merle-Lieberman')
# processing prof: ('Enrique', 'Martinez Celaya')
# processing prof: ('Min Young', 'Mun')
# processing prof: ('Barnet', 'Kellman')
# processing prof: ('Laura', 'Riley')
# processing prof: ('Frank', 'Corsetti')
# processing prof: ('Matthew', 'Lait')
# processing prof: ('Seon', 'Kim')
# processing prof: ('Myka', 'Winder')
# processing prof: processing prof: ('Rick', 'Berg')
# ('Rami', 'Yanni')
# processing prof: ('Christine', 'Beckman')
# processing prof: ('Therese', 'Curtin')
# processing prof: ('Steven', 'Sussman')
# processing prof: ('Anne', 'Lagatta')
# processing prof: ('Stefanos', 'Nikolaidis')
# processing prof: ('David', 'Howard')
# processing prof: ('Wensheng', 'Wu')
# processing prof: ('Amy', 'Reed')
# processing prof: ('Cassandra', 'Fatouros')
# processing prof: ('Christelle', 'Fischer-Bovet')
# processing prof: ('Lisa', 'Luna')
# processing prof: ('Raymond', 'Kim')
# processing prof: ('Tin-Yu', 'Tseng')
# processing prof: ('Frank', 'Chang')
# processing prof: ('Douglas', 'Burke')
# processing prof: ('Eric', 'Webb')
# processing prof: ('Lance', 'Winkel')
# processing prof: ('Carol', 'Geffner')
# processing prof: ('Cesar', 'Armendariz')
# processing prof: ('Rob', 'Schoeben')
# processing prof: ('Natalie', 'Brunell')
# processing prof: ('Jon', 'Kroll')
# processing prof: ('Catherine', 'Neubauer')
# processing prof: ('Nam', 'Cho')
# processing prof: ('Paula', 'Patnoe-Woodley')
# processing prof: ('Jennifer', 'Parga')
# processing prof: ('Rose', 'Layton')
# processing prof: ('Brian', 'Bernards')
# processing prof: ('Leonard', 'Adleman')
# processing prof: ('Anna', 'Arabyan')
# processing prof: ('Alexandra', 'Wilcox')
# processing prof: ('Ronald', 'Christie')
# processing prof: ('Brad', 'Cracchiola')
# processing prof: ('Eliz', 'Sanasarian')
# processing prof: processing prof: ('Scott', 'Easley')
# ('Jason', 'Harper')
# processing prof: ('Aaron', 'Siegel')
# processing prof: ('Gourab', 'Mukherjee')
# processing prof: ('Mary', 'Harris')
# processing prof: ('Mary', 'Posatko')
# processing prof: ('Constantine', 'Sideris')
# processing prof: ('R Paul', 'Maiden')
# processing prof: ('Ken', 'Wong')
# processing prof: ('John', 'Sideris')
# processing prof: ('Enrique', 'Cadenas')
# processing prof: ('Inga', 'Maslova')
# processing prof: ('Valery', 'Augustin')
# processing prof: ('Lisa', 'Seidman')
# processing prof: ('Melanie', 'Calvert')
# processing prof: ('Gary', 'Shaffer')
# processing prof:processing prof: ('Michael', 'Bodie')
#  ('Sergio', 'Sanudo-Wilhelmy')
# processing prof: ('Raquel', 'Sanchez')
# processing prof: ('Kimberly', 'Dodds')
# processing prof: ('Ellen', 'Wayland-Smith')
# processing prof: ('Geoff', 'Boeing')
# processing prof: ('Jonathan', 'Diaz')
# processing prof: ('Jim', 'Moore')
# processing prof: ('Reginald', 'Tucker-Seeley')
# processing prof:processing prof: ('Renee', 'Campbell')
#  ('Sze-Chuan', 'Suen')
# processing prof: ('Jeff', 'Nugent')
# processing prof: ('Jae', 'Jung')
# processing prof:processing prof: ('Anthony', 'Anderson')
#  ('Eric', 'Briggs')
# processing prof: ('Lars', 'Harding')
# processing prof: ('Abby', 'Fifer Mandell')
# processing prof: ('Jessica', 'Manzone')
# processing prof: ('Burghardt', 'Tenderich')
# processing prof: ('Dowell', 'Myers')
# processing prof: ('Bob', 'Mintzer')
# processing prof: ('James', 'Leonetti')
# processing prof: ('Shaun', 'Harper')
# processing prof: ('Kerry', 'Doyle')
# processing prof: ('Elahe', 'Nezami')
# processing prof: ('Douglas', 'Manuel II')
# processing prof:processing prof: ('Peter', 'Qin')
#  ('Brian', 'Head')
# processing prof: ('Babak', 'Boloury-Azad')
# processing prof: ('Nadia', 'Sellami')
# processing prof: ('Larry', 'Goldstein')
# processing prof: ('Jincai', 'Chang')
# processing prof: ('Fengzhu', 'Sun')
# processing prof: ('Penelope', 'Jones')
# processing prof: ('Lucio', 'Comai')
# processing prof: ('Mike', 'Foster')
# processing prof: ('Kate', 'Powers')
# processing prof: ('Lisa', 'Pecot-Hebert')
# processing prof: ('Jim', 'Clements')
# processing prof: ('Seth', 'Kurzban')
# processing prof: ('Amy', 'Hodge')
# processing prof: ('Darline', 'Robles')
# processing prof: ('Stacy', 'Geck')
# processing prof: ('John', 'Brennan')
# processing prof: ('Ferol', 'Mennen')
# processing prof: ('Howard', 'Williamson')
# processing prof: ('Cauligi', 'Raghavendra')
# processing prof: ('Jeffrey', 'Fields')
# processing prof: ('Debra', 'Waters-Roman')
# processing prof: ('Camille', 'Thornton-Alson')
# processing prof: ('Joel', 'Bryant')
# processing prof: ('Tina', 'Fietsam')
# processing prof: ('Joseph', 'Lim')
# processing prof: ('Richard', 'Lemarchand')
# processing prof: ('Paulina', 'Oliva')
# processing prof: ('Mahdi', 'Soltanolkotabi')
# processing prof: ('Bennett', 'Lee')
# processing prof: ('Jovi', 'Schnell')
# processing prof: ('Glenn', 'Clark')
# processing prof: ('Martzi', 'Campos')
# processing prof:processing prof: ('Jungeun Olivia', 'Lee')
#  ('Stewart', 'Gordon')
# processing prof: ('Doug', 'Hammond')
# processing prof: ('Tyson', 'Roberts')
# processing prof: ('Jean', 'Lantz')
# processing prof: ('Claire', 'Abrams')
# processing prof: ('Amy', 'Watson')
# processing prof: ('Mary', 'Gallagher')
# processing prof: ('Deborah', 'Glynn')
# processing prof: ('John', 'Eatwell')
# processing prof: ('Julie', 'Van Dam')
# processing prof: ('Colin', 'Leslie')
# processing prof: ('Vittorio', 'Bassi')
# processing prof: ('Raffi', 'Svadjian')
# processing prof: ('Richard', 'Smith')
# processing prof: ('David', 'Linton')
# processing prof: ('Anna', 'Farzindar')
# processing prof: ('Alli', 'Coritz')
# processing prof: ('Saleemah', 'Knight')
# processing prof: ('Arthur', 'Auerbach')processing prof:
#  ('Paul', 'Orfalea')
# processing prof: ('Rebecca', 'Choi')
# processing prof: ('Sherry', 'Zaks')
# processing prof: ('Diane', 'Winston')
# processing prof: ('Caryn', 'Angelson')
# processing prof: ('Paula', 'Cizmar')
# processing prof: ('Mellissa', 'Withers')
# processing prof: ('George', 'Braunegg')
# processing prof: ('Maia', 'Hoskin')
# processing prof: ('Todd', 'Robinson')
# processing prof: ('Daniel', 'Park')
# processing prof: ('Bora', 'Gencturk')
# processing prof: ('Gary', 'Cohn')
# processing prof: ('Matthew', 'Mecklenburg')
# processing prof: ('Gary', 'Painter')
# processing prof: ('Diane', 'Da Silva')
# processing prof: ('Ann', 'Klenk')
# processing prof: ('Patricia', 'Grabarek')
# processing prof: ('Alison', 'Muraszewski')
# processing prof: ('Michael', 'Du Plessis')
# processing prof: ('Kiranjeet', 'Dhillon')
# processing prof: ('Drew', 'Casper')
# processing prof: ('Naomi', 'Warren')
# processing prof: ('Wen', 'Sun')
# processing prof: ('Kaali', 'Dass')
# processing prof: ('Jinhee', 'Choung')
# processing prof: ('Carlos', 'Adame')
# processing prof: ('Paul', 'Dapkus')
# processing prof: ('Nicolas', 'Moure')
# processing prof: ('Sergey', 'Nuzhdin')
# processing prof: ('Kim', 'Finney')
# processing prof: ('Erik', 'Hovenkamp')
# processing prof: ('Alexandra', 'Graddy-Reed')
# processing prof: ('Nicole', 'Richards')
# processing prof: ('Greta', 'Panova')
# processing prof: ('Luciano', 'Nocera')
# processing prof: ('Thomas', 'Booth')
# processing prof: ('Kyle', 'Konis')
# processing prof: ('Santosh', 'Shahi')
# processing prof: ('Annalisa', 'Enrile')
# processing prof: ('Mark', 'Thompson')
# processing prof: ('Randy', 'Lake')
# processing prof: ('Dan', 'Lainer-Vos')
# processing prof: ('John', 'Heilman')
# processing prof: ('Ben', 'Poston')
# processing prof: ('Francisco', 'Roman')
# processing prof: ('Glenn', 'Melnick')
# processing prof: ('Kiki', 'Benzon')
# processing prof: ('Terri', 'Thomas')
# processing prof:processing prof: ('Daniel', 'Carlin') ('Ann', 'Owens')
#
# processing prof: ('Anamara', 'Ritt')
# processing prof: ('Luciana', 'Varkulja')
# processing prof: ('Kathleen', 'Schorsch')
# processing prof: ('Deniz', 'Rudin')
# processing prof: ('Jonathan', 'Speier')
# processing prof: ('Gage', 'Crump')
# processing prof: ('Eun', 'Kim')
# processing prof: ('Robert', 'Smythe')
# processing prof: ('John', 'Tower')
# processing prof: processing prof:('Susanne', 'Foulk')
#  ('Ben', 'Reichardt')
# processing prof: ('David', 'Goetsch')
# processing prof: ('Terri', 'Austin')
# processing prof: ('Tomas', 'Duran')
# processing prof: ('Oscar', 'Gallardo')
# processing prof: ('Hyo', 'Kang')
# processing prof: ('Uzma', 'Burki')
# processing prof: ('Timothy', 'Stanton')
# processing prof: ('Vinay', 'Goyal')
# processing prof: ('Lindsay', "O'Neill")
# processing prof: ('Sayd', 'Randle')
# processing prof: ('Roseann', 'Mulligan')
# processing prof: ('Casey', 'Moon')
# processing prof: ('Yen-Hsiang', 'Nieh')
# processing prof: ('Morten', 'Bay')
# processing prof: ('Sanjay', 'Madhav')
# processing prof: ('Leigh', 'Tost')
# processing prof: ('Mary Anna', 'Noveck')
# processing prof: ('Niema', 'Pahlevan')
# processing prof: ('Tomoaki', 'Hayashi')
# processing prof: ('Jason', 'Doctor')
# processing prof: ('Josh', 'Neman-Ebrahim')
# processing prof: ('Karen', 'Lincoln')
# processing prof: ('Nick', 'Vyas')
# processing prof: ('Katherine', 'Shing')
# processing prof: ('Chrislynn', 'Freed')
# processing prof: ('Alan', 'Pasqua')
# processing prof: ('Josh', 'Lockman')
# processing prof: ('Clair', 'Mellenthin')
# processing prof: ('Tanya', 'Ryutov')
# processing prof: ('Kristy', 'Morrell')
# processing prof: ('Derisa', 'Grant')
# processing prof: ('John', 'Chang')
# processing prof: ('Christina', 'Webb')
# processing prof: ('Lynn', 'Dodd')
# processing prof: ('Denis', 'Evseenko')
# processing prof: ('Leslie', 'Kapner')
# processing prof: ('Francis', 'Pereira')
# processing prof: ('Luanne', 'Rohrbach')
# processing prof: ('Wei-Min', 'Shen')
# processing prof: ('Ali', 'Zadeh')
# processing prof: ('Robert', 'Minnichelli')
# processing prof: ('Gerardo', 'Munck')
# processing prof: ('Sathyanaraya', 'Raghavachary')
# processing prof: ('Charles', 'Radovich')
# processing prof: ('Kay', 'Jann')
# processing prof: ('Dianne', 'Farrington')
# processing prof: ('Yan', 'Jin')
# processing prof: ('Sofia', 'Reddy')
# processing prof: ('Kim', 'Gross')
# processing prof: ('Nathan', 'Cherry')
# processing prof: ('Keith', 'Allen-Niesen')
# processing prof: ('Jeffrey', 'Fellenzer')
# processing prof: ('Christopher', 'Magriney')
# processing prof: ('Scott', 'Paterson')
# processing prof: ('Frank', 'Manis')
# processing prof: ('Amy', "O'Neal")
# processing prof: ('Qi', 'Feng')
# processing prof: ('Karrie', 'Kingsley')
# processing prof: ('Natascha', 'Grundmann')
# processing prof: ('Carlos', 'Sanchez')
# processing prof: ('William', 'Tobiska')
# processing prof: ('Michael', 'Parks')
# processing prof: ('David', 'Ginsburg')
# processing prof: ('Sule', 'Guney')
# processing prof: ('Grayson', 'Jaggers')
# processing prof: ('Ravneet', 'Tiwana')
# processing prof: ('Carlos Antonio', 'Delgado')
# processing prof: ('Cristina', 'Zavaleta')
# processing prof: ('Paul', 'Wong')
# processing prof: ('Megan', 'Herrold')
# processing prof: ('Jennifer', 'Krogh')
# processing prof: ('Colleen', 'McQuillen')
# processing prof: ('Susan C', 'Wright')
# processing prof: ('Joel', 'Timm')
# processing prof: ('Cary', 'Frydman')
# processing prof: ('Sarah', 'Bonner')
# processing prof: ('Michael', 'Faia')
# processing prof: ('Geoffrey', 'Cowan')
# processing prof: ('Sivaramakrishnan', 'Siddarth')
# processing prof: ('Miao', 'Zhang')
# processing prof: ('Cynthia', 'Martinez')
# processing prof: ('Kendra', 'Atkin')
# processing prof: ('Robin', 'Elledge')
# processing prof: ('John K', 'Ugoretz')
# processing prof: ('Takako', 'Tajima')
# processing prof: ('Aimei', 'Yang')
# processing prof: ('Richard', 'Dang')
# processing prof: ('Darby', 'Walters')
# processing prof: ('Ruben', 'Davila')
# processing prof: ('Courtney', 'Conley')
# processing prof: ('Canan', 'Ipek')
# processing prof: ('Phyllis', 'Pollack')
# processing prof: ('Mandong', 'Liu')
# processing prof: ('Geert', 'Ridder')
# processing prof: ('William', 'Leach')
# processing prof: ('Jennifer', 'Swift')
# processing prof: ('Amy', 'Parish')
# processing prof: ('Ellen', 'Oliveira')
# processing prof: ('Judy', 'Lewis')
# processing prof: ('Victor', 'Adamchik')
# processing prof: ('Andrew', 'Gracey')
# processing prof: ('Stephen', 'Moyer')
# processing prof: ('Ken', 'Cazan')
# processing prof: ('Josephine', 'Fava Hochuli')
# processing prof: ('Steven', 'Martin')
# processing prof: ('Sarah', 'Caliboso Soto')
# processing prof: ('Reuven', 'Firestone')
# processing prof: ('Lisa', 'Vest')
# processing prof: ('Sozan', 'Wali')
# processing prof: ('Bruce', 'Block')
# processing prof: ('Qifa', 'Zhou')
# processing prof: ('Jamie', 'Fudacz')
# processing prof: ('Judith', 'Franco')
# processing prof: ('Aaron', 'Mazel-Gee')
# processing prof: ('Lisa', 'Goldstone')
# processing prof: ('Amir', 'Goldkorn')
# processing prof: ('Jeb', 'Barnes')
# processing prof: ('Sara', 'Semborski')
# processing prof: ('Farzana', 'Choudhury')
# processing prof: ('Gayla', 'Margolin')
# processing prof: ('Leah', 'Hanzlicek')
# processing prof: ('Dion', 'Jackson')
# processing prof: ('Vincent', 'Robert')
# processing prof: processing prof: ('Richard', 'Sloan')
# ('Moussa', 'Diop')
# processing prof: ('Trina', 'Gregory')
# processing prof: ('Yvette', 'Amirian')
# processing prof: ('Danielle', 'Luchetta')
# processing prof: ('Patricia', 'Castillo')
# processing prof: ('Saeed', 'Mohasseb')
# processing prof: ('Andrew', 'Guzman')
# processing prof: ('Candice', 'Whitely')
# processing prof: ('Nicholas', 'Merkin')
# processing prof: ('Kevin', 'Lyman')
# processing prof: ('Christopher', 'Gopal')
# processing prof: ('Kathleen', 'Woodruff')
# processing prof: ('Karl', 'Gnass')
# processing prof: ('Laura', 'Cardinal')
# processing prof: ('Scott', 'Fisher')
# processing prof: ('Stephanie', 'Schwartz')
# processing prof: ('Samuel', 'Kim')
# processing prof: ('Mary', 'Ho')
# processing prof: ('Andreas', 'Molisch')
# processing prof: ('Rebecca', 'Weintraub')
# processing prof: ('Jae', 'Deal')
# processing prof: ('Zhiming', 'Xu')
# processing prof: ('Ariela', 'Gross')
# processing prof:processing prof:  ('Xinhui', 'Yang')
# ('Gregg', 'Brandow')
# processing prof: ('Jesse', 'Yen')
# processing prof: ('Sheila', 'Banuelos')
# processing prof: ('Young-Kwon', 'Hong')
# processing prof: ('Monica', 'Morlacco')
# processing prof: ('Trudi', 'Ferguson')
# processing prof: ('Geoffrey', 'Spedding')
# processing prof: ('Marylynne', 'Boorn')
# processing prof: ('Mary', 'Byram Washburn')
# processing prof:processing prof: ('Margaret', 'Rosenthal')
#  ('Nathanael', 'Fast')
# processing prof: ('Vince', 'Gonzales')
# processing prof: ('Marc', 'Choueiti')
# processing prof: ('Michael', 'Escalante')
# processing prof: ('Steven', 'Lopez')
# processing prof: ('Isabel', 'Morales')
# processing prof: ('Reka', 'Clausen')
# processing prof: ('Mina', 'Chow')
# processing prof: ('Cosimo', 'Arnesano')
# processing prof: ('Hector', 'Amaya')
# processing prof: ('Timothy', 'Fox')
# processing prof: ('Stacy', 'Kratz')
# processing prof: ('David', 'Erceg')
# processing prof: ('Abigail', 'Palmer')
# processing prof: ('Wichada', 'La Motte-Kerr')
# processing prof:processing prof: ('Nicole', 'Johnson')
#  ('Judith', 'Farmer')
# processing prof: ('Rand', 'Wilcox')
# processing prof: ('Wendy', 'MacK')
# processing prof: ('Irving', 'Biederman')
# processing prof: ('Michael', 'Hahn')
# processing prof: ('Michael', 'Fiorica')
# processing prof: ('Nina', 'Bradley')
# processing prof: ('Jane', 'Junn')
# processing prof: ('Sourena', 'Haj-Mohamadi')
# processing prof: ('Mark', 'Marino')
# processing prof: ('Joseph', 'Pereira')
# processing prof: ('Ralph', 'Wedgwood')
# processing prof: ('Trudy', 'Green')
# processing prof: ('William', 'Resh')
# processing prof: ('Elizabeth', 'Falletta')
# processing prof: ('Samuel', 'Mistrano')
# processing prof: ('Arthur', 'Stone')
# processing prof: ('Tyler', 'Quick')
# processing prof: ('Paat', 'Rusmevichientong')
# processing prof: ('Marco', 'Papa')processing prof:
#  ('Brandon', 'Jeffords')
# processing prof: ('Ama', 'Saran')
# processing prof: ('Dorothy', 'Lund')
# processing prof: ('John', 'Eklund')
# processing prof: ('Karen', 'Ciccone')
# processing prof: ('Tram', 'Sparks')
# processing prof: ('Diana', 'Jochai')
# processing prof: ('Alan', 'Smith')
# processing prof: ('Anthony', 'Dimario')
# processing prof: ('Mohammad reza', 'Rajati')
# processing prof: ('Paul', 'Pflug')
# processing prof: ('Merle', 'Hopkins')
# processing prof: ('Helen', 'Choi')
# processing prof: ('Ali', 'Abbas')
# processing prof: ('Kimberly', 'Tso')
# processing prof: ('Paul', 'Foley')
# processing prof: ('Scott', 'Tennant')
# processing prof: ('Edmond', 'Jonckheere')
# processing prof: ('Ceci', 'Moss')
# processing prof: ('Kathleen', 'Takayama')
# processing prof: ('David', 'Zarazua')
# processing prof: ('Tim', 'Marx')
# processing prof: ('Jonathan', 'Kotler')
# processing prof: ('Nicole', 'Maccalla')
# processing prof: ('Muhammad', 'Alkhudair')
# processing prof: ('Alexander', 'Zholkovsky')
# processing prof: ('Peter', 'Sollett')
# processing prof: ('Joseph Anthony', 'Kunc')
# processing prof: ('Shantanu', 'Dutta')
# processing prof: ('Feng', 'Chen')
# processing prof: ('Arthur', 'Bartner')
# processing prof: ('Hector', 'Reyes')
# processing prof: ('Shahed', 'Rowshan')
# processing prof: ('Lewis', 'Rothbart')
# processing prof: ('Yanhao', 'Wei')
# processing prof: ('Susan', 'Kresin')
# processing prof: ('Herb', 'Perlmutter')
# processing prof: ('Clare', 'Pastore')
# processing prof: ('Mark', 'Redekopp')
# processing prof:processing prof: ('Jonathan', 'Tarbox')
#  ('Winston', 'Chee')
# processing prof: ('Gabriella', 'Santinelli')
# processing prof: ('Jane', 'Baumgarten')
# processing prof: ('Arjun', 'Prakash')
# processing prof: ('Millard', 'Latimer')
# processing prof: ('Stan', 'Yamashiro')
# processing prof:processing prof:  ('Thomas', 'Pier')
# ('Sandeep', 'Gupta')
# processing prof: ('Ed', 'Mc Caffery')
# processing prof: ('Joseph', 'Semkiu')
# processing prof: ('Chris', 'Roze')
# processing prof: processing prof: ('Keith', 'Plocek')
# ('Franita', 'Tolson')
# processing prof: ('Michael', 'Nguyen')
# processing prof: ('Matthew', 'Gilpin')
# processing prof: ('Michael', 'Madden')
# processing prof: ('Thu', 'Ta')
# processing prof: ('Rick', 'Schmunk')
# processing prof: ('Anthony', 'Jonas')
# processing prof: ('Tracie', 'Kirkland')
# processing prof: ('Danica', 'Liberman')
# processing prof: ('Yalda', 'Khashe')
# processing prof: ('Ha Yun', 'Cho')
# processing prof: ('Chris', 'Swain')
# processing prof: ('Gary', 'Wagner')
# processing prof: ('Stephan', 'Haas')
# processing prof: ('Richard', 'Arratia')
# processing prof:processing prof:  ('Artjoms', 'Kovalovs')
# ('Terence', 'Fitzgerald')
# processing prof: ('Terry', 'Cravens')
# processing prof: ('Renee', 'Smith-Maddox')
# processing prof: processing prof:('Amy', 'Rechenmacher')
#  ('Amanda', 'Bloom')
# processing prof: ('Caroline', 'Muglia')
# processing prof: ('Paige', 'Berger')
# processing prof: ('Michael', 'Schneir')
# processing prof: ('Julie', 'Albright')
# processing prof: ('Jung Koo', 'Kang')
# processing prof: ('Cw', 'Park')
# processing prof: ('Jacob', 'Ross')
# processing prof: ('Jeff', 'Guh')
# processing prof: ('John', 'Arensmeyer')
# processing prof: ('Heejin', 'Cho')
# processing prof: ('Eric N.', 'Pham')
# processing prof: ('Trent', 'Benedick')
# processing prof: ('Lindsay', 'Wolfington')
# processing prof: ('Maximo', 'Marin')
# processing prof: ('Paul', 'Lazarus')
# processing prof: ('Philip', 'Ethington')
# processing prof: ('Linda', 'Cox')
# processing prof: ('Itzhak', 'Bars')
# processing prof: ('Amy', 'Powell')
# processing prof: ('Shawishi', 'Haynes')
# processing prof: ('Hao', 'Chen')
# processing prof: ('Brian', 'Haas')
# processing prof: ('Jeffrey', 'West')
# processing prof: ('Neil', 'Segil')
# processing prof: ('Isabel', 'Wade')
# processing prof: ('Claradina', 'Soto')
# processing prof: ('James', 'Wind')
# processing prof: ('Jonathan', 'Munoz-Proulx')
# processing prof: ('Hayoun', 'Lee')
# processing prof: ('Jacqueline', 'Concilla')
# processing prof: ('Marianne', 'Szymanski')
# processing prof: ('Aiichiro', 'Nakano')
# processing prof: ('David', 'Parrish')
# processing prof: ('Lisa', 'Ozaeta')
# processing prof: ('John', 'Perfitt')
# processing prof: ('Sabrina', 'Napolitano')
# processing prof: ('Brent', 'Melot')
# processing prof: ('Carolee', 'Winstein')
# processing prof: ('Sara', 'McSweyn')
# processing prof: ('Helene', 'Reiner')
# processing prof: ('Emily', 'Han')
# processing prof: processing prof: ('Karen', 'Sternheimer')
# ('Devon', 'Harlow')
# processing prof: ('Jinchi', 'Lv')
# processing prof: ('Deborah', 'Natoli')
# processing prof: ('Daniel', 'Pecchenino')
# processing prof: ('Gregg', 'Daniel')
# processing prof: ('Shaama', 'Mallikarjun Sharada')
# processing prof: ('Andrew', 'McMahon')
# processing prof: ('Sarah', 'Hamm-Alvarez')
# processing prof: ('Marcus', 'Anderson')
# processing prof: ('An-Min', 'Wu')
# processing prof: ('Andres', 'Gomez')
# processing prof: ('Donald', 'Bohlinger')
# processing prof: ('Daryl', 'Davies')
# processing prof: ('Chiaoyun', 'Kuo')
# processing prof: ('Chris', 'Bresnahan')
# processing prof: ('David', 'Hinton')
# processing prof:processing prof: ('Michael', 'Roster')
#  ('Brittani', 'Morris')
# processing prof: ('Daniela', 'Baroffio')
# processing prof: ('William', 'Gorski')
# processing prof: ('Robert', 'Townsend')
# processing prof: ('Ken', 'Sereno')
# processing prof: ('Patrick', 'Prince')
# processing prof: ('Vibhor', 'Trehan')
# processing prof: ('Arianna', 'Uhalde')
# processing prof: ('Peter', 'Webster')
# processing prof: ('Atia', 'Sattar')
# processing prof: ('Tyrone', 'Callahan')
# processing prof: ('Samuel', 'Mantell')
# processing prof: ('Andrei', 'Irimia')
# processing prof: ('Jennifer', 'Marotta')
# processing prof: ('David', 'Moore')
# processing prof: ('Ryan', 'Park')
# processing prof: ('Kevin', 'Nash')
# processing prof: ('Eric', 'Rice')
# processing prof: ('Parag', 'Havaldar')
# processing prof: ('Thomas', 'Tanbonliong')
# processing prof: ('Weng Kin', 'San')
# processing prof: ('David', 'Bridel')
# processing prof: ('Ricardo', 'Mancera')
# processing prof: ('Doug', 'Thomas')
# processing prof: ('Justin', 'Bibler')
# processing prof: ('Susan', 'Bain')
# processing prof: ('Trudi', 'Sandmeier')
# processing prof: ('Leon', 'Rodriguez')
# processing prof: ('Sarah', 'Springer')
# processing prof: ('Jason', 'Cozby')
# processing prof:processing prof: ('Steven', 'Lamy')
#  ('Joshua', 'West')
# processing prof: ('Gregory', 'Stevens')
# processing prof: ('Oliver', 'Rizk')
# processing prof: ('Mark', 'Sakaguchi')
# processing prof: ('Cynthia', 'Alt')
# processing prof: ('Dennis', 'Green')
# processing prof: ('Stanley', 'Iezman')
# processing prof: ('Rachel', 'Fried')
# processing prof: ('Kristine', 'Garroway')
# ...
# processing prof: ('Sylvia', 'Fumey')
# processing prof: ('Megan', 'Becker')
# processing prof: ('Mary Joan', 'Negro')
# processing prof: ('Susan L', 'Forsburg')
# processing prof: ('William', 'Kanengiser')
# processing prof: ('Susan', 'Edwards')
# processing prof: ('Jim', 'Hubbard')
# processing prof: ('John', 'Lee')
# processing prof: ('Mark', 'Kulakoff')
# processing prof: ('Victoria', 'Degtyareva')
# processing prof: ('Adrienne Ann', 'Mullen')
# processing prof: ('Tom', 'Jordan')
# processing prof: ('David', 'Carter')
# processing prof: ('Nitin', 'Kale')
# processing prof: ('Daniel', 'Brumer')
# processing prof: ('Andrew', 'MacKay')
# processing prof: ('Cesar', 'Acosta-Mejia')
# processing prof: ('Andrew', 'Murr')
# processing prof: ('Darryl', 'Brown')
# processing prof: ('Frank', 'Catalano')
# processing prof: ('Andrea', 'Armani')
# processing prof: ('Nina', 'Eliasoph')
# processing prof: ('Ed', 'Reynolds')
# processing prof: ('Mark', 'Frey')
# processing prof: ('Shlomi', 'Ronen')
# processing prof: ('Pamela', 'Starr')
# processing prof: ('Guilan', 'Siassi')
# processing prof: ('Daria', 'Griffith')
# processing prof: ('Hamid', 'Nazer-Zadeh')
# processing prof:processing prof: ('Susan', 'Arnold')
#  ('Rayudu', 'Gopalakrishna')
# processing prof: ('Elizabeth', 'Ramsey')
# processing prof: ('Max', 'Barroso')
# processing prof: ('Jesus', 'Dominguez')
# processing prof: ('Peter', 'Clarke')
# processing prof: ('Douglas', 'Shook')
# processing prof: ('Yao-Yi', 'Chiang')
# processing prof: ('Hernan', 'Galperin')
# processing prof: ('Kelsey', 'Rubin-Detlev')
# processing prof: ('Curt', 'Wittig')
# processing prof: ('David', 'Schwartz')
# processing prof: ('John', 'Rowe')
# processing prof: ('Lon', 'Kurashige')
# processing prof: ('Stanley', 'Tahara')
# processing prof: ('Jerry', 'Loeb')
# processing prof: ('John', 'Thomas')
# processing prof: ('Seda', 'Durguner')
# processing prof: ('Houda', 'Alachkar')
# processing prof: ('Michael', 'Thom')
# processing prof: ('Renee', 'Michelsen')
# processing prof: ('Michael', 'Wissot')
# processing prof: ('Carolina', 'Castillo Larrea')
# processing prof: ('Kendra', 'Walther')
# processing prof: ('T J', 'McCarthy')
# processing prof: ('Richard', 'Whitley')
# processing prof: ('Laura', 'Fox')
# processing prof: ('Eric', 'Coe')
# processing prof: ('Brandon', 'Franzke')
# processing prof: ('Janet', 'Hoskins')
# processing prof: ('Pai-Ling', 'Yin')
# processing prof: ('Graeme', 'Morland')
# processing prof: ('James', 'Wald')
# processing prof:processing prof: ('Summer', 'Dunsmore')
#  ('Yuan', 'Gao')
# processing prof: ('Nenad', 'Medvidovic')
# processing prof: ('Caroline', 'Vranca')
# processing prof: ('Mark', 'Goldstein')
# processing prof: ('Robert', 'Banks')
# processing prof: ('Sara', 'Catania')
# processing prof: ('David', 'Ulin')
# processing prof: ('Miya', 'Mizuta')
# processing prof: ('Kevin', 'Robb')
# processing prof: ('Jobin', 'Varkey')
# processing prof: ('Mini', 'Datta')
# processing prof: ('Rotem', 'Gilbert')
# processing prof: ('Ralph', 'Kirshbaum')
# processing prof: ('John', 'Roche')
# processing prof: ('Cynthia', 'Gensler')
# processing prof: ('Mark', 'Krailo')
# processing prof: ('Sarah', 'Feakins')
# processing prof: ('Min-Kyoung', 'Rhee')
# processing prof: ('Robert', 'Rasmussen')
# processing prof: ('Jenifer', 'Crawford')
# processing prof: ('Camille', 'Dieterle')
# processing prof: ('Aaron', 'Martini')
# processing prof: ('David', 'Hutchins')
# processing prof: ('Ernest', 'Wilson')
# processing prof: ('David', 'Isaacs')
# processing prof: ('Patrick', 'Murphy')
# processing prof: ('Ruchi', 'Desai')
# processing prof: ('Maria', 'Esnaola')
# processing prof: ('Sarah', 'Mojarad')
# processing prof: ('Melissa L', 'Miller')
# processing prof: ('Suzanne', 'Lacy')
# processing prof: ('Clark', 'Muller')
# processing prof: ('Charlotte', 'Stratton')
# processing prof: ('Kristen', 'Zaleski')
# processing prof: ('Shawn', 'Belling')processing prof: ('Dan', 'Lupovitz')
#
# processing prof: ('Hanna', 'Reisler')
# processing prof: ('Porter', 'Williams')
# processing prof: ('Tobias', 'Ulmer')
# processing prof: ('Gerald', 'Hintz')
# processing prof: ('Sriram', 'Dasu')
# processing prof: ('Eric L', 'Fecht')
# processing prof: ('Dan', 'Wei')
# processing prof: ('Cristina', 'Visperas')
# processing prof: ('Henry', 'Jenkins')
# processing prof: ('Maurice', 'Rahimi')
# processing prof: ('Greg', 'Autry')
# processing prof: ('Leslie', 'Wind')
# processing prof: ('Seong', 'Kim')
# processing prof: ('Carol', 'Wise')
# processing prof: ('Scott', 'Applebaum')
# processing prof: ('Nicole', 'Esparza')
# processing prof: ('Edgar', 'Arceneaux')
# processing prof: ('Nicolai', 'Haydn')
# processing prof: ('Roger', 'Ghanem')
# processing prof: ('Jack', 'Barcal')
# processing prof: ('Florence', 'Hofman')
# processing prof:processing prof: ('Rachel', 'Mendoza')
#  ('Nitin', 'Govil')
# processing prof: ('Leland', 'Saito')
# processing prof: ('Charles', 'Russell-Schlesinger')
# processing prof: ('Roeban', 'Katz')
# processing prof: ('Veronika', 'Krausas')
# processing prof: ('Sita', 'Reddy')
# processing prof: ('Benjamin', 'Pack')
# processing prof: ('Robert', 'Adamik')
# processing prof: ('Jessica', 'Brier')
# processing prof: ('Wonho', 'Song')
# processing prof: ('Cecilia', 'Caballero')
# processing prof: ('Sivarama', 'Vinjamury')
# processing prof: ('Romain', 'Ranciere')
# processing prof: ('Hannah', 'Garry')
# processing prof: ('Louis', 'Goldstein')
# processing prof: ('Thomas', 'Lozito')
# processing prof:processing prof: ('D Sabela', 'Grimes')
#  ('Alexandra', 'Portaro')
# processing prof: ('Erroll', 'Southers')
# processing prof: ('Eric', 'Allen')
# processing prof: ('Guofu', 'Tan')
# processing prof: ('Ali', 'Zahid')
# processing prof: ('Richard', 'Holland')
# processing prof: ('Laura', 'Ferguson')
# processing prof: ('Laura', 'Loyola')
# processing prof: ('Kedra', 'Ishop')
# processing prof: ('Donald', 'Crockett')
# processing prof: ('Chris', 'Mayeda')
# processing prof: ('Madeline', 'Thayer')
# processing prof: ('Julie', 'Slayton')
# processing prof: ('Hadi', 'Qazwini')
# processing prof: ('Susie', 'Kim')processing prof:
# ('Maria', 'Maldonado')
# processing prof: ('Barbara', 'Nance')
# processing prof:processing prof: ('Christopher', 'Zambri')
#  ('Stacy', 'Scholder')
# processing prof: ('Brett', 'Spatola')
# processing prof: ('Ulrich', 'Neumann')
# processing prof: ('Peter', 'Robinson')
# processing prof: ('P J', 'Leimgruber')
# processing prof: ('Jayanth', 'Kudva')
# processing prof: ('James Lewis', 'Heft')
# processing prof: ('Tracy', 'Tambascia')
# processing prof: ('Navid', 'Pour-Ghasemi')
# processing prof: ('Chu-Yi', 'Wang')
# processing prof: ('Michael', 'Hricak')
# processing prof: ('Michael', 'Sievers')
# processing prof: ('Marcel', 'Valcarce')
# processing prof: ('Yasemin', 'Yilmaz')
# processing prof: ('Caroline', 'Betts')
# processing prof: ('Robert', 'Alderette')
# processing prof: ('Agatha', 'King')
# processing prof: ('Matthew', 'Cox')
# processing prof: ('David', 'Albertson')
# processing prof: ('Tiffany', 'Danko')
# processing prof: ('Graham', 'Robertson')
# processing prof: ('Michael', 'Hannan')
# processing prof: ('Daniel', 'Kirages')
# processing prof: ('Reine-Claire', 'Dousarkissian')
# processing prof: ('Peggy', 'Farnham')
# processing prof: ('Kevin', 'Caporicci')
# processing prof: ('Michael', 'Bunn')
# processing prof: ('Estela', 'Andujo')
# processing prof: ('David', 'Levine')
# processing prof: ('Kelton', 'Rhoads')
# processing prof: ('Shae', 'Harvey')
# processing prof: ('Sandra', 'Disner')
# processing prof: ('Elsa', 'Garcia-Sanda')
# processing prof: ('Robert', 'Chow')
# processing prof: ('Michaela', 'Ullmann')
# processing prof: ('Sarah', 'Benor')
# processing prof: ('Kristian', 'Carlson')
# processing prof: ('Sean', 'Nye')
# processing prof: ('Timothy', 'Triche')
# processing prof: ('Douglas', 'Bender')
# processing prof: ('St.', 'Colon')
# processing prof: ('Felix', 'Yip')
# processing prof: ('Xiaowu', 'Gai')
# processing prof: ('Anne', 'Katz')
# processing prof: ('Mohamed', 'Ndaoud')
# processing prof:processing prof: ('Carmen', 'Lee')
#  ('James', 'Thrash')
# processing prof: ('William', 'Slaughter')
# processing prof: ('Sarah', 'Axeen')
# processing prof: ('Kenneth', 'Phillips')
# processing prof: ('Ian', 'Ehrenreich')
# processing prof: ('Divana', 'Olivas')
# processing prof: ('Bala', 'Subramanian')
# processing prof: ('Bonnie', 'Blake')
# processing prof: ('Janak', 'Chandrasoma')
# processing prof: ('Aleksandra', 'Korolova')
# processing prof: ('Giorgia', 'Quadrato')
# processing prof: ('Lucio', 'Soibelman')
# processing prof: ('Kevin', 'McCorkle')
# processing prof: ('Rehan', 'Kapadia')
# processing prof: ('Dana', 'Tate')
# processing prof: ('Nathalie', 'Bragadir')
# processing prof: ('Tom', 'Sloper')
# processing prof: ('Carl', 'Collins')
# processing prof: ('Calvin', 'Nguyen')
# processing prof: ('Frederic', 'Clark')
# processing prof: ('Benjamin', 'La Brot')
# processing prof: ('Juan', 'Carrillo')
# processing prof: ('Benita', 'Garvin')
# processing prof: ('Keigo', 'MacHida')
# processing prof: ('Guillermo', 'Reyes Souto')
# processing prof: ('Janna', 'Wong')
# processing prof: ('Justin', 'Trifiro')
# processing prof: ('Robert', 'Young')
# processing prof: ('Robert', 'Filback')
# processing prof: ('Daniel', 'Tiffany')
# processing prof: ('Ron', 'Ben-Ari')
# processing prof: ('David', 'Cash')
# processing prof: ('Heather', 'Davis')
# processing prof: ('John', 'Slaughter')
# processing prof: ('Bob', 'Pearson')
# processing prof: ('Helen', 'Kim')
# processing prof: ('Yu-Wei', 'Hsieh')
# processing prof: ('K Michael', 'Rowley')
# processing prof: ('Susan', 'Sinclair')
# processing prof: ('Andrea', 'Stolpe')
# processing prof: ('Robert', 'Kuznia')
# processing prof: ('Trey', 'Callaway')
# processing prof: ('Nicholas', 'Cain')
# processing prof: ('Shawnmari', 'Kaiser')
# processing prof: ('Steve', 'Nutt')
# processing prof: ('Jonathan', 'Holzer')
# processing prof: ('Alan', 'Berger')
# processing prof: ('Julianna', 'Kirschner')
# processing prof: ('Christina', 'Belcher')
# processing prof: ('Steven', 'Richeimer')
# processing prof: ('Sillas', 'Duarte')
# processing prof: ('Beatriz', 'Ilari')
# processing prof: ('Paul', 'Nash')
# processing prof: ('Emily', 'Cooperdock')
# processing prof: ('Shahriar', 'Shamsian')
# processing prof: ('James', 'Self')
# processing prof: ('Deborah', 'Weiss')
# processing prof: ('Kathleen', 'Dowdey')
# processing prof: ('Richard', 'Newmyer')
# processing prof: ('Selina', 'Troesch')
# processing prof: ('Namkil', 'Kim')
# processing prof: ('Steven', 'Bush')
# processing prof: ('Dan', 'Erwin')
# processing prof: ('Devin', 'Griffiths')
# processing prof: ('Zahra', 'Nealy')
# processing prof: ('Eunjin (anna)', 'Kim')
# processing prof: ('Amy', 'Pellman')
# processing prof: ('Lisa', 'Kabot')
# processing prof: ('Edith', 'Mirzaian')
# processing prof: ('Sean', 'Bouchard')
# processing prof: ('Kerry', 'Fields')
# processing prof: ('Young', 'Cho')
# processing prof: ('Christopher', 'Sampson')
# processing prof: ('Vicki', 'Callahan')
# processing prof: ('Daniel', 'Kagan')
# processing prof: ('Jeffrey', 'Smith')
# processing prof: ('Mike', 'Brennan')
# processing prof:processing prof: ('Patrick', 'Harder')
#  ('Paul', 'Hungerford')
# processing prof: ('Terry', 'Gordon')
# processing prof: ('Minnie', 'Mc Millan')
# processing prof: ('Justin', 'Ching')
# processing prof: ('Eve', 'Lee')
# processing prof: ('Nivedita', 'Bhaskhar')
# processing prof: ('Gioia', 'Polidori')
# processing prof: ('Andrew', 'Griebeler')
# processing prof: ('Scott', 'Uriu')
# processing prof: ('Ginger', 'Nolan')
# processing prof: ('Don', 'Trahan')
# processing prof: ('Emily', 'Schulze')
# processing prof: ('Brian', 'Rathbun')
# processing prof: ('Aimee', 'Odette')
# processing prof: ('Debra', 'Berl')
# processing prof: ('Mark', 'Haddad')
# processing prof:processing prof: ('Cheng', 'Hsiao')
#  ('Ramesh', 'Govindan')
# processing prof: ('Zune', 'Nguyen')
# processing prof: ('Indra', 'Mukhopadhyay')
# processing prof: ('Bill', 'Yahraus')
# processing prof: processing prof: ('Aaron', 'Cote')
# ('Lindsey', 'Bier')
# processing prof: ('Jessica', 'Parr')
# processing prof: ('Victor', 'Fazio')
# processing prof: ('Susie', 'Cognetta')
# processing prof: ('Brett', 'Ryback')
# processing prof: ('William', 'Deverell')
# processing prof: ('Piotr', 'Florczyk')
# processing prof: ('Joshua', 'Adam')
# processing prof: ('Toni Ann', 'Johnson')
# processing prof: ('Narineh', 'Makijan')
# processing prof: ('Dwight', 'Stirling')
# processing prof: ('Jay', 'Clewis')
# processing prof: ('John', 'Drake')
# processing prof: ('Kerim', 'Yasar')
# processing prof: ('Jennifer', 'Bernstein')
# processing prof: ('Quentin', 'Fleming')
# processing prof: ('Marci', 'Vogel')
# processing prof: ('Candace', 'Smith')
# processing prof: ('Meiqing', 'Zhang')
# processing prof: ('Geraldine', 'Fiss')
# processing prof: ('Lindsey', 'Plato-Johnson')
# processing prof: ('Maya', 'Maskarinec')
# processing prof: ('Amara', 'Aguilar')
# processing prof: ('Steve', 'Barth')
# processing prof: ('Stephen', 'MacK')
# processing prof: ('Wanda', 'Cumberlander')
# processing prof: ('Rodney', 'To')
# processing prof: ('Alex', 'Capron')
# processing prof: ('Siyi', 'Chen')
# processing prof: ('Maria', 'Ogneva')
# processing prof: ('Bret', 'Easterling')
# processing prof: ('Bill', 'Holder')
# processing prof: ('Barbara', 'Pierce')
# processing prof: ('Liang', 'Chen')
# processing prof: ('Tak', 'Kata')
# processing prof: ('Harly', 'Ramsey')
# processing prof: ('David', 'Kang')
# processing prof: ('Yanhui', 'Wu')
# processing prof: ('Hazel', 'Atuel')
# processing prof: ('Laura Isabel', 'Serna')
# processing prof: ('Trond', 'Sigurdsen')
# processing prof: ('Jack', 'Berger')
# processing prof: ('Iraj', 'Ershaghi')
# processing prof: ('Davide', 'Proserpio')
# processing prof: ('Willa', 'Seidenberg')
# processing prof: ('Lauren', 'Levitt')
# processing prof: ('Thomas', 'Mc Neill')
# processing prof: ('Jennifer', 'Petersen')
# processing prof: ('Erin', 'Kasimow')
# processing prof: ('Deanna', 'Rivera')
# processing prof: ('Danny', 'Wang')
# processing prof: ('Mihailo', 'Trifunac')
# processing prof: ('Nikhil', 'Kar')
# processing prof: ('Zeynep', 'Ertem')
# processing prof: ('Jenna', 'Kobara')
# processing prof: ('Carsten', 'Becker')
# processing prof: ('Ebrahim', 'Zandi')
# processing prof: ('Erin', 'McIntyre')
# processing prof: ('Mike', 'Ananny')processing prof: ('John', 'Romley')
#
# processing prof: ('Michael', 'Cousineau')
# processing prof: ('Steven', 'Heilman')
# processing prof:processing prof: ('Mary', 'Looman')
#  ('Craig', 'Stanford')
# processing prof: ('Sunyoung', 'Park')
# processing prof: ('Joseph', 'Priester')
# processing prof: ('Joan', 'Tardibuono')
# processing prof: ('Fred', 'Stone')
# processing prof: ('Stephen', 'Lu')
# processing prof: ('Nicole', 'Webster')
# processing prof: ('Patrick', 'Maio')
# processing prof: ('Genevieve', 'Giuliano')
# processing prof: ('Andy', 'Abad')
# processing prof: ('Tamera', 'Daugherty')
# processing prof: ('Firdaus', 'Udwadia')
# processing prof: ('Xiang', 'Jian')
# processing prof: ('Meiling', 'Cheng')
# processing prof: ('Albert', 'Napoli')
# processing prof: ('Michael', 'Chavez Booth')
# processing prof: ('Gabriel', 'Kahn')
# processing prof: ('Terence', 'Sanger')
# processing prof: ('Joon-Ho', 'Choi')
# processing prof: ('Samantha', 'Broitman')
# processing prof: ('Rebecca', 'Lemon')
# processing prof: ('Bob', 'Bridges')
# processing prof: ('Sonja', 'Warfield')
# processing prof: ('Rebekah', 'Garrison')
# processing prof: ('Eric', 'Tan')
# processing prof: ('Cecilia', 'Patino Sutton')
# processing prof: ('Catherine', 'Bell')
# processing prof: ('Daniel', 'Sussman')
# processing prof: ('Paul', 'Jackson Jr ')
# processing prof: ('Gian-Maria', 'Annovi')
# processing prof: ('Hagit', 'Arieli-Chai')
# processing prof: ('Joseph', 'Wang')
# processing prof: ('Meredith', 'Lepley')
# processing prof: ('Rika', 'Hiro')
# processing prof: ('Mark', 'Chaisson')
# processing prof: ('James', 'Finley')
# processing prof: ('Alon', 'Frydman')
# processing prof: ('Gillian', 'Finley')
# processing prof: ('Ira', 'Kalb')
# processing prof: ('Sharon', 'Lavery')
# processing prof: ('Jeremiah', "O'Brian")
# processing prof: ('Lucas', 'Herchenroeder')
# processing prof: ('Roger', 'Duncan')
# processing prof: ('Akira Mizuta', 'Lippit')
# processing prof: ('Jane', 'James')
# processing prof: ('Carol', 'Baum')
# processing prof: ('Stephen', 'Aguilar')
# processing prof: ('Michael', 'Nichol')
# processing prof: ('Cynthia', 'Lieu')
# processing prof: ('Ahmad', 'Besaratinia')
# processing prof: ('Brendan', 'Pawlowski')
# CPU times: user 6min 55s, sys: 32.1 s, total: 7min 28s
# Wall time: 9min 10s

# %%
        
with open(join('.','profInfoDB.json'), 'w') as outfile:
    json.dump(dict(profInfo), outfile)

# %%
dict(profInfo)
# Out:
# {'Roderick Castro': array([], dtype=float64),
#  'Carsten Becker': array([], dtype=float64),
#  'Cavan Concannon': [3.8, 0.67, 13.0],
#  'Jennifer Misran': [4.4, 0.86, 7.0],
#  'Edward Rhodes': [3.1, 0.56, 29.0],
#  'Sim Sarna': array([], dtype=float64),
#  'Michael Kassner': array([], dtype=float64),
#  'Anna Quyen Nguyen': array([], dtype=float64),
#  'Alexander Zholkovsky': [3.5, 0.33, 16.0],
#  'Lisa Kabot': array([], dtype=float64),
#  'Gerd Bergmann': array([], dtype=float64),
#  'Erin Trish': array([], dtype=float64),
#  'Robert Webster': array([], dtype=float64),
#  'Rebecca Choi': array([], dtype=float64),
#  'Victor Fazio': array([], dtype=float64),
#  'Kairos Llobrera': array([], dtype=float64),
#  'Lilly Shoup': array([], dtype=float64),
#  'Robert Farley': array([], dtype=float64),
#  'China Adams': array([], dtype=float64),
#  'Scott Wiltermuth': array([], dtype=float64),
#  'Alan Berger': array([], dtype=float64),
#  'Rosa Di Felice': array([], dtype=float64),
#  'Sriram Dasu': array([], dtype=float64),
#  'Monalisa Chatterjee': [4.0, 0.83, 8.0],
#  'Lucienne Aarsen': array([], dtype=float64),
#  'Benjamin Pack': [4.4, 0.57, 21.0],
#  'Andrae Alexander': array([], dtype=float64),
#  'Sasha Anawalt': array([], dtype=float64),
#  'Sivaramakrishnan Siddarth': array([], dtype=float64),
#  'Trent Benedick': array([], dtype=float64),
#  'Charlotte Stratton': array([], dtype=float64),
#  'Kimberly Kelly Rolfe': array([], dtype=float64),
#  'Behnam Jafarpour': array([], dtype=float64),
#  'Benjamin La Brot': array([], dtype=float64),
#  'Rebecca Romero': array([], dtype=float64),
#  'James Wald': array([], dtype=float64),
#  'Keith Plocek': array([], dtype=float64),
#  'Richard Chernick': array([], dtype=float64),
#  'Yue Yang': array([], dtype=float64),
#  'Bruce Finn': array([], dtype=float64),
#  'Carly Roman': array([], dtype=float64),
#  'Daniel Hackman': array([], dtype=float64),
#  'Raymundo Zacarias': array([], dtype=float64),
#  'Shobhit Jain': array([], dtype=float64),
#  'Joe Qin': array([], dtype=float64),
#  'Marianna Chodorowska-Pilch': [4.2, 0.78, 16.0],
#  'Michael Hahn': array([], dtype=float64),
#  'Ashutosh Nayyar': array([], dtype=float64),
#  'Jason Berman': array([], dtype=float64),
#  'Nicole Kuklok-Waldman': array([], dtype=float64),
#  'Rochelle Gold': [4.7, 1.0, 11.0],
#  'Neal Desby': array([], dtype=float64),
#  'Divana Olivas': array([], dtype=float64),
#  'Kathleen West': array([], dtype=float64),
#  'Dennis Schorr': [3.3, 0.38, 17.0],
#  'Bocheng Jin': array([], dtype=float64),
#  'Sabrina Smiley': array([], dtype=float64),
#  'Jim Clements': array([], dtype=float64),
#  'Jack Barcal': array([], dtype=float64),
#  'Deniz Rudin': array([], dtype=float64),
#  'Ron Grover': array([], dtype=float64),
#  'Emily Schulze': array([], dtype=float64),
#  'Brett Spatola': array([], dtype=float64),
#  'Miranda Barone': [4.2, 0.82, 54.0],
#  'Beiyun Zhou': array([], dtype=float64),
#  "Lindsay O'Neill": [4.3, 0.8, 31.0],
#  'Timothy Werlinger': array([], dtype=float64),
#  'Danny Wang': array([], dtype=float64),
#  'Kevin Caporicci': [4.7, 1.0, 7.0],
#  'Gary Wagner': array([], dtype=float64),
#  'Wiebke Ziebis': array([], dtype=float64),
#  'Ralph Oyaga': array([], dtype=float64),
#  'Meggan Thompson': array([], dtype=float64),
#  'Matthew Scott': array([], dtype=float64),
#  'Elizabeth Fife': array([], dtype=float64),
#  'Michael Kaminsky': array([], dtype=float64),
#  'Mary Murphy': array([], dtype=float64),
#  'Jennifer Head': array([], dtype=float64),
#  'Adam Huttenlocker': array([], dtype=float64),
#  'John Loper': [4.0, 0.8, 10.0],
#  'Noe Olivas': array([], dtype=float64),
#  'Mahmood Sariolghalam': array([], dtype=float64),
#  'Michael Kodama': array([], dtype=float64),
#  'Ivette Gomez': [4.3, 1.0, 23.0],
#  'Themistocles Sparangis': array([], dtype=float64),
#  'David Zarazua': [3.0, 0.92, 30.0],
#  'Gerald Goodnight': array([], dtype=float64),
#  'Julia Paull': array([], dtype=float64),
#  'Scott Kroopf': array([], dtype=float64),
#  'Carlos Godoy': [5.0, 1.0, 22.0],
#  'Richard Antaramian': array([], dtype=float64),
#  'Kasia Anderson': array([], dtype=float64),
#  'Josephine Fava Hochuli': array([], dtype=float64),
#  'Barbara Pierce': array([], dtype=float64),
#  'Jose Zavala': array([], dtype=float64),
#  'Laurie Fisher': [4.1, 0.62, 13.0],
#  'Jennifer Bernstein': array([], dtype=float64),
#  'Holly Sotelo': array([], dtype=float64),
#  'Nicholas Earhart': array([], dtype=float64),
#  'Nakisha Sattelmaier': array([], dtype=float64),
#  'Narineh Makijan': array([], dtype=float64),
#  'Rachel Gezerseh': array([], dtype=float64),
#  'Rika Hiro': array([], dtype=float64),
#  'Myra Turner': array([], dtype=float64),
#  'Timothy Triche': array([], dtype=float64),
#  'Peter Erskine': array([], dtype=float64),
#  'Daniel Lee': array([], dtype=float64),
#  'David Johnson': array([], dtype=float64),
#  'Taqueena Quintana': array([], dtype=float64),
#  'Phan Phan': array([], dtype=float64),
#  'Jennifer Lott': array([], dtype=float64),
#  'Sena Durguner': [4.4, 0.87, 122.0],
#  'Peter Carnevale': array([], dtype=float64),
#  'Shantanu Dutta': array([], dtype=float64),
#  'Peter Braun': array([], dtype=float64),
#  'Nick Vyas': array([], dtype=float64),
#  'Larry Gross': array([], dtype=float64),
#  'Robert Banks': array([], dtype=float64),
#  'Niels Frenzen': array([], dtype=float64),
#  'Adam Silverman': array([], dtype=float64),
#  'Piotr Florczyk': array([], dtype=float64),
#  'David Kang': [4.5, 0.77, 23.0],
#  'Cindy Guyer': array([], dtype=float64),
#  'Kaori Ito': array([], dtype=float64),
#  'Paul Prioleau': array([], dtype=float64),
#  'John Roche': array([], dtype=float64),
#  'Yan Tang': array([], dtype=float64),
#  'Alison Trope': [2.9, 0.57, 27.0],
#  'Gregory Kling': array([], dtype=float64),
#  'Patience Moll': array([], dtype=float64),
#  'Philip Ethington': array([], dtype=float64),
#  'Shieva Kleinschmidt': [3.9, 0.8, 33.0],
#  'Thomas Mueller': array([], dtype=float64),
#  'Rick Berg': [3.3, 0.5, 6.0],
#  'Daniela Baroffio': array([], dtype=float64),
#  'Olivia Smith': array([], dtype=float64),
#  'Qiang Huang': array([], dtype=float64),
#  'John Carpten': array([], dtype=float64),
#  'Richard Peterson': array([], dtype=float64),
#  'Michael Schneir': array([], dtype=float64),
#  'Jonathan Sauder': array([], dtype=float64),
#  'David Ginsburg': array([], dtype=float64),
#  'Sara Kintzle': array([], dtype=float64),
#  'Don Trahan': array([], dtype=float64),
#  'Lawrence Green': [3.3, 0.89, 23.0],
#  'Eric Friedlander': array([], dtype=float64),
#  'Boris Fritz': array([], dtype=float64),
#  'Susan L Forsburg': array([], dtype=float64),
#  'Katsuhiko Oda': array([], dtype=float64),
#  'Jessi Johnson': [4.1, 0.69, 15.0],
#  'Melissa Daniels-Rauterkus': array([], dtype=float64),
#  'Amy Bresnahan': [4.0, 0.8, 5.0],
#  'Lucas Herchenroeder': [2.9, 0.43, 22.0],
#  'Nikhil Bhatia': array([], dtype=float64),
#  'Gregg Brandow': array([], dtype=float64),
#  'John De Mita': array([], dtype=float64),
#  'Ramesh Govindan': array([], dtype=float64),
#  'Pam Franzwa': array([], dtype=float64),
#  'Joseph Bebel': array([], dtype=float64),
#  'Kate Burton': array([], dtype=float64),
#  'Shahin Nazarian': [4.7, 0.92, 85.0],
#  'Kristin Diehl': array([], dtype=float64),
#  'James Fortney': [4.6, 1.0, 12.0],
#  'Liuning Zhou': array([], dtype=float64),
#  'Tiara Wilson': array([], dtype=float64),
#  'Paolo Zanardi': array([], dtype=float64),
#  'Abbass Sharif': [4.6, 1.0, 15.0],
#  'Kim Finney': array([], dtype=float64),
#  'Yajaira Curiel': array([], dtype=float64),
#  'Michael Nguyen': array([], dtype=float64),
#  'Bayo Akinfemi': array([], dtype=float64),
#  'Ann Crigler': array([], dtype=float64),
#  'Jeffery Jenkins': array([], dtype=float64),
#  'Linsey Smith': array([], dtype=float64),
#  'Nicos Petasis': array([], dtype=float64),
#  'George Salem': array([], dtype=float64),
#  'Hye Min Kim': array([], dtype=float64),
#  'Julie Zissimopoulos': array([], dtype=float64),
#  'Vianey Cabrera': [4.8, 1.0, 21.0],
#  'Savannah Bloch': array([], dtype=float64),
#  'Cosimo Arnesano': array([], dtype=float64),
#  'Dianne Farrington': array([], dtype=float64),
#  'Alexis Zoto': array([], dtype=float64),
#  'Sylvain Barbot': array([], dtype=float64),
#  'Jason Reisig': array([], dtype=float64),
#  'Stefano Rebeggiani': [4.6, 0.9, 12.0],
#  'F J Pratt': array([], dtype=float64),
#  'Alon Frydman': array([], dtype=float64),
#  'Steven Fleming': array([], dtype=float64),
#  'Cheryl Coleman': array([], dtype=float64),
#  'Quade French': array([], dtype=float64),
#  'Scott Darrell': array([], dtype=float64),
#  'Trina Hoefling': array([], dtype=float64),
#  'Sharon Greene': array([], dtype=float64),
#  'Edith Mirzaian': array([], dtype=float64),
#  'Ahmad Besaratinia': [2.3, 0.4, 26.0],
#  'Nicolas Benavides': array([], dtype=float64),
#  'Benita Garvin': array([], dtype=float64),
#  'Sylvia Fumey': array([], dtype=float64),
#  'Hue Wang': array([], dtype=float64),
#  'Frederick Owusu': array([], dtype=float64),
#  'Paul Orfalea': array([], dtype=float64),
#  'Wendy Phillips': array([], dtype=float64),
#  'Kay Sturm': array([], dtype=float64),
#  'Grant Lawless': array([], dtype=float64),
#  'Roberto Suro': [3.3, 0.55, 14.0],
#  'Gillian Finley': array([], dtype=float64),
#  'Paul Nash': array([], dtype=float64),
#  'Carol Wise': [4.0, 0.6, 17.0],
#  'Julie Tilson': array([], dtype=float64),
#  'Francesca Italiano': array([], dtype=float64),
#  'Darren Ruddell': array([], dtype=float64),
#  'Michelle Meyers': array([], dtype=float64),
#  'Arpi Mardirossian': [3.5, 0.59, 22.0],
#  'Samuel King': array([], dtype=float64),
#  'Ariela Gross': array([], dtype=float64),
#  'Aravind Asok': array([], dtype=float64),
#  'James Condon': array([], dtype=float64),
#  'Manochehr Rashidian': [2.9, 0.63, 63.0],
#  'Hiroshi Ochiumi': array([], dtype=float64),
#  'Botao Yang': [3.6, 0.83, 13.0],
#  'Annalisa Enrile': array([], dtype=float64),
#  'Jason Buhle': array([], dtype=float64),
#  'Kate Jacobs': array([], dtype=float64),
#  'Garrett Brown': array([], dtype=float64),
#  'Milan Miric': array([], dtype=float64),
#  'Nithya Muthuswamy': array([], dtype=float64),
#  'Linda Hoffman': array([], dtype=float64),
#  'Bogdan Marcu': array([], dtype=float64),
#  'Hashem Pesaran': array([], dtype=float64),
#  'Carl Voigt': [4.1, 0.75, 34.0],
#  'Andrea Witkin': [4.8, 1.0, 18.0],
#  'Joan Piggott': array([], dtype=float64),
#  'Ian Culbertson': [4.0, 0.83, 8.0],
#  'Ryan Leack': array([], dtype=float64),
#  'Nina Young': array([], dtype=float64),
#  'Barbara Siegel': array([], dtype=float64),
#  'Christopher Magriney': array([], dtype=float64),
#  'Michael Uno': array([], dtype=float64),
#  'Hayoun Lee': array([], dtype=float64),
#  'John Owens': array([], dtype=float64),
#  'Cynthia Alt': [2.8, 0.42, 13.0],
#  'Michael Cousineau': array([], dtype=float64),
#  'Mark Irwin': array([], dtype=float64),
#  'Natalie Meyers': array([], dtype=float64),
#  'Paul Bader': [2.7, 0.33, 6.0],
#  'Ketaki Pant': array([], dtype=float64),
#  'Assad Oberai': array([], dtype=float64),
#  'Samantha Burton': [4.3, 0.5, 6.0],
#  'William Schmidt': array([], dtype=float64),
#  'Nicholas Smith': array([], dtype=float64),
#  'Tatiana Akishina': array([], dtype=float64),
#  'Leslie Kapner': array([], dtype=float64),
#  'Farzana Choudhury': array([], dtype=float64),
#  'Min-Kyoung Rhee': array([], dtype=float64),
#  'Kate Levin': [4.4, 1.0, 10.0],
#  'Hernan Galperin': array([], dtype=float64),
#  'Sergei Gepshtein': array([], dtype=float64),
#  'Yasemin Copur-Gencturk': array([], dtype=float64),
#  'Brendan Pawlowski': array([], dtype=float64),
#  'Scott Smith': array([], dtype=float64),
#  'Kathleen Garretson': array([], dtype=float64),
#  'Joseph Pereira': array([], dtype=float64),
#  'Eugenia Weiss': array([], dtype=float64),
#  'Bing Wang': array([], dtype=float64),
#  'Sarah McGill': array([], dtype=float64),
#  'Susan Enguidanos': array([], dtype=float64),
#  'Lina Bahn': array([], dtype=float64),
#  'Ben Carrington': array([], dtype=float64),
#  'Sherry Zaks': array([], dtype=float64),
#  'Jon Burlingame': array([], dtype=float64),
#  'Darryl Shibata': array([], dtype=float64),
#  'Sivarama Vinjamury': array([], dtype=float64),
#  'Alice Baumgartner': array([], dtype=float64),
#  'Jonathan Aronson': array([], dtype=float64),
#  'Robert Vos': [3.4, 0.42, 15.0],
#  'Charles Stark': array([], dtype=float64),
#  'Paul Pflug': array([], dtype=float64),
#  'Rehan Kapadia': array([], dtype=float64),
#  'Thomas Mc Neill': array([], dtype=float64),
#  'Vincent Mendoza': array([], dtype=float64),
#  'Mark Haddad': [4.6, 0.89, 9.0],
#  'David Sloane': array([], dtype=float64),
#  'Christopher Sampson': array([], dtype=float64),
#  'Michael Hricak': array([], dtype=float64),
#  'Josh Kun': array([], dtype=float64),
#  'Dave Dinh': array([], dtype=float64),
#  'Joseph Rodgers': array([], dtype=float64),
#  'Michael Connors': array([], dtype=float64),
#  'Percival Everett': [4.7, 1.0, 9.0],
#  'Rufus Spann': array([], dtype=float64),
#  'Joshua West': [4.0, 0.77, 22.0],
#  'Jennifer Thomas': array([], dtype=float64),
#  'Albert Farias': array([], dtype=float64),
#  'Joshua Garroway': [4.5, 0.67, 28.0],
#  'Marc Ambinder': array([], dtype=float64),
#  'Keith Allen-Niesen': array([], dtype=float64),
#  'Robert Alderette': array([], dtype=float64),
#  'Fred Stone': array([], dtype=float64),
#  'Meridith Kruse': [4.8, 0.88, 10.0],
#  'Erroll Southers': array([], dtype=float64),
#  'David Ulin': array([], dtype=float64),
#  'Gerald Hintz': array([], dtype=float64),
#  'Enrique Martinez Celaya': array([], dtype=float64),
#  'Karen Skinner': array([], dtype=float64),
#  'Carrie Guss': array([], dtype=float64),
#  'Eric Freiser': array([], dtype=float64),
#  'Dave Quast': array([], dtype=float64),
#  'Edward Seo': array([], dtype=float64),
#  'Tom Miller': array([], dtype=float64),
#  'Sung-Shim Park': array([], dtype=float64),
#  'Tamera Daugherty': array([], dtype=float64),
#  'Sima Parisay': array([], dtype=float64),
#  'Dan Schrage': [3.6, 0.57, 7.0],
#  'Hossein Hashemi': array([], dtype=float64),
#  'Samuel Mantell': array([], dtype=float64),
#  'Jay Wang': array([], dtype=float64),
#  'Michael Napoliello': array([], dtype=float64),
#  'Miao Zhang': [3.0, 0.63, 8.0],
#  'Mikel Snow': array([], dtype=float64),
#  'Carter Wellford': array([], dtype=float64),
#  'Linda Brown': array([], dtype=float64),
#  'Donald Paul': array([], dtype=float64),
#  "Daniel O'Leary": array([], dtype=float64),
#  'Kimberly Rubal': array([], dtype=float64),
#  'Juli Juteau': array([], dtype=float64),
#  'Nathan Greenfield': [4.5, 0.93, 20.0],
#  'Donna Ghalambor': array([], dtype=float64),
#  'Ashley Hagen': array([], dtype=float64),
#  'Carolann Peterson': array([], dtype=float64),
#  'Shirin Birjandi': array([], dtype=float64),
#  'Elizabeth Johnson': array([], dtype=float64),
#  'Maria Chavez-Courtright': array([], dtype=float64),
#  'Philip Li': array([], dtype=float64),
#  'Lee Olvera': array([], dtype=float64),
#  'Kevin Robinson': array([], dtype=float64),
#  'Jeff Guh': array([], dtype=float64),
#  'Anastassia Tzoytzoyrakos': array([], dtype=float64),
#  'Atiyeh Showrai': array([], dtype=float64),
#  'Wayne Sandholtz': array([], dtype=float64),
#  'Tessa Waterbury Wallace': [3.0, 0.4, 6.0],
#  'Hongqiao Li': array([], dtype=float64),
#  'Mariana Stern': array([], dtype=float64),
#  'Dmitrii Kuznetsov': array([], dtype=float64),
#  'Michael Lieber': array([], dtype=float64),
#  'Mark Chaisson': array([], dtype=float64),
#  'Chris Morocco': array([], dtype=float64),
#  'Ronald Mitchell': array([], dtype=float64),
#  'Robert Dekle': [2.6, 1.0, 22.0],
#  'Carlos Pantano-Rubino': array([], dtype=float64),
#  'Bruce Block': array([], dtype=float64),
#  'Canan Ipek': [4.2, 0.85, 14.0],
#  'Vince Gonzales': array([], dtype=float64),
#  'Julie Marsh': array([], dtype=float64),
#  'Alice Parker': array([], dtype=float64),
#  'Evelyn Boria-Rivera': array([], dtype=float64),
#  'Sarah Katherine Schmaltz': array([], dtype=float64),
#  'Peter Robinson': [4.9, 1.0, 14.0],
#  'Artjoms Kovalovs': array([], dtype=float64),
#  'John Frnka': array([], dtype=float64),
#  'Zahra Nealy': array([], dtype=float64),
#  'Yu-Wei Hsieh': array([], dtype=float64),
#  'Albert Napoli': [4.5, 0.9, 18.0],
#  'Terence Sanger': array([], dtype=float64),
#  'Heejin Cho': array([], dtype=float64),
#  'Karen Tinsley': array([], dtype=float64),
#  'Nicole Johnson': array([], dtype=float64),
#  'Susan Harris': array([], dtype=float64),
#  'Stacey Leasca': array([], dtype=float64),
#  'Darek Oleszkiewicz': array([], dtype=float64),
#  'Helena Yli-Renko': array([], dtype=float64),
#  'Nancy Boley Cruz': array([], dtype=float64),
#  'Stewart Gordon': array([], dtype=float64),
#  'Andres Abeliuk Kimelman': array([], dtype=float64),
#  'Charla Elizabeth': array([], dtype=float64),
#  'Devin Griffiths': [4.0, 0.6, 13.0],
#  'David Goetsch': array([], dtype=float64),
#  'Juli Kirkpatrick': array([], dtype=float64),
#  'Catherine Pond': array([], dtype=float64),
#  'Firdaus Udwadia': [5.0, 1.0, 9.0],
#  'Christine Beckman': array([], dtype=float64),
#  'Dave Lavond': [3.4, 0.63, 51.0],
#  'Daniel Kagan': array([], dtype=float64),
#  'Adam Hughes': array([], dtype=float64),
#  'Sahand Nikoukar': array([], dtype=float64),
#  'Jennifer Treweek': array([], dtype=float64),
#  'Jianfeng Zhang': array([], dtype=float64),
#  'Eric Schmidt': array([], dtype=float64),
#  'Greta Panova': array([], dtype=float64),
#  'Aimee Odette': [5.0, 1.0, 5.0],
#  'John Eatwell': array([], dtype=float64),
#  'Kellie Moore': array([], dtype=float64),
#  'Erika Patall': array([], dtype=float64),
#  'Sharon Merle-Lieberman': array([], dtype=float64),
#  'Victoria Beltran': array([], dtype=float64),
#  'Jessica Ho': array([], dtype=float64),
#  'Peter Sollett': array([], dtype=float64),
#  'Joe Saltzman': array([], dtype=float64),
#  'Terry David Church': array([], dtype=float64),
#  'Vasilis Marmarelis': array([], dtype=float64),
#  'Carol Lin': array([], dtype=float64),
#  'Jennifer Petersen': array([], dtype=float64),
#  'Michael Cameron': array([], dtype=float64),
#  'Robert Ingenito': array([], dtype=float64),
#  'Christian Grose': array([], dtype=float64),
#  'Sarah Anindo Marshall': array([], dtype=float64),
#  'Ilan Rotstein': array([], dtype=float64),
#  'Carolina Garcia': array([], dtype=float64),
#  'Francesca Romana Puggelli': array([], dtype=float64),
#  'Mackenzie Partridge': array([], dtype=float64),
#  'Jeremy Deneau': array([], dtype=float64),
#  'Yuka Kumagai': array([], dtype=float64),
#  'Nayan Shah': [2.5, 0.33, 7.0],
#  'Beverly Neufeld': array([], dtype=float64),
#  'Cynthia Soria': array([], dtype=float64),
#  'Rodney To': array([], dtype=float64),
#  'Ruth Weisberg': array([], dtype=float64),
#  'Nitin Govil': array([], dtype=float64),
#  'William Celis': array([], dtype=float64),
#  'Alan Green': array([], dtype=float64),
#  'Bingen Yang': array([], dtype=float64),
#  'Kiki Benzon': array([], dtype=float64),
#  'Ray Matthews': array([], dtype=float64),
#  'Anne Lagatta': array([], dtype=float64),
#  'Jennifer De La Fuente': array([], dtype=float64),
#  'Sean Bouchard': array([], dtype=float64),
#  'Corinna Schroeder': array([], dtype=float64),
#  'Marion Philadelphia': array([], dtype=float64),
#  'Tom Sloper': [3.3, 0.5, 11.0],
#  'Roumyana Pancheva': array([], dtype=float64),
#  'Kenneth Ahern': array([], dtype=float64),
#  'Stephen Cronin': array([], dtype=float64),
#  'Patricia George': array([], dtype=float64),
#  'Mike Scheibe': array([], dtype=float64),
#  'Elisabeth Raff': array([], dtype=float64),
#  'Dowell Myers': [3.0, 0.67, 12.0],
#  'Amy Merrill-Brugger': array([], dtype=float64),
#  'Dani Byrd': array([], dtype=float64),
#  'Jennifer West': array([], dtype=float64),
#  'Heather Bell': array([], dtype=float64),
#  'Daniel Schnur': array([], dtype=float64),
#  'Alexandra Graddy-Reed': [3.4, 0.4, 5.0],
#  'Judith Franco': array([], dtype=float64),
#  'Susie Cognetta': array([], dtype=float64),
#  'Simon Uwins': array([], dtype=float64),
#  'Jerry Lucido': array([], dtype=float64),
#  'Kendra Walther': [4.4, 0.79, 15.0],
#  'Andy Enfield': array([], dtype=float64),
#  'Dan Erwin': array([], dtype=float64),
#  'Meiying Li': array([], dtype=float64),
#  'John Watson': array([], dtype=float64),
#  'Shalini Gupta': array([], dtype=float64),
#  'Christopher Laine': array([], dtype=float64),
#  'Jae Jung': array([], dtype=float64),
#  'Corinne Hyde': array([], dtype=float64),
#  'Jane Steinberg': array([], dtype=float64),
#  'Doris Sung': array([], dtype=float64),
#  'Morris Levy': [4.8, 1.0, 16.0],
#  'Tyler Quick': array([], dtype=float64),
#  'Jill Kickul': array([], dtype=float64),
#  'Remigijus Mikulevicius': array([], dtype=float64),
#  'Lorena Gallego': [4.5, 0.8, 29.0],
#  'Lucy V Lee': array([], dtype=float64),
#  'Kendra Atkin': array([], dtype=float64),
#  'Sharon Gillerman': array([], dtype=float64),
#  'Meredith Franklin': array([], dtype=float64),
#  'Karen Moss': array([], dtype=float64),
#  'Joseph Semkiu': array([], dtype=float64),
#  'Cha-Chi Fung': array([], dtype=float64),
#  'Guofu Tan': array([], dtype=float64),
#  'Thomas Kemper': array([], dtype=float64),
#  'Andrew MacKay': array([], dtype=float64),
#  'David Treuer': [2.4, 0.31, 13.0],
#  'Anne Postman': array([], dtype=float64),
#  'Mark Redekopp': [4.9, 1.0, 119.0],
#  'David Parrish': array([], dtype=float64),
#  'Courtney Conley': array([], dtype=float64),
#  'Kiros Berhane': array([], dtype=float64),
#  'Neetu Khanna': array([], dtype=float64),
#  'Bret Nielsen': array([], dtype=float64),
#  'Clay Helton': array([], dtype=float64),
#  'Richard Fliegel': array([], dtype=float64),
#  'Brian Rathbun': [4.0, 0.75, 16.0],
#  'Brian Bernards': [4.2, 0.57, 23.0],
#  'Steve Barth': array([], dtype=float64),
#  'Terrence Town': array([], dtype=float64),
#  'Aaron Mazel-Gee': [3.7, 0.57, 14.0],
#  'Koray Yilmaz': array([], dtype=float64),
#  'Marcus Butler': array([], dtype=float64),
#  'Jane Rosenthal': array([], dtype=float64),
#  'Massoud Pirbazari': array([], dtype=float64),
#  'Helane Anderson': array([], dtype=float64),
#  'Amy Yillik': array([], dtype=float64),
#  'Aaron Siegel': array([], dtype=float64),
#  'Eric L Fecht': array([], dtype=float64),
#  'Ralf Haiges': array([], dtype=float64),
#  'Charles Lagreco': array([], dtype=float64),
#  'David Isaacs': array([], dtype=float64),
#  'Matthew Harwood': array([], dtype=float64),
#  'Amy Hodge': array([], dtype=float64),
#  'Jesse Vigil': array([], dtype=float64),
#  'Douglas Burke': [2.4, 0.13, 31.0],
#  'Farida Habeeb': array([], dtype=float64),
#  'Michaela Ullmann': array([], dtype=float64),
#  'Paula Patnoe-Woodley': array([], dtype=float64),
#  'Brenda Goodman': array([], dtype=float64),
#  'James Wind': array([], dtype=float64),
#  'Kathleen Porter': array([], dtype=float64),
#  'Dan Field': array([], dtype=float64),
#  'Jenifer Crawford': array([], dtype=float64),
#  'Andrew Bacon': array([], dtype=float64),
#  'Isabel Wade': array([], dtype=float64),
#  'Elizabeth Harper': array([], dtype=float64),
#  'Michael Parks': array([], dtype=float64),
#  'Sandra Kaplan': array([], dtype=float64),
#  'Tram Sparks': array([], dtype=float64),
#  'Maximo Marin': array([], dtype=float64),
#  'Smrity Randhawa': [4.2, 1.0, 27.0],
#  'Christopher Beam': array([], dtype=float64),
#  'Dana Gioia': [4.4, 0.54, 21.0],
#  'Andrew Norman': array([], dtype=float64),
#  'Virginia Nunez Mir': array([], dtype=float64),
#  'Robert Shrum': array([], dtype=float64),
#  'Gian-Maria Annovi': array([], dtype=float64),
#  'Jason Rosenfield': array([], dtype=float64),
#  'Noriko Yamaguchi': array([], dtype=float64),
#  'Peter Calabrese': array([], dtype=float64),
#  'Michael McNulty': array([], dtype=float64),
#  'Jody Agius Vallejo': array([], dtype=float64),
#  'Jenebah Lewis': array([], dtype=float64),
#  'Luciano Nocera': array([], dtype=float64),
#  'Carolee Winstein': array([], dtype=float64),
#  'Maria Zalewska': array([], dtype=float64),
#  'Eunjin (anna) Kim': array([], dtype=float64),
#  'Sze-Chuan Suen': array([], dtype=float64),
#  'Laura Baker': array([], dtype=float64),
#  'Paul Dapkus': array([], dtype=float64),
#  'Dawn Bray': array([], dtype=float64),
#  'James Dolan': [2.8, 0.58, 54.0],
#  'Karra Bikson': [4.4, 1.0, 20.0],
#  'Emi Minejima': array([], dtype=float64),
#  'Tom Jordan': array([], dtype=float64),
#  'Christina Webb': array([], dtype=float64),
#  'Paul Stern': array([], dtype=float64),
#  'Troy Quinn': array([], dtype=float64),
#  'Corinne Feldman': array([], dtype=float64),
#  'Sarah Axeen': array([], dtype=float64),
#  'Gene Warren III': array([], dtype=float64),
#  'Robert Kozinets': array([], dtype=float64),
#  'David Glasgow': array([], dtype=float64),
#  'David Tsui': array([], dtype=float64),
#  'Duncan Mahoney': array([], dtype=float64),
#  'Monika Wiener': array([], dtype=float64),
#  'Frederick Shaine': array([], dtype=float64),
#  'Harvey Kaslow': array([], dtype=float64),
#  'Joshua Allbright': array([], dtype=float64),
#  'Joel Hay': array([], dtype=float64),
#  'Randy Lake': array([], dtype=float64),
#  'Michael Hurlburt': array([], dtype=float64),
#  'Bahadir Inozu': array([], dtype=float64),
#  'Ed Johnson': array([], dtype=float64),
#  'Marc Choueiti': array([], dtype=float64),
#  'Paul Newton': array([], dtype=float64),
#  'Ratika Narag': [3.0, 0.55, 25.0],
#  'William Feuer': array([], dtype=float64),
#  'Jaclyn Cohen-Steinberg': [4.2, 0.83, 10.0],
#  'Ed Goo': [2.6, 0.38, 22.0],
#  'Natalie Belisle': array([], dtype=float64),
#  'Andrew Campbell': [4.4, 0.75, 8.0],
#  'Stephen Pierce': array([], dtype=float64),
#  'Julie Suh': [4.5, 0.78, 52.0],
#  'Christopher Muniz': [4.8, 0.92, 12.0],
#  'Timothy Chung': array([], dtype=float64),
#  'Trudy Green': array([], dtype=float64),
#  'Bruce Green': array([], dtype=float64),
#  'John Jones': array([], dtype=float64),
#  'Kevin McCorkle': array([], dtype=float64),
#  'Bodour Salhia': array([], dtype=float64),
#  'Laurie Brand': array([], dtype=float64),
#  'Paul Maibaum': array([], dtype=float64),
#  'Ewa Wojciak': array([], dtype=float64),
#  'Jill Johnston': array([], dtype=float64),
#  'Leana Golubchik': array([], dtype=float64),
#  'Rym Kaki': array([], dtype=float64),
#  'Carolin Fleischmann': array([], dtype=float64),
#  'Carolyn Manetti': array([], dtype=float64),
#  'Jennifer Krogh': array([], dtype=float64),
#  'Yuxuan Shao': array([], dtype=float64),
#  'Elizabeth Ramsey': array([], dtype=float64),
#  'Jean Lantz': array([], dtype=float64),
#  'Daniel Carlin': array([], dtype=float64),
#  'Sathyanaraya Raghavachary': array([], dtype=float64),
#  'Nathanael Fast': array([], dtype=float64),
#  'Genevieve Giuliano': array([], dtype=float64),
#  'Jonathan Kotler': array([], dtype=float64),
#  'Fred Cook': array([], dtype=float64),
#  'Bart Kosko': array([], dtype=float64),
#  'Zune Nguyen': [5.0, 1.0, 12.0],
#  'Shelley Smith': array([], dtype=float64),
#  'Ansgar Siemer': array([], dtype=float64),
#  'Yaphett Powell': array([], dtype=float64),
#  'James McHugh': array([], dtype=float64),
#  'Tomoaki Hayashi': array([], dtype=float64),
#  'Nimfa Bemis': [3.5, 0.44, 150.0],
#  'Christopher Harrer': array([], dtype=float64),
#  'Daniel Birman': array([], dtype=float64),
#  'Kornelia Kulig': array([], dtype=float64),
#  'Christian Redfearn': array([], dtype=float64),
#  'Janos Peti Peterdi': array([], dtype=float64),
#  'Gayla Margolin': array([], dtype=float64),
#  'Constantine Sideris': array([], dtype=float64),
#  'Tien Ng': array([], dtype=float64),
#  'William Feuerborn': array([], dtype=float64),
#  'Lee Schneider': array([], dtype=float64),
#  'Rachel Fried': array([], dtype=float64),
#  'Jean Ho': array([], dtype=float64),
#  'Sayd Randle': array([], dtype=float64),
#  'Yvonne Marchand': array([], dtype=float64),
#  'Seon Kim': array([], dtype=float64),
#  'Kian Kaviani': array([], dtype=float64),
#  'Laurence Wong': array([], dtype=float64),
#  'Michael Garcia': array([], dtype=float64),
#  'Nicole Esparza': array([], dtype=float64),
#  'Jakub Hlavka': array([], dtype=float64),
#  'Matthew Stevens': array([], dtype=float64),
#  'Alexander Sawchuk': array([], dtype=float64),
#  'Robert Chow': array([], dtype=float64),
#  'Herb Perlmutter': array([], dtype=float64),
#  'Karen North': array([], dtype=float64),
#  'Lindsey Bier': [3.7, 0.57, 14.0],
#  'Alan Nelson': [3.3, 0.5, 6.0],
#  'Gilberto Gutierrez': array([], dtype=float64),
#  'Eric Haas': array([], dtype=float64),
#  'Simon Coke': array([], dtype=float64),
#  'Ali Zadeh': array([], dtype=float64),
#  'Mike Brennan': array([], dtype=float64),
#  'Eliz Sanasarian': [3.9, 0.67, 29.0],
#  'Yves Declerck': array([], dtype=float64),
#  'Cesar Armendariz': [4.5, 1.0, 11.0],
#  'Edgar Landa': array([], dtype=float64),
#  'Charles Mc Kenna': array([], dtype=float64),
#  'Spencer Couts': array([], dtype=float64),
#  'Jang-Hyun Youn': array([], dtype=float64),
#  'Omid Akbari': array([], dtype=float64),
#  'Kathleen Becker': array([], dtype=float64),
#  'Robert Lu': array([], dtype=float64),
#  'Mark Borenstein': array([], dtype=float64),
#  'Sharon Carnicke': [3.3, 0.2, 12.0],
#  'David Hutkin': array([], dtype=float64),
#  'Davide Proserpio': [3.8, 0.92, 12.0],
#  'Costas Synolakis': [2.8, 0.33, 6.0],
#  'John Perfitt': array([], dtype=float64),
#  'Stephen Byars': [4.2, 0.71, 22.0],
#  'Susie Kim': array([], dtype=float64),
#  'Yalda Khashe': array([], dtype=float64),
#  'Marsha Riggio': array([], dtype=float64),
#  'Natania Meeker': array([], dtype=float64),
#  'Dr. Dora Kingsley Vertenten': array([], dtype=float64),
#  'Paulo Branicio': [4.6, 0.92, 13.0],
#  'Susan Hess': array([], dtype=float64),
#  'Gary Painter': array([], dtype=float64),
#  'Juan Carrillo': array([], dtype=float64),
#  'Beth Meyerowitz': array([], dtype=float64),
#  'Yongxiang Wang': [2.6, 0.6, 15.0],
#  'James Deiner': array([], dtype=float64),
#  'Kristine Garroway': array([], dtype=float64),
#  'Annette Kim': array([], dtype=float64),
#  'Jorge De La Roca': array([], dtype=float64),
#  'John Mutlow': array([], dtype=float64),
#  'Paul Wong': array([], dtype=float64),
#  'David Lucero': array([], dtype=float64),
#  'Ashley York': array([], dtype=float64),
#  'Robert Ley': array([], dtype=float64),
#  'Mike Zyda': array([], dtype=float64),
#  'Lata Pandya': array([], dtype=float64),
#  'Leah Hanzlicek': [4.1, 0.6, 8.0],
#  'Kim Goodman': array([], dtype=float64),
#  'Kadri Vihvelin': array([], dtype=float64),
#  'Lindsey Plato-Johnson': array([], dtype=float64),
#  'Sean Nye': [3.6, 0.68, 35.0],
#  'Birendra Jha': array([], dtype=float64),
#  'Douglas Becker': [3.8, 0.75, 41.0],
#  'Lance Winkel': [3.3, 0.4, 6.0],
#  'Herag Haleblian': array([], dtype=float64),
#  'Jeremy Kagan': array([], dtype=float64),
#  'Kerim Yasar': array([], dtype=float64),
#  'Barnet Kellman': array([], dtype=float64),
#  'Mary Looman': array([], dtype=float64),
#  'Glenn Clark': array([], dtype=float64),
#  'Terance Wolfe': array([], dtype=float64),
#  'Cynthia Mori': array([], dtype=float64),
#  'Marisa Mandler': [3.7, 0.6, 6.0],
#  'Tyson Roberts': [2.7, 0.6, 10.0],
#  'Cesar Acosta-Mejia': array([], dtype=float64),
#  'Emma Jackson': array([], dtype=float64),
#  'Yang Chai': array([], dtype=float64),
#  'Kazuo Takeda': [2.3, 0.29, 19.0],
#  'Eunice Humphrey': array([], dtype=float64),
#  'Jennifer Hogan': array([], dtype=float64),
#  'Woojin An': array([], dtype=float64),
#  'Steven Sussman': array([], dtype=float64),
#  'Janet Batchler': array([], dtype=float64),
#  'Caroline Muglia': array([], dtype=float64),
#  'Janet Hoskins': array([], dtype=float64),
#  'Elizabeth Falletta': array([], dtype=float64),
#  'Joselito Seldera': array([], dtype=float64),
#  'Katherine Guevara': array([], dtype=float64),
#  'Zeynep Ertem': array([], dtype=float64),
#  'Tom Peterson': array([], dtype=float64),
#  'Anthony Anderson': array([], dtype=float64),
#  'Lisa Leeman': array([], dtype=float64),
#  'Bill Holder': array([], dtype=float64),
#  'Ming-Deh Huang': array([], dtype=float64),
#  'Antonio Elefano': [4.8, 1.0, 18.0],
#  'Elaine Zhong': array([], dtype=float64),
#  'Rebecca Lonergan': array([], dtype=float64),
#  'Mary Traester': array([], dtype=float64),
#  'Jeffrey Dubin': array([], dtype=float64),
#  'Jacob Ross': [3.1, 0.75, 58.0],
#  'Anahit Hakoupian': [4.7, 0.8, 22.0],
#  'Nenad Medvidovic': [3.7, 0.65, 59.0],
#  'Emily Zeamer': [3.1, 0.17, 7.0],
#  'Diane Ghirardo': array([], dtype=float64),
#  'Raymond Gallagher': array([], dtype=float64),
#  'Judith Shelton': array([], dtype=float64),
#  'Kristy Payne': array([], dtype=float64),
#  'Aiichiro Nakano': array([], dtype=float64),
#  'Steven Lamy': [4.0, 0.88, 93.0],
#  'Jacquelyn Bsharah': array([], dtype=float64),
#  'Yasemin Yilmaz': array([], dtype=float64),
#  'Sheila Banuelos': array([], dtype=float64),
#  'Douglas Bender': array([], dtype=float64),
#  'Daniel Richter': [3.1, 0.64, 47.0],
#  'Ryan Park': array([], dtype=float64),
#  'Antonio Bento': array([], dtype=float64),
#  'Amanda Ingalls': array([], dtype=float64),
#  'Victoria Lanclos': array([], dtype=float64),
#  'Margaret Chidester': array([], dtype=float64),
#  'Paul Sparks': array([], dtype=float64),
#  'Enrique Cadenas': array([], dtype=float64),
#  'Deborah Hazelton': array([], dtype=float64),
#  'Jian Xu': array([], dtype=float64),
#  'Renee Michelsen': array([], dtype=float64),
#  'Kevin Lohenry': array([], dtype=float64),
#  'Kathryn Havens': array([], dtype=float64),
#  'Ken-Ichi Nomura': array([], dtype=float64),
#  'Claire Peeps': array([], dtype=float64),
#  'Kevin Nash': array([], dtype=float64),
#  'Vincent Womack': array([], dtype=float64),
#  'Katie Marsh': array([], dtype=float64),
#  'Peggy Farnham': array([], dtype=float64),
#  'Kat Superfisky': array([], dtype=float64),
#  'Kristen Mc Gregor': array([], dtype=float64),
#  'Anupam Madhukar': array([], dtype=float64),
#  'Manuel Monge': array([], dtype=float64),
#  'Gary Cohn': array([], dtype=float64),
#  'Cecil Jackson': [3.7, 0.7, 29.0],
#  'Nina Rathbun': [3.8, 0.55, 24.0],
#  'David Moore': array([], dtype=float64),
#  'Samuel Mistrano': array([], dtype=float64),
#  'Michael Press': array([], dtype=float64),
#  'Michael Jakowec': array([], dtype=float64),
#  'Khalil Iskarous': array([], dtype=float64),
#  'Clayton Stephenson': [2.8, 0.27, 31.0],
#  'Viannda Hawkins': array([], dtype=float64),
#  'Megan McCain': array([], dtype=float64),
#  'Laurel Felt': array([], dtype=float64),
#  'Howard Williamson': array([], dtype=float64),
#  'Tin-Yu Tseng': array([], dtype=float64),
#  'Michael Bonaguidi': array([], dtype=float64),
#  'P T McNiff': array([], dtype=float64),
#  'Gordon Stables': [4.4, 1.0, 16.0],
#  'Vishnu Sridharan': array([], dtype=float64),
#  'Julian Domaradzki': array([], dtype=float64),
#  'Meredith Lepley': array([], dtype=float64),
#  'Benjamin Weiss': array([], dtype=float64),
#  'Geza Bottlik': array([], dtype=float64),
#  'Laura Riley': array([], dtype=float64),
#  'Emily Anderson': [4.6, 1.0, 24.0],
#  'John Matsusaka': array([], dtype=float64),
#  'Marcel Valcarce': array([], dtype=float64),
#  'Nicholas Merkin': array([], dtype=float64),
#  'Ian Fusselman': array([], dtype=float64),
#  'Ronald Christie': array([], dtype=float64),
#  'Courtney Brunious': array([], dtype=float64),
#  'James Boedicker': array([], dtype=float64),
#  'Ann Klenk': array([], dtype=float64),
#  'Antoine Bechara': array([], dtype=float64),
#  'Tom Sito': [4.8, 1.0, 14.0],
#  'Dawn Stoppiello': array([], dtype=float64),
#  'Megan Herrold': array([], dtype=float64),
#  'Martha Lyon-Levine': array([], dtype=float64),
#  'Albert Herrera': [3.2, 0.65, 95.0],
#  'Melissa Singh': array([], dtype=float64),
#  'Amy Cannon': [4.8, 1.0, 6.0],
#  'Dan Simon': array([], dtype=float64),
#  'Stephen Child': array([], dtype=float64),
#  'Callie Siskel': array([], dtype=float64),
#  'Yen-Hsiang Nieh': array([], dtype=float64),
#  'Kenneth Foster': array([], dtype=float64),
#  'Stefanos Nikolaidis': array([], dtype=float64),
#  'Christopher Chomyn': array([], dtype=float64),
#  'Mary Baron': array([], dtype=float64),
#  'Bangyan Stiles': array([], dtype=float64),
#  'Donald Arnold': array([], dtype=float64),
#  'Brandy Chappell': array([], dtype=float64),
#  'Sofia Reddy': array([], dtype=float64),
#  'Amy Lee': array([], dtype=float64),
#  'Yael Wolinsky-Nahmias': array([], dtype=float64),
#  'Steven Heilman': [3.4, 0.67, 9.0],
#  'Jennifer Tran': array([], dtype=float64),
#  'Bruce McCormick': array([], dtype=float64),
#  'James Thrash': array([], dtype=float64),
#  'Michael Palacios': array([], dtype=float64),
#  'Richard Dang': array([], dtype=float64),
#  'Kristen Zaleski': array([], dtype=float64),
#  'Mark Pearson': array([], dtype=float64),
#  'Anamara Ritt': array([], dtype=float64),
#  'Eric Canny': array([], dtype=float64),
#  'Amy Schroeder': [4.5, 0.92, 16.0],
#  'Dale Kiefer': [2.1, 0.46, 30.0],
#  'John Pascarella': array([], dtype=float64),
#  'Jon Kroll': array([], dtype=float64),
#  'Robertas Gabrys': [2.7, 0.23, 46.0],
#  'Trina Gregory': [4.2, 0.86, 21.0],
#  'Bob Mintzer': array([], dtype=float64),
#  'Ernest Greene': [3.0, 0.33, 23.0],
#  'Woodie Tescher': array([], dtype=float64),
#  'Nicolai Haydn': [2.7, 0.5, 19.0],
#  'Stephanie Bower': array([], dtype=float64),
#  'Arnold Tiber': array([], dtype=float64),
#  'Stephan Ray': array([], dtype=float64),
#  'Jennifer Ramos': array([], dtype=float64),
#  'Lauren Hamer': array([], dtype=float64),
#  'Jason Glenn': array([], dtype=float64),
#  'Piedad Suarez': array([], dtype=float64),
#  'Armand Tanguay': [3.7, 0.8, 21.0],
#  'Christopher Gould': [2.3, 0.08, 63.0],
#  'Cruz Arroyo': array([], dtype=float64),
#  'Jae Deal': array([], dtype=float64),
#  'Amber Foster': array([], dtype=float64),
#  'Afroditi Angelopoulou': array([], dtype=float64),
#  'Kc Wayland': array([], dtype=float64),
#  'Alexa Alemanni': array([], dtype=float64),
#  'Eric Medrano': array([], dtype=float64),
#  'Danielle Brown': array([], dtype=float64),
#  'Susan McCabe': array([], dtype=float64),
#  'Diane Kim': array([], dtype=float64),
#  'Christopher Shaw': array([], dtype=float64),
#  'Phyllis Pollack': array([], dtype=float64),
#  'Donald Yett': array([], dtype=float64),
#  'Tamar Gregorian': array([], dtype=float64),
#  'Roy Quintero': array([], dtype=float64),
#  'Eric Shen': array([], dtype=float64),
#  'Justin Hoyt': array([], dtype=float64),
#  'Cathy Krop': array([], dtype=float64),
#  'Courtney Rotz': array([], dtype=float64),
#  'Brandon Jeffords': array([], dtype=float64),
#  'Joshua Aizenman': array([], dtype=float64),
#  'Simon Blessenohl': array([], dtype=float64),
#  'Mary Byram Washburn': [3.7, 0.75, 25.0],
#  'Debbie Murad': array([], dtype=float64),
#  'Susan Berg': array([], dtype=float64),
#  'Martzi Campos': array([], dtype=float64),
#  'Musa Brooker': array([], dtype=float64),
#  'Teresa Norris': array([], dtype=float64),
#  'Kelly Rawlings': array([], dtype=float64),
#  'Darryl Brown': array([], dtype=float64),
#  'Christopher Smith': [4.3, 0.83, 11.0],
#  'Sarah Bottjer': array([], dtype=float64),
#  'Xiang Jian': array([], dtype=float64),
#  'Laura Castaneda': array([], dtype=float64),
#  'Elham Radan': array([], dtype=float64),
#  'Kyung Moon Hwang': array([], dtype=float64),
#  'Anne Desalvo': array([], dtype=float64),
#  'Karen Tongson': [3.8, 0.6, 8.0],
#  'Melissa Durham': array([], dtype=float64),
#  'Michael Thom': array([], dtype=float64),
#  'Cara Mullio': array([], dtype=float64),
#  'Carl Meyer': array([], dtype=float64),
#  'Francesca Mariani': array([], dtype=float64),
#  'Jeanmarie Bouteiller': array([], dtype=float64),
#  'Christina Belcher': array([], dtype=float64),
#  'Reine-Claire Dousarkissian': array([], dtype=float64),
#  'Nicole Maccalla': array([], dtype=float64),
#  'Viola Lasmana': array([], dtype=float64),
#  'Kai Chen': array([], dtype=float64),
#  'Janet Semple-Hess': array([], dtype=float64),
#  'Mark Marino': array([], dtype=float64),
#  'Ulrich Neumann': array([], dtype=float64),
#  'Rebecca Lundeen': array([], dtype=float64),
#  'Chris Roze': array([], dtype=float64),
#  'Alexis Camacho': array([], dtype=float64),
#  'Vincent Lee': [1.6, 0.33, 11.0],
#  'Colleen McQuillen': array([], dtype=float64),
#  'Xochitl Ruiz': array([], dtype=float64),
#  'Sean Friar': array([], dtype=float64),
#  'Michael Mische': [4.2, 0.67, 53.0],
#  'Julianna Kirschner': array([], dtype=float64),
#  'Julie Cederbaum': array([], dtype=float64),
#  'John Tower': array([], dtype=float64),
#  'Paul Orlando': [4.2, 0.8, 5.0],
#  'Mandong Liu': array([], dtype=float64),
#  'Jason Cozby': array([], dtype=float64),
#  'William Simmons': array([], dtype=float64),
#  'Bhaskar Krishnamachari': array([], dtype=float64),
#  'Sarah Frontiera': array([], dtype=float64),
#  'Anthony Dimario': array([], dtype=float64),
#  'Joseph Cortez': array([], dtype=float64),
#  'Patrick Murphy': array([], dtype=float64),
#  'Cynthia Mosqueda': array([], dtype=float64),
#  'Paul Hungerford': array([], dtype=float64),
#  'Stan Yamashiro': array([], dtype=float64),
#  'Paula Cizmar': array([], dtype=float64),
#  'Nazam Nageer': array([], dtype=float64),
#  'Gabriel Uzquiano': array([], dtype=float64),
#  'Lirong Yan': array([], dtype=float64),
#  'Heather Fogarty': array([], dtype=float64),
#  'Vishal Patel': array([], dtype=float64),
#  'Nitin Kale': [4.6, 1.0, 20.0],
#  'Yanhao Wei': [4.1, 0.86, 7.0],
#  'Edwin Hill': array([], dtype=float64),
#  'Alexander McDowell': array([], dtype=float64),
#  'Steve Lund': [3.0, 0.39, 19.0],
#  'Robert H Hill': array([], dtype=float64),
#  'Gregg Daniel': array([], dtype=float64),
#  'Jessica Marglin': array([], dtype=float64),
#  'Aimee Aguillon': array([], dtype=float64),
#  'Emily Nix': [4.5, 1.0, 11.0],
#  'Melissa Robinson': array([], dtype=float64),
#  'Paul Hodgins': array([], dtype=float64),
#  'Gary Blackard': array([], dtype=float64),
#  'Scott Malzahn': array([], dtype=float64),
#  'Min Yu': array([], dtype=float64),
#  'Leonard Wilson': array([], dtype=float64),
#  'Sharon Lloyd': [4.0, 1.0, 24.0],
#  'Marcus Anderson': array([], dtype=float64),
#  'Andrea Hollingshead': array([], dtype=float64),
#  'Jim Huntley': array([], dtype=float64),
#  'Kirstin Eggers': array([], dtype=float64),
#  'Lisa Klerman': array([], dtype=float64),
#  'Larry Livingston': array([], dtype=float64),
#  'Patty Chang': array([], dtype=float64),
#  'Maria Mercedes Fages Agudo': [5.0, 1.0, 14.0],
#  'Sherin Guirguis': array([], dtype=float64),
#  'Gilbert Zimmerman': array([], dtype=float64),
#  'Cynthia Sanchez': array([], dtype=float64),
#  'Lupe Arevalo': array([], dtype=float64),
#  'Miller Fong': array([], dtype=float64),
#  'Mary Gallagher': array([], dtype=float64),
#  'Edward Maby': [3.2, 0.17, 16.0],
#  'Cheryl MacOn-Oliver': array([], dtype=float64),
#  'Jonathan Mullins': array([], dtype=float64),
#  'Sally Ramirez': array([], dtype=float64),
#  'James Diewald': array([], dtype=float64),
#  'Ram Nevatia': array([], dtype=float64),
#  'Rita Burke': array([], dtype=float64),
#  'Frank Catalano': array([], dtype=float64),
#  'Marlon Boarnet': array([], dtype=float64),
#  'Justin Ichida': array([], dtype=float64),
#  'Ruth Ann Supranovich': array([], dtype=float64),
#  'Sri Narayan': array([], dtype=float64),
#  'Elizabeth Brauer': array([], dtype=float64),
#  'Artineh Samkian': array([], dtype=float64),
#  'Russell Gould': array([], dtype=float64),
#  'Robert Nashak': array([], dtype=float64),
#  'Parul Bhatia': array([], dtype=float64),
#  'Zivia Wilson Sweeney': array([], dtype=float64),
#  'John Lee': array([], dtype=float64),
#  'Frederick Freking': array([], dtype=float64),
#  'Michelle Winfield': array([], dtype=float64),
#  'Roger Clemens': array([], dtype=float64),
#  'Greys Sosic': array([], dtype=float64),
#  'Marc Ballon': array([], dtype=float64),
#  'Stacy Kratz': [4.8, 1.0, 24.0],
#  'John Brennan': array([], dtype=float64),
#  'Dain Blanton': array([], dtype=float64),
#  'Margo Apostolos': [4.3, 1.0, 25.0],
#  'Stephen Lovejoy': array([], dtype=float64),
#  'William Whittington': array([], dtype=float64),
#  'Scott Tennant': array([], dtype=float64),
#  'Sarah Hamm-Alvarez': array([], dtype=float64),
#  'Kathryn Dunn': array([], dtype=float64),
#  'Sean Galliher': array([], dtype=float64),
#  'Daniel Park': array([], dtype=float64),
#  'Doe Mayer': array([], dtype=float64),
#  'Sara Catania': array([], dtype=float64),
#  'Richard Vawter': array([], dtype=float64),
#  'Keith Morel': array([], dtype=float64),
#  'Gabriel Crenshaw': array([], dtype=float64),
#  'Kevin Forrester': array([], dtype=float64),
#  'Eric Webb': array([], dtype=float64),
#  'Anthony Taranto': array([], dtype=float64),
#  'Ira Kalb': [3.5, 0.56, 109.0],
#  'Jayanth Kudva': array([], dtype=float64),
#  'Allissa Richardson': array([], dtype=float64),
#  'William Patton': array([], dtype=float64),
#  'Omar El Sawy': array([], dtype=float64),
#  'Laura Nicoara': array([], dtype=float64),
#  'Lee Cerling': array([], dtype=float64),
#  ...}
