# %%
import requests
import os,json
from os.path import join, isdir
from pprint import pprint
import itertools as it
import dask
import re
from bs4 import BeautifulSoup
import string

# %%
class SoCInterface:
    def __init__(self):
        self.SoCPrefix = 'http://web-app.usc.edu/web/soc/api' 
    '''
    get the list of active instructors of the given semester. 
    Take ~10 secs to run [7.62 s ± 545 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)]
    parameter: 
        semester, str, for instance: '20193' (2019 Fall)
    return:
        prof name, set, for instance: {(first, last), (first, last)...}
    '''
    def get_all_instructors(self, semester):
        url = '/'.join([self.SoCPrefix,'depts', semester]) # form a valid url
        schoolList = self.__make_request(url)['department']
        deptList = list(map(self.__dept_extractor, schoolList)) 
        deptList = list(it.chain.from_iterable(deptList)) # flatten the data structure, [{code:csci, name:comp science},{}]
        # now use get instructor info (multithreading)
        multithreader = [ dask.delayed(self.__get_dept_course)(dept,semester) for dept in deptList]
        # flattened result
        return list(set(list(it.chain.from_iterable(dask.compute(*multithreader, scheduler = 'threads',num_workers=12))) ))

    #---------------------------
    # private helpers 
    '''
    retrieve information from the given url 
    parameter:
        url: a valid url 
    return:
        a json file 
    '''
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.json()
    '''
    extract department names
    parameter: 
        dictionary: a dictionary of school information
    return:
        a list of departments under the given school, list of str
    '''
    def __dept_extractor(self, dictionary):
        try:
            if type(dictionary['department']) == list:
                return dictionary['department']
            else:
                return [dictionary['department']] # some school only has one department 
        except:
            return [dictionary] # some school might not have sub-department
    '''
    extract course information 
    parameter: 
        courseData: dictionary generated by __get_dept_course
    return:
        list of intructors of an given class, list of tuple
    '''
    def __course_extractor(self, courseData):
        if courseData['canceled'] == 'Y' or courseData['canceled'] == 'y':
            return []# return an empty dict if the session is cancled
        if 'instructor' in courseData:
            if type(courseData['instructor']) == dict: # mutiple instructors
                return [(courseData['instructor']['first_name'], courseData['instructor']['last_name']) ]
            else: # multiple prof for the same section
                return [(prof['first_name'], prof['last_name']) for prof in courseData['instructor']]
        else:
            return []
        
    '''
    get all courses under the same department
    parameter: 
        deptInfo, dictionary generated by getAllInstructors
        semester, str, for instance: '20193' (2019 Fall)
    return: a list of professors under the given department, a list of tuple
    '''
    def __get_dept_course(self,deptInfo, semester):
        url = '/'.join([self.SoCPrefix,'classes' ,deptInfo['code'], semester])
        courseList = self.__make_request(url)['OfferedCourses']['course']
        if type(courseList) == dict: # some dept has only one course
            courseList = [courseList]
        profList = []
        for course in courseList: 
            if type(course['CourseData']['SectionData']) == dict:  # some course has only one session
                profList += [self.__course_extractor(course['CourseData']['SectionData'])]
            else:
                profList += list(map(self.__course_extractor, course['CourseData']['SectionData']))
        return list(it.chain.from_iterable(profList)) # flatten the list

# %%
class RMPInterface:
    def __init__(self, outDir):
        if not isdir(outDir):
            os.mkdir (outDir)
        self.outDir = outDir
        self.RMPPrefix = 'https://www.ratemyprofessors.com'
        self. queryBody = '/search.jsp?queryoption=HEADER&queryBy=teacherName&schoolName=University+of+Southern+California&schoolID=1381&query='
    def update_prof_DB(self, profList):
        multithreader = [ dask.delayed(self.__get_prof_info)(prof) for prof in profList]
        profScoreList = list(dask.compute(*multithreader, scheduler = 'threads'))
        profScoreList = list (filter (lambda profInfo: len(profInfo)>0, profScoreList))
        with open(join(outDir,'profScoreDB.json'), 'w') as outfile:
            json.dump(dict(profScoreList), outfile)
        
    '''    
    retrieve information about the given professor
    parameter:
        profName, tuple, (first name, last name)
    return: 
        information about the prof, tuple, for instance:
        (name, {department name 1: (score, # of raters), department name 2: (score, # of raters)}) 
        a name may have several departments because people may have the same name
    '''
    def __get_prof_info(self, profName):
        url = ''.join([self.RMPPrefix,self.queryBody,'+'.join(profName)])
        profListPage = BeautifulSoup(self.__make_request(url), 'html.parser')
        relatedProf = {}
        for listings in  profListPage.find_all('li', {'class':'listing PROFESSOR'}):
            profUrl = self.RMPPrefix + listings.find('a', href=True)['href']# link to prof's individual page
            dept = listings.find('span', attrs = {'class':'sub'}).text.split(',')[-1]
            profInfoPage = BeautifulSoup(self.__make_request(profUrl), 'html.parser')
            rateTuple = self.__extract_prof_info(profInfoPage)
            if rateTuple != tuple(): # in case no information found 
                relatedProf[dept] = rateTuple
        
        if len(relatedProf) >0 :
            return (' '.join(profName), relatedProf)
        else:
            return () # no associate prof. 
    '''
    make request and return text data
    parameter:
        url: a valid url pointing to RMP pages
    return:
        web content, str
    '''
    def __make_request(self, url):
        try:
            response = requests.post(url)
        except: # in case of time-out, reconnect
            response = requests.post(url)
        return response.text
    
    def __extract_prof_info(self, profInfoPage):
        try:
            score = profInfoPage.find('div', {'class': 'grade'}).text # get avg. RMP score
            # get num of rater
            raterNum = re.findall(r'\b\d+\b',profInfoPage.find('div', {'class': 'table-toggle rating-count active'}).text)
            return (float(score), int(raterNum[0]))
        except:
            return ()

# %%
# %%time
gateway = SoCInterface()
profs = gateway.get_all_instructors('20193')

gateway = RMPInterface('./tempStorage/')
profDict = gateway.update_prof_DB(profs)
#gateway.update_prof_DB([('aaron', 'cote'), ('Andrew', 'Goodney'), ('Olivera', 'Grujic'), ('Mahdi', 'Soltanolkotabi')])
# Out:
# working on:  ('Stephen', 'Child')
# working on: working on:  ('Irene', 'Chiolo')
#  ('Brijesh', 'Pinto')
# working on:  ('Lance', 'Winkel')
# working on:  ('Rebecca', 'Ehrhardt')
# working on:  ('David', 'Hutchins')
# working on:  ('David', 'Albertson')
# working on:  ('Shana', 'Kraynak')
# working on:  ('Dion', 'Jackson')
# working on:  ('Nicole', 'Esparza')
# working on:  ('Juan', 'Carrillo')
# working on:  ('Anna', 'Arabyan')
# working on:  ('Karra', 'Bikson')
# working on:  ('Ram', 'Nevatia')
# working on:  ('William', 'Celis')
# working on:  ('M G', 'Lord')
# working on:  ('Bill', 'Biersach')
# working on:  ('Mansour', 'Rostami')
# working on:  ('Anna', 'Farzindar')
# working on:  ('Sung-Hwa', 'Park')
# working on:  ('Stefan', 'Pollack')
# working on:  ('Takahiro', 'Sakai')
# working on:  ('Hector', 'Reyes')
# working on:  ('Brent', 'Blair')
# working on:  ('Judith', 'Hirsch')
# working on:  ('Carol', 'Muske-Dukes')
# working on:  ('Leah', 'Pate')
# working on:  ('Peter', 'Holzhauer')
# working on:  ('David', 'Bringhurst')
# working on:  ('Jennifer', 'Miller')
# working on:  ('Jill', 'Davis')
# working on:  ('Sharon', 'Lloyd')
# working on:  ('Isabelle', 'Pilliere Mazumdar')
# working on:  ('David', 'Caron')
# working on:  ('William', 'Frank')
# working on:  ('David', 'Schwartz')
# working on:  ('Aaron', 'Serfaty')
# working on:  ('Hok Chio (mark)', 'Lai')
# working on:  ('Joseph', 'Greenfield')
# working on:  ('Diana', 'Blaine')
# working on:  ('Jason', 'Glenn')
# working on:  ('Dawn', 'Porter')
# working on:  ('Emily', 'Artiano')
# working on:  ('Kristin', 'Diehl')
# working on:  ('Maurice', 'Rahimi')
# working on:  ('China', 'Adams')
# working on:  ('Rand', 'Wilcox')
# working on:  ('Lucienne', 'Aarsen')
# working on:  ('Kirby', 'Farah')
# working on:  ('Nicolas', 'Duquette')
# working on:  ('Gaurav', 'Sukhatme')
# working on:  ('Yaffa', 'Weisman')
# working on:  ('Cymra', 'Haskell')
# working on:  ('James', 'McHugh')
# working on:  ('Mariana', 'Stern')
# working on:  ('Rena', 'Heinrich')
# working on:  ('Christopher', 'Sampson')
# working on:  ('Itzhak', 'Bars')
# working on:  working on:  ('Bruce', 'Brown')
# ('Jeffrey', 'Smith')
# working on:  ('Emily', 'Zeamer')
# working on:  ('Britta', 'Bothe')
# working on:  ('Deanna', 'Rivera')
# working on:  ('Andrew', 'Murr')
# working on:  ('Andrea', 'Witkin')
# working on:  ('Lee', 'Cerling')
# working on:  ('Julie', 'Albright')
# working on:  ('Timothy', 'Pescatello')working on:  ('Everett', 'Lewis')
#
# working on:  ('Jeffrey', 'Russell')
# working on:  ('Feng', 'Chen')
# working on:  ('Tina', 'Fietsam')
# working on:  ('David', 'Gerber')working on:  ('Michal', 'Sela-Amit')
#
# working on:  ('Nancy', 'Castro')
# working on:  ('Kim', 'Finney')
# working on:  ('Maria Mercedes', 'Fages Agudo')
# working on:  ('Mark', 'Thompson')
# working on:  ('Eugenia', 'Mora-Flores')
# working on:  ('Oscar', 'Aparicio')
# working on:  ('Jeffrey', 'Weaver')
# working on:  ('Raffaella', 'Ghittoni')
# working on:  ('Rose', 'Layton')
# working on:  ('Megan', 'Becker')
# working on:  ('Julie', 'Cederbaum')
# working on: working on:   ('Carolina', 'Castillo Larrea')('Yu-Wei', 'Hsieh')
#
# working on:  ('Rodney', 'To')
# working on:  ('Muhammad', 'Sahimi')
# working on:  ('Ali', 'Zahid')
# working on:  ('Jonathan', 'Taylor')
# working on:  ('Petros', 'Ioannou')
# working on:  ('Vanessa', 'Osborne')
# working on:  ('Patrick', 'Dent')
# working on:  ('Clark', 'Hansen')
# working on:  ('Alex', 'Jablonski')
# working on:  ('Brendan', 'Pawlowski')
# working on:  ('Arianna', 'Uhalde')
# working on:  ('Shieva', 'Kleinschmidt')
# working on:  ('Benjamin', 'Pack')
# working on:  ('Dan', 'Simon')
# working on:  ('Janet', 'Hoskins')
# working on:  ('Kenneth', 'Ahern')
# working on:  ('Cavan', 'Concannon')
# working on:  ('Paul', 'Bader')
# working on:  ('Natania', 'Meeker')
# working on:  ('Irving', 'Biederman')
# working on:  ('Craig', 'Stanford')
# working on:  ('Brett', 'Gordon')
# working on:  ('Saleemah', 'Knight')
# working on:  ('Ashley', 'Karlin')
# working on:  ('Robert', 'Guralnick')
# working on:  ('Kirstin', 'Eggers')
# working on:  ('Mike', 'Gruntman')
# working on:  ('Kate', 'Jacobs')
# working on:  ('Jinchi', 'Lv')
# working on:  ('Guillermo', 'Reyes Souto')
# working on:  ('Bingen', 'Yang')
# working on:  ('Julian', 'Domaradzki')
# working on:  ('Maria', 'Hu')
# working on:  ('Darby', 'Walters')
# working on:  ('David', 'Black')
# working on:  ('Aimee', 'Odette')
# working on:  ('Cheng', 'Hsiao')
# working on:  ('John', 'Carlsson')
# working on:  ('Marjorie', 'Becker')
# working on:  ('Valery', 'Fokin')
# working on:  ('Dave', "O'Brien")
# working on:  ('Maria', 'Salnikova')
# working on:  ('Gerald', 'Hintz')
# working on:  ('Gordon', 'Stables')
# working on:  ('Daniel', 'Pecchenino')
# working on:  ('Kevin', 'Fields')
# working on:  ('Janna', 'Wong')
# working on:  ('Julia', 'Plotts')
# working on:  ('William', 'Breland')
# working on:  ('Wen', 'Sun')
# working on:  ('Anthony', 'Maddox')
# working on:  ('Stanley', 'Huey')
# working on:  ('Gabriel', 'Uzquiano')
# working on:  ('Anita', 'Penkova')
# working on:  ('James', 'Dolan')
# working on:  ('James', 'Leonetti')
# working on:  ('Joshua', 'West')
# working on:  ('Lynn', 'Dodd')
# working on:  ('Karen', 'Liebowitz')
# working on:  ('Nitin', 'Kale')
# working on:  ('Steven', 'Heilman')
# working on:  ('Sim', 'Sarna')
# working on:  ('Elizabeth', 'Swart')
# working on:  ('Steve', 'Barth')
# working on:  ('Jin', 'Ma')
# working on:  ('Marcel', 'Valcarce')
# working on:  ('Evangelos', 'Lympouridis')
# working on:  ('Karen', 'Perez')
# working on:  ('Eric', 'Allen')
# working on:  ('Heather', 'James')
# working on:  ('Samuel', 'Erman')
# working on:  ('Matthew', 'Gilpin')
# working on:  ('Eliz', 'Sanasarian')
# working on:  ('Sandeep', 'Gupta')
# working on:  ('Colleen', 'Keough')
# working on:  ('Milan', 'Miric')
# working on:  ('Sarah', 'Benor')
# working on:  ('Aaron', 'Hagedorn')
# working on:  ('Khalil', 'Iskarous')
# working on:  ('Patricia', 'Tobey')
# working on:  ('Christian', 'Pike')
# working on:  ('Howard', 'Greenwald')
# working on:  ('Thea', 'Tomaini')
# working on:  ('Helen', 'Kim')
# working on:  ('Robert', 'English')
# working on:  ('Marianne', 'Szymanski')
# working on:  ('Jennifer', 'Krogh')
# working on:  ('Jeffrey', 'Dubin')
# working on:  ('Laura', 'Cardinal')
# working on:  ('Douglas', 'Becker')
# working on:  ('Stefano', 'Rebeggiani')
# working on:  ('Yehuda', 'Gilad')
# working on:  ('Alfred', 'Brown')
# working on: working on: working on:  ('Michael', 'Overing')
#  ('Michael', 'Jakowec')
#  ('Patience', 'Moll')
# working on:  ('Benny', 'Forer')
# working on:  ('Mohammad', 'Safarzadeh')
# working on:  ('Samuel', 'Steinberg')
# working on:  ('Satwindar', 'Sadhal')
# working on:  ('Abbass', 'Sharif')
# working on: working on:  ('Ali', 'Abbas')
#  ('Xavier', 'Fumat')
# working on:  ('Jonathan', 'May')
# working on:  ('Fedor', 'Malikov')
# working on:  ('Maya', 'Maskarinec')
# working on:  ('Chunming', 'Wang')
# working on:  ('William', 'Deverell')
# working on:  ('Sofia', 'Martinez')
# working on:  ('James', 'Savoca')
# working on:  ('Marion', 'Philadelphia')
# working on:  ('Manochehr', 'Rashidian')
# working on:  ('Sandra', 'Ross')
# working on:  ('Dorinne', 'Kondo')
# working on:  ('Peter', 'Erskine')
# working on:  ('Dan', 'Field')
# working on:  ('Erika', 'Wright')
# working on:  ('Adlai', 'Wertman')
# working on:  ('Laura Isabel', 'Serna')
# working on:  ('Jan', 'Nissly')
# working on:  ('Supannika', 'Koolmanojwong')
# working on:  ('Muhammad', 'Naveed')
# working on:  ('Jae', 'Deal')
# working on:  ('Marie', 'Enright')
# working on:  ('Scott', 'Stone')
# working on:  ('Michael', 'Garcia')
# working on:  ('Nick', 'Strimple')
# working on:  ('Bruce', 'Zuckerman')
# working on:  ('Michelle Silver', 'Lee')
# working on:  ('Yanhao', 'Wei')
# working on:  ('Jill', 'Sohm')
# working on:  ('Steve', 'Ross')
# working on:  ('Richard', 'Vawter')
# working on:  ('Martha', 'Townsend')
# working on:  ('Brent', 'Chappelow')
# working on:  ('Nina', 'Rathbun')
# working on:  ('Gary', 'Rosen')
# working on:  ('Katherine', 'Shing')
# working on:  ('Wiebke', 'Ziebis')
# working on:  ('Seda', 'Durguner')
# working on:  ('Marc', 'Ballon')
# working on:  ('Cauligi', 'Raghavendra')
# working on:  ('Moh', 'El-Naggar')
# working on:  ('Peer', 'Fiss')
# working on:  ('Darry', 'Sragow')
# working on:  ('Nazam', 'Nageer')
# working on:  ('Sara', 'Haq')
# working on:  ('Sha', 'Yang')
# working on:  ('Karen', 'Kensek')
# working on:  ('Rory', 'Lukins')
# working on:  ('Lessa', 'Grunenfelder')
# working on:  ('Armand', 'Tanguay')
# working on:  ('Mike', 'Lee')
# working on:  ('Teddy', 'Lance')
# working on:  ('Tridib', 'Banerjee')
# working on:  ('Scott', 'Darrell')
# working on:  ('Antonio', 'Bento')
# working on:  ('Aluizio', 'Prata')
# working on:  ('Rex', 'Kovacevich')
# working on:  ('Jack', 'Feinberg')
# working on:  ('Lodovico', 'Pizzati')
# working on:  ('Alexandra', 'Graddy-Reed')
# working on:  ('Mark', 'Goldstein')
# working on:  ('Yuan', 'Gao')
# working on:  ('Clark', 'Kromenaker')
# working on:  ('Myron', 'Goodman')
# working on:  ('Julia', 'Chamberlin')
# working on:  ('Jonathan', 'Mullins')
# working on:  ('Chander', 'Burgos')
# working on:  ('Kristy', 'Payne')
# working on:  ('Atiyeh', 'Showrai')
# working on:  ('Virgil', 'Adumitroaie')
# working on:  ('Andrew', 'Goodney')
# working on:  ('Susan', 'Arnold')
# working on:  ('Lavonna', 'Lewis')
# working on: working on:  ('Murat', 'Bayiz')
#  ('Alberto', 'Vallejo')
# working on:  ('Niels', 'Frenzen')
# working on:  ('Canan', 'Ipek')
# working on:  ('Lee', 'Olvera')
# working on:  ('Candace', 'Smith')
# working on:  ('Sara', 'Schwartz')
# working on:  ('Joshua', 'Aizenman')
# working on:  ('Christopher', 'Fleming')
# working on:  ('Christopher', 'Muniz')
# working on:  ('Richard', 'Leahy')
# working on:  ('Lorraine', 'Turcotte')
# working on:  ('Christopher', 'Shaw')
# working on:  ('Ben', 'Lee')
# working on:  ('Howard', 'Rodman')
# working on:  ('Candice', 'Levy')
# working on:  ('Jaclyn', 'Cohen-Steinberg')
# working on:  ('Brittany', 'Kay')
# working on:  ('Barry', 'Boehm')
# working on:  ('Scott', 'Paterson')
# working on:  ('Hossein', 'Hashemi')
# working on:  ('Gerald', 'Davison')
# working on:  ('Ariela', 'Gross')
# working on:  ('Sabrina', 'Smiley')
# working on:  ('Jane', 'Pinckard')
# working on:  ('Jorge', 'De La Roca')
# working on:  ('John', 'Romley')
# working on:  ('Emily', 'Nix')
# working on:  ('Mary', 'Murphy')
# working on:  ('Bhargav', 'Oza')
# working on:  ('Botao', 'Yang')
# working on:  ('Ali', 'Nowroozi')
# working on:  ('Ergin', 'Bayrak')
# working on:  ('John', 'Pascarella')
# working on:  ('Christopher', 'Freeman')
# working on:  ('Tom', 'Chang')
# working on:  ('Rebecca', 'Broyer')
# working on:  ('Hanna', 'Reisler')
# working on:  ('Jean', 'Ho')
# working on:  ('Christopher', 'Gould')
# working on:  ('Donald', 'Arnold')
# working on:  ('Elizabeth', 'Misener')
# working on:  ('David', 'St John')
# working on:  ('Gregory', 'Treverton')
# working on:  ('Iris', 'Gonzalez')
# working on:  ('James', 'Steele')
# working on:  ('Jody', 'Armour')
# working on:  ('Jennifer', 'Misran')
# working on:  ('Jasmine', 'Bryant')
# working on:  ('Laura', 'Gale')
# working on:  ('Jenifer', 'Crawford')
# working on:  ('John', 'Murray')
# working on:  ('Inna', 'Abramova')
# working on:  ('Paolo', 'Sigismondi')
# working on:  ('James', 'Fortney')
# working on:  ('Michael', 'Neely')
# working on:  ('Nathan', 'Perl-Rosenthal')
# working on:  ('Stephen', 'Read')
# working on:  ('Thomas', 'Knapp')
# working on:  ('Jeff', 'Guh')
# working on:  ('Robert', 'Scheer')
# working on:  ('Tristan', 'Whitman')
# working on: working on:  ('Naomi', 'Warren')
#  ('Dana', 'Milstein')
# working on:  ('Neelesh', 'Tiruviluamala')
# working on:  ('Jennifer', 'Warren')
# working on:  ('Doni', 'Whitsett')
# working on:  ('Lindsay', "O'Neill")
# working on:  ('Rocio', 'Terry')
# working on:  ('David', 'Isaacs')
# working on:  ('Susan', 'Estrich')
# working on:  ('Ann', 'Owens')
# working on:  ('Bob', 'Bailey')
# working on:  ('Daria', 'Roithmayr')
# working on:  ('Najmedin', 'Meshkati')
# working on:  ('Trixy', 'Wattenbarger')
# working on:  ('Anthony', 'Borquez')
# working on:  ('Jillian', 'Pierson')
# working on:  ('Eric', 'Hanson')
# working on:  ('Frank', 'Corsetti')
# working on:  ('Tom', 'Hollihan')
# working on:  ('Jim', 'Staahl')
# working on:  ('Travis', 'Williams')
# working on:  ('Young', 'Cho')
# working on:  ('Nathalie', 'Bragadir')
# working on:  ('Peter', 'Calabrese')
# working on:  ('Gourab', 'Mukherjee')
# working on:  ('Gillian', 'Finley')
# working on:  ('Lauren', 'Matchison')
# working on:  ('Darren', 'Ruddell')
# working on:  ('Nitin', 'Govil')
# working on:  ('Paulo', 'Branicio')
# working on: working on:  ('Lan', 'Luo')
#  ('Jonathan', 'Diaz')
# working on:  ('Stacy', 'Smith')
# working on:  ('Mark', 'Marino')
# working on:  ('Jason', 'Ellenburg')
# working on:  ('Tamara', 'Espinet')
# working on:  ('Anita', 'Dashiell-Sparks')
# working on:  ('Ahmad', 'Besaratinia')
# working on:  ('Nicole', 'MacCalla')
# working on:  ('Yehuda', 'Ben-Zion')
# working on:  ('William', 'Feuerborn')
# working on:  ('David', 'Kang')
# working on:  ('Grayson', 'Jaggers')
# working on:  ('Edmond', 'Jonckheere')
# working on:  ('Heather', 'Davis')
# working on:  ('Lisa', 'Vest')
# working on:  ('Jesus', 'Fuentes')
# working on:  ('Lloyd', 'Levitin')
# working on:  ('Kidogo', 'Kennedy')
# working on:  ('Peyman', 'Nojoumian')
# working on:  ('Douglas', 'Burke')
# working on:  ('Arthur', 'Auerbach')
# working on:  ('John', 'Walsh')
# working on:  ('Bob', 'Girandola')
# working on:  ('Mohammad reza', 'Rajati')
# working on:  ('Sandra', 'Disner')
# working on:  ('Andrea', 'Armani')
# working on:  ('Elissa', 'Grossman')
# working on:  ('Terry', 'Gordon')
# working on:  ('Jennifer', 'Lewis')
# working on: working on:  ('Julia', 'Paull')
#  ('Neetu', 'Khanna')
# working on:  ('Scott', 'Abrams')
# working on:  ('Iva', 'Bozovic')
# working on:  ('Song-Hee', 'Kim')
# working on:  ('Sheldon', 'Kamienny')
# working on:  ('Laurie', 'Brand')
# working on:  ('Wanda', 'Jewell')
# working on: working on:  ('Ramesh', 'Govindan')
#  ('Jay', 'Bartroff')
# working on:  ('Eric', 'Rawson')
# working on:  ('Deborah', 'Seibel')
# working on:  ('Elizabeth', 'Falletta')
# working on:  ('Nicole', 'Kuklok-Waldman')
# working on:  ('Bart', 'Kosko')
# working on:  ('Victoria', 'Petryshyn')
# working on:  ('Helena', 'Seli')
# working on:  ('Alison', "D'Amato")
# working on:  ('Benita', 'Walton-Moss')
# working on:  ('Andy', 'Abad')
# working on:  ('Maria', 'Aranda')
# working on:  ('Farzana', 'Choudhury')
# working on:  ('Daniela', 'Baroffio')
# working on:  ('Irina', 'Jestkova')
# working on:  ('Megan', 'McCain')
# working on:  ('Thomas', 'Mueller')
# working on:  ('Vanessa', 'Schwartz')
# working on:  ('Massoud', 'Pirbazari')
# working on:  ('Karen', 'Sternheimer')
# working on:  ('Amanda', 'Hobmeier')
# working on:  ('Yanhui', 'Wu')
# working on:  ('Dan', 'Erwin')
# working on:  ('Robin', 'Jeshion')
# working on:  ('Caesar', 'Sedek')
# working on:  ('Marcia', 'Cunha')
# working on:  ('Brenda', 'Goodman')
# working on:  ('Susan', 'Friedlander')
# working on:  ('Jim', 'Hubbard')
# working on:  ('Stacy', 'Kratz')
# working on:  ('Anne', 'Katz')
# working on:  ('Parish', 'Sedghizadeh')
# working on:  ('Dana', 'Johnson')
# working on:  ('Kenneth', 'Breisch')
# working on:  ('Terry David', 'Church')
# working on:  ('Saeed', 'Mohasseb')
# working on:  ('Steve', 'Vankanegan')
# working on:  ('Gerd', 'Bergmann')
# working on:  ('Aninda', 'Das')
# working on:  ('Sanjay', 'Madhav')
# working on:  ('James', 'Owens')
# working on:  ('Dawn', 'Stoppiello')
# working on:  ('Roumyana', 'Pancheva')
# working on:  ('Andrew', 'Simpson')
# working on:  ('Pamela', 'Albanese')
# working on:  ('Chrislynn', 'Freed')
# working on:  ('William', 'Wyatt')
# working on:  ('Karen', 'Lincoln')
# working on:  ('Phil', 'Meyer')
# working on:  ('Jonathan', 'Aronson')
# working on:  ('Dave', 'Quast')
# working on:  ('Chris', 'Roze')
# working on:  ('Ladan', 'Masoudie')
# working on:  ('Stephanie', 'Dewing')
# working on:  ('Tim', 'Biblarz')
# working on:  ('Michael', 'Crowley')
# working on:  ('Costas', 'Synolakis')
# working on:  ('Jacob', 'Soll')
# working on:  ('Christopher', 'Smith')
# working on:  ('John', 'De Mita')
# working on:  ('Kendra', 'Atkin')
# working on:  ('Nathalie', 'Burle')
# working on:  ('Arthur', 'Chivichyan')
# working on:  ('Wei-Min', 'Shen')
# working on:  ('Julianna', 'Kirschner')
# working on:  ('Alan', 'Mittelstaedt')working on:  ('Brandon', 'Franzke')
#
# working on:  working on:  ('Larry', 'Jordan')
# ('Dariush', 'Derakhshani')
# working on:  working on:  ('Steve', 'Hsu')
# ('Kimon', 'Drakopoulos')
# working on:  ('Hye Jin', 'Lee')
# working on:  ('Chongwu', 'Zhou')
# working on:  ('Sherin', 'Guirguis')
# working on:  ('Christa', 'Bancroft')
# working on:  ('Kate', 'Flint')
# working on:  ('Guilan', 'Siassi')
# working on:  ('Anthony', 'Boyle')
# working on:  ('Geza', 'Bottlik')
# working on:  ('Ann Marie', 'Yamada')
# working on:  ('Lanita', 'Jacobs')
# working on:  ('Dan', 'Wei')
# working on:  ('Rebecca', 'Brown')
# working on:  ('Nabil', 'Ziane')
# working on:  ('Donald', 'Spivack')
# working on:  ('Alice', 'Echols')
# working on:  ('Arpi', 'Mardirossian')
# working on:  ('Ricardo', 'Mancera')
# working on:  ('Francesca', 'Italiano')
# working on:  ('Tamara', 'Black')
# working on:  ('Helaine', 'Lopes')
# working on:  ('Susanna', 'Seierup')
# working on:  ('Ashok', 'Srinivasan')
# working on:  ('Ryan', 'Boyd')
# working on:  ('Carolann', 'Peterson')
# working on:  ('Vibhor', 'Trehan')
# working on:  ('John', 'Wilson')
# working on:  working on:  ('Robert', 'Waller')
# working on:  ('Andrew', 'Bacon')
# ('Alisa', 'Sanchez')
# working on:  ('Paul', 'Young')
# working on:  ('Peter', 'Robinson')
# working on:  ('Anna', 'Krylov')
# working on:  ('Paul', 'Urcioli')
# working on:  ('Leah', 'Hochman')
# working on:  ('Donald', 'Yett')
# working on:  ('Mary', 'McNamara')
# working on:  ('Amanda', 'Pope')
# working on:  ('Trudy', 'Green')
# working on:  ('Gerald', 'Giaquinta')
# working on:  ('Heidi', 'Khalil')
# working on:  ('Alice', 'Fung')
# working on:  ('Marianna', 'Chodorowska-Pilch')
# working on:  ('John', 'Thomas')
# working on: working on:  ('Charles', 'Swenson')
#  ('Benjamin', 'Uchiyama')
# working on:  ('Hans', 'Bozler')
# working on:  ('Maureen', 'Yeager')
# working on:  ('Brian', 'Olson')
# working on:  ('Tigran', 'Ayrapetyan')
# working on:  ('Eric', 'Roth')
# working on:  ('Margo', 'Apostolos')
# working on:  ('Achinta', 'McDaniel')
# working on:  ('Jeremy', 'Dann')
# working on:  ('Kim', 'Goodman')
# working on:  ('Lars', 'Perner')
# working on:  ('Erin', 'Moore')
# working on:  ('Rhoda', 'Coleman')
# working on:  ('Paula', 'Carbone')
# working on:  ('David', 'Carter')
# working on:  ('Jimi', 'Huh')
# working on:  ('Mick', 'Swartz')
# working on:  ('Robert', 'Parke')
# working on:  ('Mark', 'Phillips')
# working on:  ('Bala', 'Subramanian')
# working on:  ('Audrey', 'Li')
# working on:  ('Gabriel', 'Kahn')
# working on:  ('Samantha', 'Burton')
# working on:  ('Ming-Deh', 'Huang')
# working on:  ('Andrew', 'Manion')
# working on:  ('Maki', 'Irie')
# working on:  ('Shenishe', 'Kelly')
# working on:  ('Brittani', 'Morris')
# working on:  ('Danielle', 'Brown')
# working on:  working on:  ('Lucia', 'Aparicio')
# ('Jeffrey', 'Fellenzer')
# working on:  ('William', 'Gorski')
# working on:  ('John', 'Carpenter')
# working on:  ('Sheila', 'Briggs')
# working on:  ('Joe', 'Saltzman')
# working on:  ('Christelle', 'Fischer-Bovet')
# working on:  ('Jon', 'Burlingame')
# working on:  ('William', 'Slaughter')
# working on:  ('Vahe', 'Peroomian')
# working on:  ('Jesse', 'Yen')
# working on:  ('Rook', 'Campbell')
# working on:  ('Kerry', 'Fields')
# working on:  ('Jeffrey', 'Fields')
# working on:  ('Laura', 'Ferguson')
# working on:  ('Alexis', 'Wellwood')
# working on:  ('Ann', 'Majchrzak')
# working on:  ('Gage', 'Crump')
# working on:  ('Melinda', 'Finberg')
# working on:  ('Nathaniel', 'Emerson')
# working on:  ('Bhaskar', 'Krishnamachari')
# working on:  ('Beverly', 'Younger')
# working on:  ('Julian', 'Gutierrez-Albilla')
# working on:  ('Drew', 'Casper')
# working on:  ('Alexis', 'Landau')
# working on:  ('Vicki', 'Callahan')
# working on:  ('Joseph', 'Priester')
# working on:  ('D Sabela', 'Grimes')
# working on:  ('Terence', 'Fitzgerald')
# working on:  ('Consuelo', 'Siguenza-Ortiz')
# working on:  ('Rika', 'Hiro')
# working on:  ('Ratika', 'Narag')
# working on:  ('Bianca', 'Harper')
# working on:  ('Lori', 'Mesrobian')
# working on:  ('Thomas', 'Cummings')
# working on:  ('Joe', 'Hacker')
# working on:  ('Sarah', 'Portnoy')
# working on:  ('Evan', 'Hughes')
# working on:  ('Leonard', 'Maltin')
# working on:  ('Frederic', 'Clark')
# working on:  ('Edgar', 'Arceneaux')
# working on: working on:   ('Jane', 'James')
# ('David', 'Tomkins')
# working on:  ('Carolyn', 'Malone')
# working on:  ('Richard', 'Arratia')
# working on:  ('Kyung Moon', 'Hwang')
# working on:  ('Carolyn', 'Phillips')
# working on:  ('Noah', 'Malmstadt')
# working on:  ('Brent', 'Liu')
# working on:  ('Margaret', 'Rosenthal')
# working on:  ('Steve', 'Bucher')
# working on:  ('Jason', 'Zevin')
# working on:  ('Bennett', 'Lee')
# working on:  ('Chad', 'Kendall')
# working on:  ('Scott', 'Spencer')
# working on:  ('Matthew', 'Manson')
# working on:  ('Stephen', 'Cronin')
# working on:  ('Rehan', 'Kapadia')
# working on:  ('Benjamin', 'Henwood')
# working on:  ('Scott', 'Soames')
# working on:  ('John', 'Ayoob')
# working on:  ('Jesse', 'Levitt')
# working on: working on:  ('Dion', 'Dickman')
#  ('Martha', 'Lyon-Levine')
# working on:  ('Shanea', 'Thomas')
# working on:  ('George', 'Sanchez')
# working on:  ('Emily', 'Anderson')
# working on:  ('Xianxian', 'Fang')
# working on:  ('Karen', 'North')
# working on:  ('Murali', 'Annavaram')
# working on:  ('Alexander', 'Zholkovsky')
# working on:  ('Tyan', 'Parker Dominguez')
# working on:  ('Sibyl', 'Wickersheimer')
# working on:  ('Jeff', 'Nugent')
# working on:  ('Ashutosh', 'Nayyar')
# working on:  ('Amy', 'Schroeder')
# working on:  ('Malgorzata', 'Switek')working on:  ('Laura', 'Davis')
#
# working on:  working on:  ('Alan', 'Berger')
# ('Christina', 'Haatainen-Jones')
# working on:  ('Jed', 'Fuhrman')
# working on:  ('Melissa', 'Robinson')
# working on:  ('Eileen', 'Abel')
# working on:  ('Linda', 'Hagen')
# working on:  ('Jay', 'Kuo')
# working on:  ('Alison', 'Trope')
# working on:  ('David', 'Zarazua')
# working on:  ('Kazuo', 'Takeda')
# working on:  ('Robertas', 'Gabrys')
# working on:  ('Leah', 'Kemp')
# working on:  ('Adam', 'Hughes')
# working on:  ('Ian', 'Culbertson')
# working on:  ('Ed', 'Goo')
# working on:  ('Gioia', 'Polidori')
# working on:  ('Steve', 'Hydon')
# working on:  ('Gabriel', 'Crenshaw')
# working on:  ('Kyung', 'Jung')
# working on:  ('Shaddin', 'Dughmi')
# working on:  ('David', 'Brind')
# working on:  ('Sonja', 'Warfield')
# working on:  ('Mary', 'Traester')
# working on:  ('Lawrence', 'Green')
# working on:  ('Tianshu', 'Sun')
# working on:  ('Cristina', 'Zavaleta')
# working on:  ('Sayd', 'Randle')
# working on:  ('Andrew', 'Ogilvie')
# working on:  ('David', 'Tsui')
# working on:  ('Fokion', 'Egolfopoulos')
# working on:  ('Liang', 'Chen')
# working on:  ('Zachary', 'Steel')
# working on:  ('Lilit', 'Keshishyan')
# working on:  ('Ben', 'Reichardt')
# working on:  ('Jessica', 'Cantiello')
# working on:  ('Paul', 'Orlando')
# working on:  ('Paolo', 'Zanardi')
# working on:  ('Emily', 'Rose')
# working on:  ('Shawn', 'Roll')
# working on:  ('Kevin', 'Robinson')
# working on:  ('Navdeep', 'Mundi')
# working on:  ('Elaine Bell', 'Kaplan')
# working on:  ('Deborah', 'Glynn')
# working on:  ('John', 'Arensmeyer')
# working on:  ('Kevin', 'Caporicci')
# working on:  ('Rahul', 'Jain')
# working on:  ('Morris', 'Levy')
# working on:  ('Nayan', 'Shah')
# working on:  ('Alan', 'Nelson')
# working on:  ('Rafael', 'Angulo')
# working on:  ('Michael', 'Bunn')
# working on:  ('Ivette', 'Gomez')
# working on:  ('Lannie', 'Tonnu')
# working on:  ('William', 'Feuer')
# working on:  ('Jinhee', 'Choung')
# working on:  ('Joseph', 'Lim')
# working on:  ('Guillaume', 'Dreyer')
# working on:  ('Reza', 'Bavafa')
# working on:  ('Leonard', 'Adleman')
# working on:  ('Suzanne', 'Hudson')
# working on:  ('Sherman', 'Jackson')
# working on:  ('Jackie', 'Kopcsak')
# working on:  ('Fred', 'Cook')
# working on:  ('Mark', 'Griffiths')
# working on:  ('Tok', 'Thompson')
# working on:  ('Richard', 'Lemarchand')
# working on:  ('Steven', 'Lopez')
# working on:  ('Chris', 'Bresnahan')
# working on:  ('Atia', 'Sattar')
# working on:  ('Kathleen', 'Woodruff')
# working on:  ('Kate', 'Levin')
# working on:  ('Mark', 'Moore')
# working on:  ('Jeremiah', "O'Brian")
# working on:  ('Helaine', 'Head')
# working on:  ('Zlatan', 'Damnjanovic')
# working on:  ('Keith', 'Mayerson')
# working on:  ('Robert', 'Vos')
# working on:  ('Ernest', 'Greene')
# working on:  ('Steven', 'Sussman')
# working on:  ('Jennifer', 'Greenhill')
# working on:  ('David', 'Cruz')
# working on:  ('Suvrajeet', 'Sen')
# working on:  ('Amy', 'Murphy')
# working on:  ('John', 'Heilman')
# working on:  ('Randy', 'Lake')
# working on:  ('Erich', 'Kreidler')
# working on:  ('Fayez', 'Hammad')
# working on:  ('Marcos', 'Briano')working on:  ('E Moncell', 'Durden')
#
# working on:  ('Leland', 'Saito')
# working on:  ('Diane', 'Badame')
# working on:  ('Dan', 'Lainer-Vos')
# working on:  ('Hilary', 'Schor')
# working on:  ('Lorena', 'Gallego')
# working on:  ('Helena', 'Yli-Renko')
# working on:  ('Linsey', 'Smith')
# working on:  ('Christian', 'Phillips')
# working on:  ('Daniel', 'Richter')
# working on:  ('Barrett', 'Koster')
# working on:  ('Christina', 'Lubinski')
# working on:  ('Devon', 'Brooks')
# working on:  ('Duke', 'Bristow')
# working on:  ('Eve', 'Lee')
# working on:  ('Sheldon', 'Ross')
# working on:  ('Nathan', 'Greenfield')
# working on:  ('Dennis', 'Schorr')
# working on: working on:  ('Vinay', 'Goyal')
#  ('Kadri', 'Vihvelin')
# working on:  ('Azure', 'Darby')
# working on:  ('Steven', 'Mednick')
# working on:  ('Carol', 'Wise')
# working on:  ('Douglas', 'Shook')
# working on:  ('Davide', 'Proserpio')
# working on:  ('Helen', 'Chung')
# working on:  ('Eric', 'Briggs')
# working on:  ('Sharon', 'Carnicke')
# working on:  ('Brian', 'Bernards')
# working on:  ('Marc', 'Aubertin')
# working on:  ('Antonia', 'Szabari')
# working on:  ('Carlos', 'Godoy')
# working on:  ('Ken', 'Sereno')
# working on:  ('Stephen', 'Moyer')
# working on:  ('Kirk', 'Snyder')
# working on: working on:  ('Ferol', 'Mennen')
#  ('Paul', 'Lerner')
# working on:  ('Sven', 'Koenig')
# working on:  ('Fengzhu', 'Sun')
# working on:  ('Reuven', 'Firestone')
# working on:  ('David', 'Weber')
# working on:  ('Caroline', 'Clerc')
# working on:  ('Christian', 'Grose')
# working on:  ('Tom', 'Buderwitz')
# working on:  ('Pamela', 'Douglas')
# working on:  ('Justin', 'Bibler')
# working on:  ('Inga', 'Maslova')
# working on:  ('Nan', 'Jia')
# working on:  ('Kristen', 'Zaleski')
# working on:  ('Kevin', 'Robb')
# working on:  ('Oliver', 'Rizk')
# working on:  ('Eric', 'Canny')
# working on:  ('Wensheng', 'Wu')
# working on:  ('Kian', 'Kaviani')
# working on:  ('Louis', 'Goldstein')
# working on:  ('Devon', 'Harlow')
# working on:  ('Daniel', 'Dissinger')
# working on:  ('Tatiana', 'Akishina')
# working on:  ('Tyson', 'Roberts')
# working on:  ('Edward', 'Avol')
# working on:  ('Aro', 'Velmet')
# working on:  ('Pierson', 'Clair')
# working on:  ('Mark', 'Haddad')
# working on:  ('Michael', 'Kassner')
# working on:  ('Stephanie', 'Bower')
# working on:  ('Mayumi', 'Ikeda')
# working on:  working on:  ('Bruce', 'Phillips')
# ('Anthony', 'Marino')
# working on:  ('Michael', 'Kodama')
# working on:  ('Haitian', 'Yue')
# working on:  ('Kayla', 'De La Haye')
# working on:  ('Richard', 'Selby')
# working on:  ('Sivarama', 'Vinjamury')
# working on:  ('Antoine', 'Bechara')
# working on:  ('Andrew', 'De Silva')
# working on:  ('Susanne', 'Foulk')
# working on:  ('Fariba', 'Ariaei')
# working on:  ('Marc', 'Schiler')
# working on:  ('Viktor', 'Prasanna')
# working on:  ('David', 'Roman')
# working on:  ('Robert', 'Hernandez')
# working on:  ('Lina', 'Bahn')
# working on:  ('Shefali', 'Rajamannar')
# working on:  ('Dan', 'Schrage')
# working on:  ('Ernest', 'Wilson')
# working on:  ('Roberto', 'Suro')
# working on:  ('John', 'Rowe')
# working on:  ('Trina', 'Gregory')
# working on:  ('Lisa', 'Pecot-Hebert')
# working on:  ('Michael', 'Patterson')
# working on:  ('Monalisa', 'Chatterjee')
# working on:  ('Jose', 'Zavala')
# working on:  ('Alexis', 'Zoto')
# working on:  ('Marisa', 'Mandler')
# working on:  ('Alan', 'Willner')working on:  ('Tin-Yu', 'Tseng')
#
# working on:  ('Xuehai', 'Qian')
# working on:  ('Juan', 'Araque')
# working on:  ('Julie', 'Van Dam')
# working on:  ('Christina', 'Paddock')
# working on:  ('Lakshmanan', 'Sathyavagiswaran')
# working on:  ('Antonio', 'Elefano')
# working on:  ('Eric', 'Junker')
# working on:  ('Paul', 'Kowalski')
# working on:  ('Caroline', 'Betts')
# working on:  ('Renee', 'Smith-Maddox')
# working on: working on:  ('Juliet', 'Musso')
#  ('Marcia', 'Wilson')
# working on:  ('Ted', 'Lee')
# working on:  ('George', 'Braunegg')
# working on:  ('Ann', 'Crigler')
# working on:  ('Sooran', 'Pak')
# working on:  ('Genevieve', 'Giuliano')
# working on:  ('Paat', 'Rusmevichientong')
# working on:  ('Janet', 'Levin')
# working on:  ('Cristian', 'Grases')
# working on:  ('Dana', 'Gioia')
# working on:  ('Daniel', 'Schnur')
# working on:  ('Albert', 'Napoli')
# working on:  ('Osonde', 'Osoba')
# working on:  ('Anna', 'Krakus')
# working on:  ('Edward', 'Maby')
# working on:  ('Kate', 'Crowley')
# working on:  ('Sarah', 'Mojarad')
# working on:  ('Zune', 'Nguyen')
# working on:  ('Hsiao-Yun', 'Liao')
# working on:  ('Richard', 'Fliegel')
# working on:  ('Sri', 'Narayan')
# working on:  ('Marci', 'Vogel')
# working on:  ('Devin', 'Griffiths')
# working on:  ('Daniel', 'Durbin')
# working on:  ('Selale', 'Tuzel')
# working on:  ('Wolf', 'Gruner')
# working on:  ('Hyunjung', 'Ahn')
# working on:  ('John', 'Dreher')
# working on:  ('Roger', 'Ghanem')
# working on:  ('Dale', 'Kiefer')
# working on:  ('Mark', 'Schroeder')
# working on:  ('Cynthia', 'Alt')
# working on:  ('Cristina', 'Visperas')
# working on:  ('Kerry', 'Ingram')
# working on:  ('Jennifer', 'Cool')
# working on:  ('Andrew', 'Kutchera')
# working on:  ('Susan', 'Helfter')
# working on:  ('Kendra', 'Walther')
# working on:  ('Massoud', 'Pedram')
# working on:  ('Antonio', 'Idini')
# working on:  ('Mahvash', 'Navazesh')
# working on:  ('Vincent', 'Lee')
# working on:  ('Harry', 'Hunter')
# working on:  ('Alicia', 'Chavez')
# working on:  ('Andreas', 'Molisch')
# working on:  ('Mohammed', 'Beshir')
# working on:  ('Nicolai', 'Haydn')
# working on:  ('Edwin', 'Hill')
# working on:  ('Thomas', 'Ward')
# working on:  ('John', 'Monterosso')
# working on:  ('Porter', 'Williams')
# working on:  ('Sean', 'Nye')
# working on:  ('Jamie', 'Fudacz')
# working on:  ('Michael', 'Du Plessis')
# working on:  ('Robert', 'Shrum')
# working on:  ('Firdaus', 'Udwadia')
# working on:  ('Scott', 'Easley')
# working on:  ('Bettine', 'Birge')
# working on:  ('Artineh', 'Samkian')
# working on:  ('Steve', 'Nutt')
# working on:  ('Hagit', 'Arieli-Chai')
# working on:  ('Steve', 'Lund')
# working on:  ('Rosa', 'Di Felice')
# working on:  ('Eva', 'Kanso')
# working on:  ('Albert', 'Herrera')
# working on:  ('Michael', 'Mische')
# working on:  ('Kristine', 'Garroway')
# working on:  ('April', 'Davidauskis')
# working on:  ('Rebecca', 'Weintraub')
# working on:  ('Ian', 'Goodwin')
# working on:  ('Oussama', 'Safadi')
# working on:  ('Aaron', 'Cote')
# working on:  ('Youngmin', 'Choe')
# working on:  ('David', 'Crombecque')
# working on:  ('Gregg', 'Daniel')
# working on:  ('Claire', 'Bono')
# working on:  ('Scott', 'Smith')
# working on:  ('Nayeon', 'Kim')
# working on:  ('Alexander', 'Sawchuk')
# working on:  ('Tom', 'Lyon')
# working on:  ('Stephen', 'MacK')
# working on:  ('Lori', 'Smith')
# working on:  ('Lily', 'Ross')
# working on:  ('David', 'Ginsburg')
# working on:  ('Ruth', 'Chung')
# working on:  ('Andrew', 'Gracey')
# working on:  ('Annie', 'Chen')
# working on:  ('Michael', 'Wissot')
# working on:  ('Amy', 'Watson')
# working on:  ('Yong', 'Chen')
# working on:  ('Susan', 'Segal')
# working on:  ('Nick', 'Cull')
# working on:  ('David', 'Balkan')
# working on:  ('Dexter', 'Booth')
# working on:  ('Stanislav', 'Minsker')
# working on:  ('Briana', 'Hinga')
# working on:  ('Robert', 'Alderette')
# working on:  ('Sena', 'Durguner')
# working on:  ('Sule', 'Guney')
# working on:  ('Michael', 'Thom')
# working on:  ('Mansour', 'Rahimi')
# working on:  ('Aleks', 'Baharlo')
# working on:  ('Tony', 'Levi')
# working on:  ('Miya', 'Mizuta')
# working on:  ('Susan', 'McCabe')
# working on:  ('Tracie', 'Mayfield')
# working on:  ('Julie', 'Slayton')
# working on:  ('Edward', 'Rhodes')
# working on:  ('Mike', 'Brennan')
# working on:  ('Sunyoung', 'Park')
# working on:  ('Henry', 'Jenkins')
# working on:  ('Lori', 'Meeks')
# working on:  ('Andrew', 'Campbell')
# working on:  ('Paul', 'Giuliano')
# working on:  ('Michael', 'Hurlburt')
# working on:  ('Alice', 'Gambrell')
# working on:  ('Shannon', 'Gibson')
# working on:  ('Dan', 'Klerman')
# working on:  ('Callie', 'Siskel')
# working on:  ('Jacob', 'Ross')
# working on:  ('Yan', 'Jin')
# working on:  ('Bernadene', 'Blaha')
# working on:  ('Claradina', 'Soto')
# working on:  ('David', 'Stamper')
# working on:  ('John', 'Loper')
# working on:  ('Divana', 'Olivas')
# working on:  ('Christopher', 'Atkins')
# working on:  ('Todd', 'Gish')
# working on:  ('Lisa', 'Leeman')
# working on:  ('Monique', 'Datta')
# working on:  ('Ewa', 'Wojciak')
# working on:  ('Laura', 'Loyola')
# working on:  ('Heidi', 'Rummel')
# working on:  ('Phil', 'Allen')
# working on:  ('Krzysztof', 'Pilch')
# working on:  ('Neal', 'Desby')
# working on:  ('Yijia', 'Guo')
# working on:  ('Stephanie', 'Payne')
# working on:  ('Thomas', 'Gustafson')
# working on:  ('Suh-Pyng', 'Ku')
# working on:  ('David', 'Poe')
# working on:  ('Josh', 'Kun')
# working on:  ('Nathalie', 'Joseph')
# working on:  ('Toby', 'Mintz')
# working on:  ('Daniel', "O'Leary")
# working on:  ('Eric', 'Webb')
# working on:  ('Amy', 'Cannon')
# working on:  ('Aimee', 'Bender')
# working on:  ('Felicia', 'Tabing')
# working on:  ('Panayiota', 'Courelli')
# working on:  ('Anthony', 'Kemp')
# working on:  ('Howard', 'Croom')
# working on:  ('Jane', 'Junn')
# working on:  ('Lindsey', 'Bier')
# working on:  ('Aaron', 'Winslow')
# working on:  ('Mark', 'Weiser')
# working on:  ('Paul', 'Orfalea')
# working on:  ('Roksana', 'Karim')
# working on:  ('Gene', 'Bickers')
# working on:  ('Francille', 'Wilson')
# working on:  ('Martin', 'Daniel')
# working on:  ('James', 'Polk')
# working on:  ('Kelsey', 'Rubin-Detlev')
# working on:  ('Robert', 'Nashak')
# working on:  ('Mohammad Reza', 'Rajati')
# working on:  ('Olu', 'Orange')
# working on:  ('James', 'Boedicker')
# working on:  ('Paul', 'Lichterman')
# working on:  ('Elsi', 'Kaiser')
# working on:  ('Timothy', 'Burton')
# working on:  ('Grace', 'Lu')
# working on:  ('Maura', 'Crowley')
# working on:  ('Graham', 'Robertson')
# working on:  ('Leana', 'Golubchik')
# working on: working on:  ('Elizabeth', 'Amini')
#  ('Xochitl', 'Ruiz')
# working on:  ('Ellen', 'Oliveira')
# working on:  ('Hazel', 'Atuel')
# working on:  ('Patrick', 'Maio')
# working on:  ('James', 'Condon')
# working on:  ('Michael', 'Cody')
# working on:  ('Sozan', 'Wali')
# working on:  ('Matthew', 'Pratt')
# working on:  ('Stephen', 'Finlay')
# working on:  ('Meggan', 'Thompson')
# working on:  ('Lowell', 'Stott')
# working on:  ('David', 'Craig')
# working on:  ('Anthony', 'Kammas')
# working on:  ('Sergey', 'Lototsky')
# working on:  ('Christina', 'Belcher')
# working on:  ('Robert', 'Sacker')
# working on:  ('Dowell', 'Myers')
# working on:  ('Francis', 'Pereira')
# working on:  ('Brooklyne', 'Gipson')
# working on:  ('Yvette', 'Amirian')
# working on:  ('Holly', 'Willis')
# working on:  ('Sheldon', 'Larry')
# working on:  ('Stephanie', 'Sabo')
# working on:  ('Amy', 'Rechenmacher')
# working on:  ('Ken', 'Cazan')
# working on:  ('Dave', 'Lavond')
# working on:  ('Jessica', 'Parr')
# working on:  ('Debra', 'Berl')
# working on:  ('Beatriz', 'Ilari')
# working on:  ('Eli', 'Levenson-Falk')
# working on:  ('Farida', 'Habeeb')
# working on:  ('Sharon', 'Lavery')
# working on:  ('Susan', 'Edwards')
# working on:  ('Sarah', 'Feakins')
# working on:  ('Mark', 'Redekopp')
# working on:  ('Jack', 'Peters')
# working on:  ('Annalisa', 'Enrile')
# working on:  ('Kathleen', 'Becker')
# working on:  ('Vianey', 'Cabrera')
# working on:  ('Todd', 'Boyd')
# working on:  ('Paul', 'Ronney')
# working on:  ('John', 'Strauss')
# working on:  ('Nathanael', 'Fast')
# working on: working on:  ('Elizabeth', 'Brauer') ('Gregg', 'Brandow')
#
# working on: working on:  ('Kurt', 'Kwast')
#  ('Julie', 'Suh')
# working on:  ('Smrity', 'Randhawa')
# working on:  ('Amber', 'Foster')
# working on:  ('Geraldine', 'Fiss')
# working on:  ('Mary', 'Byram Washburn')
# working on:  ('Carl', 'Collins')
# working on:  ('Edwin', 'McCann')
# working on:  ('Myka', 'Winder')
# working on:  ('Laura', 'Flanagan')
# working on:  ('Urbashi', 'Mitra')
# working on:  ('Joshua', 'Goldstein')
# working on:  ('Eric', 'Coe')
# working on:  ('Rick', 'Schmunk')
# working on:  ('Laura', 'Baker')
# working on:  ('Wendy', 'Wood')
# working on:  ('Ketaki', 'Pant')
# working on:  ('Pamela', 'Starr')
# working on:  ('Jonathan', 'Markowitz')
# working on:  ('Indra', 'Mukhopadhyay')
# working on:  ('Todd', 'Brun')
# working on: working on:  ('Lon', 'Kurashige')
#  ('Trond', 'Sigurdsen')
# working on:  ('Geert', 'Ridder')
# working on:  ('Adrian', 'Stern')
# working on:  ('Guofu', 'Tan')
# working on:  ('Mary', 'Harris')
# working on:  ('Barnet', 'Kellman')working on:  ('Quentin', 'Fleming')
#
# working on:  ('Susan', 'Gavigan')
# working on:  ('David', 'Treuer')
# working on:  ('David', 'Dreyer')
# working on:  ('Cynthia', 'Rollo-Carlson')
# working on: working on:  ('Maria', 'Escobedo')
#  ('Maria', 'Colman')
# working on:  ('Lucas', 'Herchenroeder')
# working on:  ('Fred', 'Stone')
# working on:  ('Brandi', 'Wells')
# working on:  ('Giorgio', 'Coricelli')
# working on:  ('Bruce', 'Yazejian')
# working on:  ('Michael', 'Coombs')
# working on:  ('Alessio', 'Filippi')
# working on:  ('Jessica', 'Klein')
# working on:  ('Priya', 'Jaikumar')
# working on:  ('Emmy', 'Min')
# working on:  ('Janet', 'Batchler')
# working on:  ('Jason', 'Fulman')
# working on: working on:  ('Nenad', 'Medvidovic')
#  ('Duncan', 'Mahoney')
# working on:  ('Steven', 'Brookman')
# working on:  ('Meisam', 'Razaviyayn')
# working on:  ('Maria', 'Zubizarreta')working on:
#  ('Chrisshonna', 'Nieva')
# working on:  ('Murali', 'Nair')
# working on:  ('Matthew', 'Whiting')
# working on:  ('Caitlin', "O'Connell")
# working on:  ('Ira', 'Kalb')
# working on:  ('Ramzi', 'Rouighi')
# working on:  ('Michael', 'Petitti')
# working on:  ('Timothy', 'Kobza')
# working on:  ('Scott', 'Applebaum')
# working on:  ('Michael', 'Rank')
# working on:  ('Paul', 'Tokorcheck')
# working on:  ('Gandhi', 'Puvvada')
# working on:  ('Bruce', 'Smith')
# working on:  ('Carl', 'Voigt')
# working on:  ('Yael', 'Wolinsky-Nahmias')
# working on:  ('Jessica', 'Kanoski')
# working on: working on:  ('Michael', 'Magill')
#  ('David', "D'Argenio")
# working on:  ('Martin', 'Gundersen')
# working on:  ('Emily', 'Liman')
# working on:  ('Stanley', 'Rosen')
# working on:  ('Carmen', 'Lee')
# working on:  ('Nick', 'Stoubis')
# working on:  ('Caroline', 'Cicero')
# working on:  ('Lauraanne', 'Carroll-Adler')
# working on: working on:  ('John', 'Pollini')
#  ('Shinyi', 'Wu')
# working on:  ('Robert', 'Young')
# working on:  ('Jennifer', 'Swift')
# working on:  ('Alice', 'Parker')
# working on:  ('Tessa', 'Milman')
# working on:  ('Andrea', 'Parra')
# working on:  ('Percival', 'Everett')
# working on:  ('Elisa', 'Warford')
# working on:  ('Stephen', 'Monte')
# working on:  ('Lisa', 'Kabot')
# working on:  ('Ali', 'Zadeh')
# working on:  ('Richard', 'Brutchey')
# working on:  ('Cecil', 'Jackson')
# working on:  ('Laurent', 'Itti')
# working on:  ('Therese', 'Wilbur')
# working on:  ('Nora', 'Ayanian')
# working on:  ('Aravind', 'Asok')
# working on:  ('Geoffrey', 'Cowan')
# working on:  ('Jennifer', 'Lott')
# working on:  ('Diane', 'Winston')
# working on:  ('Sarah', 'Bonner')
# working on:  ('Robert', 'Dekle')
# working on:  ('Francesca', 'Leardini')
# working on:  ('Roberto', 'Diaz')
# working on:  ('Chao', 'Wang')
# working on:  ('Amy', 'Bresnahan')
# working on:  ('Megan', 'Luke')
# working on:  ('Sandra', 'Batista')
# working on:  ('Bruce', 'Block')
# working on:  ('Jolanta', 'Aritz')
# working on:  ('Debbie', 'Murad')
# working on:  ('Irving', 'Belateche')
# working on:  ('Justin', 'Haldar')
# working on:  ('Kurt', 'Palmer')
# working on:  ('James', 'Van Cleve')
# working on:  ('William', 'Thalmann')
# working on:  ('Elizabeth', 'Durst')
# working on:  ('Ruben', 'Davila')
# working on:  ('Thomas', 'Bertolini')
# working on:  ('Charles', 'Gutierrez')
# working on:  ('Greys', 'Sosic')
# working on:  ('Marco', 'Papa')
# working on:  ('Amanda', 'Bloom')
# working on:  ('Brian', 'Rathbun')
# working on:  ('Sergey', 'Nuzhdin')
# working on:  ('Victoria', 'Behner')
# working on:  ('Monica', 'Bachner')
# working on:  ('Patrick', 'Henry')
# working on:  ('Jianfeng', 'Zhang')
# working on:  ('Miranda', 'Barone')
# working on:  ('Susan', 'Lape')
# working on:  ('Yumi', 'Matsumoto')
# working on:  ('Anahit', 'Hakoupian')
# working on:  ('Julien', 'Emile-Geay')
# working on:  ('Ricky', 'Bluthenthal')
# working on: working on:  ('Panivong', 'Norindr')
#  ('Alvin', 'Huang')
# working on:  ('Ralph', 'Wedgwood')
# working on:  ('Jacques', 'Hymans')
# working on:  ('Clayton', 'Stephenson')
# working on:  ('Karla', 'Heidelberg')
# working on:  ('Isabelle', 'Brocas')
# working on:  ('Tom', 'Sloper')
# working on:  ('Marco', 'Paolieri')
# working on:  ('Sarah', 'Mesle')
# working on:  ('Rick', 'Berg')
# working on:  ('Stephanie', 'Shroyer')
# working on:  ('Shiing-Wu', 'Wang')
# working on:  ('Christopher', 'Sutherland')
# working on:  ('Mara', 'Ziegler')
# working on:  ('Michael', 'Uno')
# working on:  ('Ruth', 'White')
# working on:  ('Nicole', 'Darling')
# working on:  ('Remigijus', 'Mikulevicius')
# working on:  ('Shahriar', 'Shamsian')
# working on:  ('Jessica', 'Marglin')
# working on:  ('Peter', 'Qin')
# working on:  ('Velina', 'Hasu Houston')
# working on:  ('Jeb', 'Barnes')
# working on:  ('Yao-Yi', 'Chiang')
# working on:  ('Shahin', 'Nazarian')
# working on:  ('Stephan', 'Haas')
# working on:  ('Ellen', 'Seiter')
# working on:  ('Stephanie', 'Eggert')
# working on:  ('Samia', 'Rafeedie')
# working on:  ('Erin', 'Graff Zivin')
# working on:  ('Dennis', 'Nemeschansky')
# working on:  ('Geoffrey', 'Shiflett')
# working on:  ('Gayle', 'Fiedler-Vierma')
# working on:  ('Laurie', 'Fisher')
# working on:  ('Ivan', 'Nikkhoo')
# working on:  ('Brett', 'Sheehan')
# working on:  ('Nina', 'Eliasoph')
# working on:  ('Helen', 'Choi')
# working on:  ('David', 'Tang')
# working on:  ('Steven', 'Bush')
# working on:  ('Konstantinos', 'Psounis')
# working on:  ('Ron', 'Grover')
# working on:  ('Deborah', 'Sims')
# working on:  ('Yuka', 'Kumagai')
# working on:  ('Mahmood', 'Sariolghalam')
# working on:  ('Meiling', 'Cheng')
# working on:  ('Vincent', 'Farenga')
# working on:  ('Yi-Hsien', 'Liu')
# working on:  ('Bill', 'Yahraus')
# working on:  ('Ulrich', 'Neumann')
# working on: working on:  ('Mary Joan', 'Negro')
#  working on:  ('Trisha', 'Tucker')
# ('Merle', 'Hopkins')
# working on: working on:  ('William', 'Resh')
#  ('Audra', 'Bardsley')
# working on:  ('Eric', 'Goldberg')
# working on:  ('Gelya', 'Frank')
# working on:  ('Jud', 'Fine')
# working on:  ('Aniko', 'Imre')
# working on:  ('Clifford', 'Neuman')
# working on:  ('Masako', 'Tamanaha')
# working on:  ('David', 'Bottjer')
# working on:  ('Sarah', 'Kessler')
# working on:  ('Rochelle', 'Gold')
# working on:  ('Victor', 'Regnier')
# working on:  ('Carolin', 'Fleischmann')
# working on:  ('Cary', 'Frydman')
# working on:  ('Miao', 'Zhang')
# working on:  ('Gerardo', 'Munck')
# working on:  ('Daniel', 'Tiffany')
# working on:  ('Michael', 'Sproul')
# working on:  ('Jonathan', 'Kotler')
# working on:  ('Taiyaba', 'Husain')
# working on:  ('John', 'Slaughter')
# working on:  ('Parag', 'Havaldar')
# working on:  ('Christopher', 'Harrer')
# working on:  ('Jessi', 'Johnson')
# working on:  ('Aaron', 'Mazel-Gee')
# working on:  ('Jessica', 'Piazza')
# working on:  ('Rodney', 'Ramcharan')
# working on:  ('Antonio', 'Ortega')
# working on:  ('Corinne', 'Hyde')
# working on: working on:  ('Jill', 'Kickul')
#  ('Andrea', 'Stolpe')
# working on:  ('Haipeng', 'Luo')
# working on:  ('Ben', 'Poston')
# working on:  ('Rotem', 'Gilbert')
# working on:  ('Mark', 'Irwin')
# working on:  ('Christoph', 'Haselwandter')
# working on:  ('Karen', 'Tongson')
# working on:  ('Kenneth', 'Phillips')
# working on:  ('Liana', 'Stepanyan')
# working on:  ('Sharoni', 'Little')
# working on:  ('Nicole', 'Maccalla')
# working on:  ('Barry', 'Schein')
# working on:  ('Brent', 'Melot')
# working on:  ('Brad', 'Shipley')
# working on:  ('Steven', 'Lamy')
# working on:  ('Yann', 'Staelens')
# working on:  ('Ramtin', 'Sheikhhassani')
# working on:  ('Mike', 'Ananny')
# working on:  ('Molly', 'Bendall')
# working on:  ('Tom', 'Peterson')
# working on:  ('Victor', 'Adamchik')
# working on:  ('Terry', 'Cravens')
# working on:  ('Stacy', 'Geck')
# working on:  ('Iraj', 'Ershaghi')
# working on:  ('Pablo', 'Frasconi')
# working on:  ('Morteza', 'Dehghani')
# working on:  ('Olivera', 'Grujic')
# working on:  ('Oliver', 'Mayer')
# working on:  ('Lisa', 'Schweitzer')
# working on:  ('Jeffrey', 'Miller')
# working on:  ('Cesar', 'Armendariz')
# working on:  ('Doug', 'Thomas')
# working on:  ('Hajime', 'Hoji')
# working on:  ('Tara', 'McPherson')
# working on: working on:  ('Charles', 'Radovich')
#  ('Brian', 'Head')
# working on:  ('Scott', 'Faris')
# working on:  ('Carter', 'Wellford')
# working on:  ('Greg', 'Autry')
# working on:  ('Jahan', 'Dawlaty')
# working on:  ('Sima', 'Parisay')
# working on:  ('Seth', 'Kurzban')
# working on:  ('Taj', 'Frazier')
# working on:  ('Tessa', 'Waterbury Wallace')
# working on:  ('Vasilis', 'Marmarelis')
# working on:  ('Anna', 'Journey')
# working on:  ('Keith', 'Jenkins')
# working on:  ('Carlos Antonio', 'Delgado')
# working on:  ('Martin', 'Ocon-Gamarra')
# working on: working on:  ('Andrew', 'Nealen')
#  ('Elizabeth', 'Zelinski')
# working on:  ('Elisabeth', 'Weiss')
# working on:  ('Kimberly', 'Morris')
# working on:  ('Nimfa', 'Bemis')
# working on:  working on:  ('Ellen', 'Wayland-Smith')
# ('Stephen', 'Byars')
# working on:  ('Peter', 'Carnevale')
# working on:  ('Tom', 'Sito')
# working on:  ('Sharon', 'Gillerman')
# working on:  ('Xiang', 'Jian')
# working on:  ('Doug', 'Hammond')working on:  ('Meridith', 'Kruse')
#
# working on:  ('Larry', 'Goldstein')
# working on:  ('Hiroshi', 'Ochiumi')
# working on:  ('Barbara', 'Nance')
# working on:  ('David', 'Bialock')
# working on:  ('Brighde', 'Mullins')
# working on:  ('Sara', 'McSweyn')
# working on:  ('Sarah', 'Bream')
# working on:  ('Amy', 'Parish')
# working on:  ('Greta', 'Matzner-Gore')
# working on:  ('Dana', 'Tate')
# working on:  ('Moe', 'Tabar')
# working on:  ('Victoria', 'Cortessis')
# working on:  ('Sasha', 'Anawalt')
# working on:  ('Aimei', 'Yang')
# working on:  ('Dmitri', 'Williams')
# working on:  ('Harly', 'Ramsey')
# working on:  ('Joan', 'Piggott')
# working on:  ('Rajiv', 'Kalia')
# working on:  ('Carly', 'Kenkel')
# working on:  ('Christopher', 'Magriney')
# working on: working on:  ('Maria', 'Ogneva')
#  ('Cara', 'Esposito')
# working on:  ('John', 'Jessee')
# working on:  ('Yongxiang', 'Wang')
# working on:  ('Kelly', 'Sanders')
# working on:  ('Chris', 'Kyriakakis')
# working on:  ('Trudi', 'Ferguson')
# working on:  ('Raymond', 'Kim')
# working on:  ('Rebecca', 'Lemon')
# working on:  ('Emerson', 'Whitney')
# working on:  ('Jane', 'Allgood')
# working on:  ('David', 'Measer')
# working on:  ('Robert', 'Brown')
# working on:  ('Allan', 'Weber')
# working on:  ('Barry', 'Thompson')
# working on:  ('Sylvain', 'Barbot')
# working on:  ('Richard', 'Fox')
# working on:  ('Parmer', 'Fuller')
# working on:  ('Scott', 'Wiltermuth')
# working on:  ('Aiichiro', 'Nakano')
# working on:  ('Joshua', 'Garroway')
# Wall time: 4min 35s

# %%
with open(join('.','profScoreDB.json'), 'w') as outfile:
    json.dump(profDict, outfile)
